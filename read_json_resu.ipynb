# %%
import json

# %%
# res json 
with open('res_feature.json', 'r') as f:
    res = json.load(f)

# %%
res["grupos"]["3"]["respuesta"]
# Out:
# [{'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 1, '3D': 1}},
#  {'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 1, '3D': 3}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 1, '3D': 2}},
#  {'meanshift': {'2D': 3, '3D': 4}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 3, '3D': 3}},
#  {'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 2, '3D': 3}},
#  {'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': 2, '3D': 3}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 3, '3D': 3}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 1, '3D': 1}},
# ...

# %%
res["grupos"]["4"]["respuesta"]
# Out:
# [{'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 2, '3D': 3}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 0, '3D': 1}},
#  {'meanshift': {'2D': -1, '3D': -1}, 'distancia': {'2D': -1, '3D': -1}},
#  {'meanshift': {'2D': -1, '3D': -1}, 'distancia': {'2D': -1, '3D': -1}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 2, '3D': 3}},
#  {'meanshift': {'2D': 3, '3D': 2}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': -1, '3D': -1}, 'distancia': {'2D': -1, '3D': -1}},
#  {'meanshift': {'2D': 2, '3D': 3}, 'distancia': {'2D': 3, '3D': 3}},
#  {'meanshift': {'2D': 2, '3D': 3}, 'distancia': {'2D': 3, '3D': 3}},
#  {'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': -1, '3D': -1}, 'distancia': {'2D': -1, '3D': -1}},
#  {'meanshift': {'2D': 2, '3D': 2}, 'distancia': {'2D': 2, '3D': 2}},
#  {'meanshift': {'2D': 3, '3D': 3}, 'distancia': {'2D': 3, '3D': 3}},
# ...

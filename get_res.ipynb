# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "99.7918426990509"}, {"result": "l", "confidence": "99.9342143535614"}, {"result": "l", "confidence": "99.93488192558289"}, {"result": "l", "confidence": "99.6771514415741"}, {"result": "l", "confidence": "99.70840811729431"}], "L": [{"result": "l", "confidence": "97.96609878540039"}, {"result": "l", "confidence": "99.60057139396667"}, {"result": "i", "confidence": "54.73031401634216"}, {"result": "i", "confidence": "77.76991128921509"}, {"result": "i", "confidence": "99.90906715393066"}, {"result": "i", "confidence": "57.017356157302856"}, {"result": "i", "confidence": "99.25318360328674"}], "I": [{"result": "i", "confidence": "99.99767541885376"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.99868869781494"}, {"result": "i", "confidence": "99.99512434005737"}, {"result": "i", "confidence": "99.98871088027954"}, {"result": "i", "confidence": "99.998939037323"}, {"result": "i", "confidence": "99.99920129776001"}]}, "400": {"C": [{"result": "l", "confidence": "96.69417142868042"}, {"result": "l", "confidence": "98.63470196723938"}, {"result": "l", "confidence": "98.65055680274963"}, {"result": "l", "confidence": "98.76118302345276"}, {"result": "i", "confidence": "89.76896405220032"}], "L": [{"result": "i", "confidence": "84.9324107170105"}, {"result": "i", "confidence": "71.70587182044983"}, {"result": "l", "confidence": "80.58302998542786"}, {"result": "l", "confidence": "89.38096165657043"}, {"result": "l", "confidence": "51.98996663093567"}, {"result": "i", "confidence": "99.95697140693665"}, {"result": "i", "confidence": "98.8224983215332"}], "I": [{"result": "i", "confidence": "99.99960660934448"}, {"result": "i", "confidence": "99.99750852584839"}, {"result": "i", "confidence": "99.98859167098999"}, {"result": "i", "confidence": "99.99812841415405"}, {"result": "i", "confidence": "99.99645948410034"}, {"result": "i", "confidence": "99.99587535858154"}]}}, "4": {"400": {"C": [{"result": "l", "confidence": "86.04772090911865"}, {"result": "l", "confidence": "50.53004026412964"}, {"result": "c", "confidence": "99.96335506439209"}, {"result": "c", "confidence": "99.67594742774963"}, {"result": "l", "confidence": "93.34042072296143"}, {"result": "l", "confidence": "94.92576718330383"}], "L": [{"result": "l", "confidence": "90.68928360939026"}, {"result": "c", "confidence": "68.18195581436157"}, {"result": "l", "confidence": "98.04392457008362"}, {"result": "i", "confidence": "99.99191761016846"}, {"result": "i", "confidence": "99.35075044631958"}, {"result": "i", "confidence": "99.99865293502808"}, {"result": "l", "confidence": "92.63414144515991"}], "I": [{"result": "i", "confidence": "99.99972581863403"}, {"result": "i", "confidence": "99.98537302017212"}, {"result": "i", "confidence": "99.99778270721436"}, {"result": "i", "confidence": "99.99030828475952"}, {"result": "i", "confidence": "99.99905824661255"}, {"result": "i", "confidence": "99.99760389328003"}]}}}, "orientacion": {"300": {"0": [{"angulo_tronco": 97.63217354281869, "angulo_head": 133.02771854733768}], "10": [{"angulo_tronco": 65.30181205180021, "angulo_head": 135.79632386100673}], "20": [{"angulo_tronco": 72.8720651285016, "angulo_head": 143.9373260504487}], "30": [{"angulo_tronco": 65.46623917203848, "angulo_head": 141.92458562937594}], "40": [{"angulo_tronco": 64.08025772692066, "angulo_head": 144.3307685524131}], "50": [{"angulo_tronco": 62.38101883835048, "angulo_head": 129.3004930913894}], "60": [{"angulo_tronco": 68.00758743710576, "angulo_head": 144.3451420933635}], "70": [{"angulo_tronco": 73.51667136822026, "angulo_head": 155.20368783641058}], "80": [{"angulo_tronco": 83.06164776508514, "angulo_head": 17.086801791390062}], "90": [{"angulo_tronco": 88.36225897773828, "angulo_head": 77.3696867986521}], "100": [{"angulo_tronco": 97.03800492111004, "angulo_head": 170.53211108865565}], "110": [{"angulo_tronco": 94.4853910542397, "angulo_head": 29.60200203273414}], "120": [{"angulo_tronco": 101.42576344771665, "angulo_head": 14.854540068915675}], "130": [{"angulo_tronco": 104.04684065280318, "angulo_head": 46.64983454105424}], "140": [{"angulo_tronco": 106.6570454016648, "angulo_head": 49.673258165396234}], "150": [{"angulo_tronco": 115.30853300459573, "angulo_head": 46.38011884982403}], "160": [{"angulo_tronco": 126.54611080509635, "angulo_head": 159.6690652067564}], "170": [{"angulo_tronco": 115.96906274759144, "angulo_head": 47.497010244363985}], "180": [{"angulo_tronco": 106.04198379636438, "angulo_head": 53.851080887869614}]}, "400": {"0": [{"angulo_tronco": 82.62483300625804, "angulo_head": 30.448227172394482}], "10": [{"angulo_tronco": 67.74878534713962, "angulo_head": 134.4925558224257}], "20": [{"angulo_tronco": 65.0439890969014, "angulo_head": 148.11312814210478}], "30": [{"angulo_tronco": 66.44926741027504, "angulo_head": 148.9998944516593}], "40": [{"angulo_tronco": 67.04760280968584, "angulo_head": 154.3870062515948}], "50": [{"angulo_tronco": 72.9074269065016, "angulo_head": 0.8133400631961045}], "60": [{"angulo_tronco": 83.15362423801058, "angulo_head": 131.05648868727192}], "70": [{"angulo_tronco": 82.51048475159558, "angulo_head": 172.30408655854248}], "80": [{"angulo_tronco": 75.18748320566868, "angulo_head": 31.145183944468016}], "90": [{"angulo_tronco": 93.15380783139969, "angulo_head": 52.26033615536096}], "100": [{"angulo_tronco": 98.58553063174138, "angulo_head": 169.7073799980331}], "110": [{"angulo_tronco": 99.1387615480177, "angulo_head": 86.75802844998826}], "120": [{"angulo_tronco": 103.92769188944766, "angulo_head": 166.91652248234695}], "130": [{"angulo_tronco": 108.84367286522502, "angulo_head": 25.160150219214646}], "140": [{"angulo_tronco": 109.6229010619986, "angulo_head": 55.91734933105603}], "150": [{"angulo_tronco": 111.84512812204052, "angulo_head": 38.351089252978326}], "160": [{"angulo_tronco": 114.75647802659084, "angulo_head": 33.28084014042117}], "170": [{"angulo_tronco": 109.4636504959893, "angulo_head": 44.96236509697537}], "180": [{"angulo_tronco": 81.91844830139414, "angulo_head": 100.73324150766781}]}}, "centroide": {"200": [{"respuesta": 216.64108969329322}], "250": [{"respuesta": 259.1378955364812}], "300": [{"respuesta": 306.79296281594964}], "350": [{"respuesta": 342.6873590941022}], "400": [{"respuesta": 377.55884514155764}], "450": [{"respuesta": 415.04750852370114}], "500": [{"respuesta": 441.81836171233545}], "550": [{"respuesta": 477.6504283450015}], "600": [{"respuesta": 499.87975965410607}]}}

json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "99.7918426990509"}, {"result": "l", "confidence": "99.9342143535614"}, {"result": "l", "confidence": "99.93488192558289"}, {"result": "l", "confidence": "99.6771514415741"}, {"result": "c", "confidence": "98.77012372016907"}, {"result": "l", "confidence": "96.27203345298767"}, {"result": "l", "confidence": "99.70840811729431"}, {"result": "l", "confidence": "99.30549263954163"}], "L": [{"result": "l", "confidence": "97.96609878540039"}, {"result": "l", "confidence": "99.60057139396667"}, {"result": "i", "confidence": "54.73031401634216"}, {"result": "i", "confidence": "77.76991128921509"}, {"result": "i", "confidence": "99.90906715393066"}, {"result": "i", "confidence": "57.017356157302856"}, {"result": "i", "confidence": "99.25318360328674"}], "I": [{"result": "i", "confidence": "99.99767541885376"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.99868869781494"}, {"result": "i", "confidence": "99.99512434005737"}, {"result": "i", "confidence": "99.98871088027954"}, {"result": "i", "confidence": "99.998939037323"}, {"result": "i", "confidence": "99.99920129776001"}]}, "400": {"C": [{"result": "l", "confidence": "96.69417142868042"}, {"result": "l", "confidence": "98.63470196723938"}, {"result": "l", "confidence": "98.65055680274963"}, {"result": "l", "confidence": "98.76118302345276"}, {"result": "i", "confidence": "89.76896405220032"}], "L": [{"result": "i", "confidence": "84.9324107170105"}, {"result": "i", "confidence": "71.70587182044983"}, {"result": "l", "confidence": "80.58302998542786"}, {"result": "l", "confidence": "89.38096165657043"}, {"result": "l", "confidence": "51.98996663093567"}, {"result": "i", "confidence": "99.95697140693665"}, {"result": "i", "confidence": "98.8224983215332"}], "I": [{"result": "i", "confidence": "99.99960660934448"}, {"result": "i", "confidence": "99.99746084213257"}, {"result": "i", "confidence": "99.98859167098999"}, {"result": "i", "confidence": "99.99812841415405"}, {"result": "i", "confidence": "99.99645948410034"}, {"result": "i", "confidence": "99.99587535858154"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99974966049194"}, {"result": "c", "confidence": "99.99107122421265"}, {"result": "c", "confidence": "99.99979734420776"}, {"result": "c", "confidence": "99.99959468841553"}, {"result": "c", "confidence": "100.0"}], "L": [{"result": "l", "confidence": "41.84539318084717"}, {"result": "c", "confidence": "95.14276385307312"}, {"result": "c", "confidence": "94.72702741622925"}, {"result": "c", "confidence": "95.550537109375"}, {"result": "c", "confidence": "87.62655854225159"}, {"result": "c", "confidence": "99.8311996459961"}, {"result": "c", "confidence": "99.96079802513123"}], "I": [{"result": "c", "confidence": "57.89933204650879"}, {"result": "i", "confidence": "99.99895095825195"}, {"result": "i", "confidence": "99.87210631370544"}, {"result": "i", "confidence": "100.0"}, {"result": "c", "confidence": "99.93452429771423"}, {"result": "i", "confidence": "99.99895095825195"}]}, "400": {"C": [{"result": "l", "confidence": "86.04772090911865"}, {"result": "l", "confidence": "50.53004026412964"}, {"result": "c", "confidence": "99.96335506439209"}, {"result": "c", "confidence": "99.67594742774963"}, {"result": "l", "confidence": "93.34042072296143"}, {"result": "l", "confidence": "94.92576718330383"}], "L": [{"result": "l", "confidence": "90.68928360939026"}, {"result": "c", "confidence": "68.18195581436157"}, {"result": "l", "confidence": "98.04392457008362"}, {"result": "i", "confidence": "99.99191761016846"}, {"result": "i", "confidence": "99.35075044631958"}, {"result": "i", "confidence": "99.99865293502808"}, {"result": "l", "confidence": "92.63414144515991"}], "I": [{"result": "i", "confidence": "99.99972581863403"}, {"result": "i", "confidence": "99.98537302017212"}, {"result": "i", "confidence": "99.99778270721436"}, {"result": "i", "confidence": "99.99030828475952"}, {"result": "i", "confidence": "99.99905824661255"}, {"result": "i", "confidence": "99.99760389328003"}]}}}, "orientacion": {"300": {"0": [{"angulo_tronco": 97.45419799074611, "angulo_head": 133.0584049703109}], "10": [{"angulo_tronco": 65.37997926571981, "angulo_head": 135.8405666118621}], "20": [{"angulo_tronco": 72.8688559725881, "angulo_head": 143.9381217855784}], "30": [{"angulo_tronco": 65.45448434461139, "angulo_head": 141.96389744466094}], "40": [{"angulo_tronco": 64.09342152775206, "angulo_head": 144.3079608729674}], "50": [{"angulo_tronco": 62.414142886458684, "angulo_head": 129.41082577644949}], "60": [{"angulo_tronco": 67.99892550811275, "angulo_head": 144.49054200129302}], "70": [{"angulo_tronco": 73.50908132163681, "angulo_head": 155.21112930313484}], "80": [{"angulo_tronco": 83.08186579983986, "angulo_head": 17.10944663894334}], "90": [{"angulo_tronco": 88.35792083885384, "angulo_head": 77.35543846963148}], "100": [{"angulo_tronco": 97.04875049226153, "angulo_head": 170.77621364923908}], "110": [{"angulo_tronco": 94.49146559417572, "angulo_head": 29.722292408205224}], "120": [{"angulo_tronco": 101.42526680326895, "angulo_head": 14.82967939182156}], "130": [{"angulo_tronco": 104.04014078695515, "angulo_head": 47.120476338078554}], "140": [{"angulo_tronco": 106.67742470195073, "angulo_head": 49.72111935169167}], "150": [{"angulo_tronco": 115.3071543293285, "angulo_head": 46.37598713341727}], "160": [{"angulo_tronco": 126.34771595807597, "angulo_head": 159.92936409327032}], "170": [{"angulo_tronco": 115.98647876281595, "angulo_head": 47.43523287069966}], "180": [{"angulo_tronco": 105.89437168158994, "angulo_head": 53.85689151318752}]}, "400": {"0": [{"angulo_tronco": 81.92818421036658, "angulo_head": 30.490805099090178}], "10": [{"angulo_tronco": 65.95627822375504, "angulo_head": 134.48986564247187}], "20": [{"angulo_tronco": 65.02761093868271, "angulo_head": 148.08146260802488}], "30": [{"angulo_tronco": 66.37226692367551, "angulo_head": 148.98698798436783}], "40": [{"angulo_tronco": 67.07903540959438, "angulo_head": 154.07786667361236}], "50": [{"angulo_tronco": 72.96221947304606, "angulo_head": 0.7805126140772602}], "60": [{"angulo_tronco": 83.17419998067187, "angulo_head": 130.89734862837244}], "70": [{"angulo_tronco": 82.55671951839055, "angulo_head": 172.25433842470235}], "80": [{"angulo_tronco": 75.18818007261423, "angulo_head": 31.082111509149726}], "90": [{"angulo_tronco": 93.13788594773891, "angulo_head": 52.13811276871598}], "100": [{"angulo_tronco": 98.61082960843895, "angulo_head": 169.0117055331501}], "110": [{"angulo_tronco": 99.07695651395919, "angulo_head": 86.76838371392573}], "120": [{"angulo_tronco": 103.8883203130615, "angulo_head": 166.99800799754058}], "130": [{"angulo_tronco": 108.89103520341264, "angulo_head": 25.106782898952417}], "140": [{"angulo_tronco": 109.64891678879053, "angulo_head": 56.018847510630266}], "150": [{"angulo_tronco": 111.85327479509176, "angulo_head": 38.21689289002704}], "160": [{"angulo_tronco": 114.81658672945284, "angulo_head": 33.276330222095645}], "170": [{"angulo_tronco": 109.52453296935423, "angulo_head": 45.02461293077568}], "180": [{"angulo_tronco": 81.87445609782041, "angulo_head": 100.73401365381599}]}}, "centroide": {"200": [{"respuesta": 216.64126361726204}], "250": [{"respuesta": 259.13870283884177}], "300": [{"respuesta": 306.7948690756065}], "350": [{"respuesta": 342.67746709706677}], "400": [{"respuesta": 377.56358540033443}], "450": [{"respuesta": 415.0414520519196}], "500": [{"respuesta": 441.8292924765998}], "550": [{"respuesta": 477.65506693271465}], "600": [{"respuesta": 499.86781610384935}]}}

json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "99.7918426990509"}, {"result": "l", "confidence": "99.93430972099304"}, {"result": "l", "confidence": "99.93626475334167"}, {"result": "l", "confidence": "99.67965483665466"}, {"result": "c", "confidence": "98.77870678901672"}, {"result": "l", "confidence": "78.95211577415466"}, {"result": "l", "confidence": "99.70307350158691"}, {"result": "l", "confidence": "98.121178150177"}], "L": [{"result": "l", "confidence": "97.95929193496704"}, {"result": "l", "confidence": "99.60184693336487"}, {"result": "i", "confidence": "54.99337911605835"}, {"result": "i", "confidence": "77.96856760978699"}, {"result": "i", "confidence": "99.91514682769775"}, {"result": "i", "confidence": "56.562042236328125"}, {"result": "i", "confidence": "99.19829964637756"}], "I": [{"result": "i", "confidence": "99.99771118164062"}, {"result": "i", "confidence": "99.28483963012695"}, {"result": "i", "confidence": "98.9891529083252"}, {"result": "i", "confidence": "99.99513626098633"}, {"result": "c", "confidence": "96.04439735412598"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.99922513961792"}]}, "400": {"C": [{"result": "l", "confidence": "92.0781135559082"}, {"result": "l", "confidence": "90.21356105804443"}, {"result": "l", "confidence": "96.37677073478699"}, {"result": "l", "confidence": "97.27256298065186"}, {"result": "i", "confidence": "95.37464380264282"}], "L": [{"result": "i", "confidence": "88.92126679420471"}, {"result": "i", "confidence": "77.22364068031311"}, {"result": "l", "confidence": "59.46840047836304"}, {"result": "l", "confidence": "75.59521794319153"}, {"result": "i", "confidence": "58.22567343711853"}, {"result": "i", "confidence": "99.96726512908936"}, {"result": "i", "confidence": "99.37809109687805"}], "I": [{"result": "i", "confidence": "99.99814033508301"}, {"result": "c", "confidence": "98.54605793952942"}, {"result": "i", "confidence": "99.9842643737793"}, {"result": "i", "confidence": "99.99034404754639"}, {"result": "i", "confidence": "99.98971223831177"}, {"result": "i", "confidence": "96.53478264808655"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.9991774559021"}, {"result": "c", "confidence": "99.9972939491272"}, {"result": "c", "confidence": "99.9982237815857"}, {"result": "c", "confidence": "99.99456405639648"}, {"result": "c", "confidence": "100.0"}], "L": [{"result": "l", "confidence": "68.84782910346985"}, {"result": "c", "confidence": "96.42050266265869"}, {"result": "c", "confidence": "97.05550074577332"}, {"result": "i", "confidence": "52.54409909248352"}, {"result": "l", "confidence": "94.39217448234558"}, {"result": "c", "confidence": "99.7848629951477"}, {"result": "c", "confidence": "99.8353123664856"}], "I": [{"result": "i", "confidence": "99.9990701675415"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "i", "confidence": "99.99903440475464"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "c", "confidence": "98.82275462150574"}, {"result": "i", "confidence": "99.99881982803345"}]}, "400": {"C": [{"result": "l", "confidence": "78.46137285232544"}, {"result": "c", "confidence": "99.36375617980957"}, {"result": "c", "confidence": "99.99680519104004"}, {"result": "c", "confidence": "95.72116136550903"}, {"result": "c", "confidence": "99.64369535446167"}, {"result": "c", "confidence": "91.91946387290955"}], "L": [{"result": "l", "confidence": "77.79381275177002"}, {"result": "c", "confidence": "97.50154614448547"}, {"result": "l", "confidence": "87.3197615146637"}, {"result": "c", "confidence": "99.27393794059753"}, {"result": "i", "confidence": "97.71486520767212"}, {"result": "c", "confidence": "81.04536533355713"}, {"result": "l", "confidence": "60.83188056945801"}], "I": [{"result": "i", "confidence": "99.99903440475464"}, {"result": "i", "confidence": "70.42229175567627"}, {"result": "i", "confidence": "99.98855590820312"}, {"result": "i", "confidence": "98.28422665596008"}, {"result": "i", "confidence": "99.98877048492432"}, {"result": "i", "confidence": "99.98247027397156"}]}}}, "orientacion": {"300": {"0": [{"angulo_tronco": 97.70559581805583, "angulo_head": 133.01236716202325}], "10": [{"angulo_tronco": 65.34249168344854, "angulo_head": 135.80543528994616}], "20": [{"angulo_tronco": 72.8629897011342, "angulo_head": 143.9356179156583}], "30": [{"angulo_tronco": 65.46182381641032, "angulo_head": 141.93202426156458}], "40": [{"angulo_tronco": 64.10745291759966, "angulo_head": 144.37410298282722}], "50": [{"angulo_tronco": 62.38981441739162, "angulo_head": 129.3197209883253}], "60": [{"angulo_tronco": 68.0053046269868, "angulo_head": 144.42931318219786}], "70": [{"angulo_tronco": 73.49898351374273, "angulo_head": 155.2506869020946}], "80": [{"angulo_tronco": 83.09920235928703, "angulo_head": 17.074839467003653}], "90": [{"angulo_tronco": 88.38252864931724, "angulo_head": 77.33742735967178}], "100": [{"angulo_tronco": 97.05124822357841, "angulo_head": 170.6901910557747}], "110": [{"angulo_tronco": 94.53040339603618, "angulo_head": 29.725157987272404}], "120": [{"angulo_tronco": 101.41683947216677, "angulo_head": 14.854712078843367}], "130": [{"angulo_tronco": 104.07310237231592, "angulo_head": 47.102577038247816}], "140": [{"angulo_tronco": 106.65657593361547, "angulo_head": 49.5862789321198}], "150": [{"angulo_tronco": 115.18699115669827, "angulo_head": 46.417219511164504}], "160": [{"angulo_tronco": 126.55708922393657, "angulo_head": 159.65457660238087}], "170": [{"angulo_tronco": 115.9728327910319, "angulo_head": 47.42625735336168}], "180": [{"angulo_tronco": 106.14348527903276, "angulo_head": 53.85038673375125}]}, "400": {"0": [{"angulo_tronco": 81.86824627395418, "angulo_head": 30.485878051679858}], "10": [{"angulo_tronco": 67.30155350890146, "angulo_head": 134.48170747953725}], "20": [{"angulo_tronco": 65.04181747370488, "angulo_head": 148.09823831744598}], "30": [{"angulo_tronco": 66.43980122238956, "angulo_head": 148.97969071747232}], "40": [{"angulo_tronco": 67.03533062013402, "angulo_head": 154.1972148804637}], "50": [{"angulo_tronco": 72.93135229244517, "angulo_head": 0.9591078916530823}], "60": [{"angulo_tronco": 83.1342225021261, "angulo_head": 130.91596010440756}], "70": [{"angulo_tronco": 82.5014075097548, "angulo_head": 172.03313700906085}], "80": [{"angulo_tronco": 75.22862023375741, "angulo_head": 31.296733741907644}], "90": [{"angulo_tronco": 93.16023107051424, "angulo_head": 52.469325924715804}], "100": [{"angulo_tronco": 98.55307137634432, "angulo_head": 169.753175161625}], "110": [{"angulo_tronco": 99.09875626073604, "angulo_head": 86.76654614826754}], "120": [{"angulo_tronco": 103.91863911802717, "angulo_head": 167.1732300404946}], "130": [{"angulo_tronco": 108.904766981668, "angulo_head": 25.17211993290106}], "140": [{"angulo_tronco": 109.60877000372433, "angulo_head": 55.8524387748133}], "150": [{"angulo_tronco": 111.82595015683431, "angulo_head": 38.94779284905703}], "160": [{"angulo_tronco": 114.83859328737731, "angulo_head": 33.29535104540535}], "170": [{"angulo_tronco": 109.3760286781733, "angulo_head": 44.99028653901188}], "180": [{"angulo_tronco": 81.75392680769161, "angulo_head": 100.7348514244224}]}}, "centroide": {"200": [{"respuesta": 216.64116101831132}], "250": [{"respuesta": 259.1384417711776}], "300": [{"respuesta": 306.794599243715}], "350": [{"respuesta": 342.68691683347055}], "400": [{"respuesta": 377.5567638726991}], "450": [{"respuesta": 415.0408560941459}], "500": [{"respuesta": 441.814930981846}], "550": [{"respuesta": 477.6791876779364}], "600": [{"respuesta": 499.88678811455986}]}}

json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "99.7918426990509"}, {"result": "l", "confidence": "99.93430972099304"}, {"result": "l", "confidence": "99.93626475334167"}, {"result": "l", "confidence": "99.67965483665466"}, {"result": "c", "confidence": "98.77870678901672"}, {"result": "l", "confidence": "78.95211577415466"}, {"result": "l", "confidence": "99.70307350158691"}, {"result": "l", "confidence": "98.121178150177"}], "L": [{"result": "l", "confidence": "97.95929193496704"}, {"result": "l", "confidence": "99.60184693336487"}, {"result": "i", "confidence": "54.99337911605835"}, {"result": "i", "confidence": "77.96856760978699"}, {"result": "i", "confidence": "99.91514682769775"}, {"result": "i", "confidence": "56.562042236328125"}, {"result": "i", "confidence": "99.19829964637756"}], "I": [{"result": "i", "confidence": "99.99771118164062"}, {"result": "i", "confidence": "99.28483963012695"}, {"result": "i", "confidence": "98.9891529083252"}, {"result": "i", "confidence": "99.99513626098633"}, {"result": "c", "confidence": "96.04439735412598"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.99922513961792"}]}, "400": {"C": [{"result": "l", "confidence": "92.0781135559082"}, {"result": "l", "confidence": "90.21356105804443"}, {"result": "l", "confidence": "96.37677073478699"}, {"result": "l", "confidence": "97.27256298065186"}, {"result": "i", "confidence": "95.37464380264282"}], "L": [{"result": "i", "confidence": "88.92126679420471"}, {"result": "i", "confidence": "77.22364068031311"}, {"result": "l", "confidence": "59.46840047836304"}, {"result": "l", "confidence": "75.59521794319153"}, {"result": "i", "confidence": "58.22567343711853"}, {"result": "i", "confidence": "99.96726512908936"}, {"result": "i", "confidence": "99.37809109687805"}], "I": [{"result": "i", "confidence": "99.99814033508301"}, {"result": "c", "confidence": "98.54605793952942"}, {"result": "i", "confidence": "99.9842643737793"}, {"result": "i", "confidence": "99.99034404754639"}, {"result": "i", "confidence": "99.98971223831177"}, {"result": "i", "confidence": "96.53478264808655"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.9991774559021"}, {"result": "c", "confidence": "99.9972939491272"}, {"result": "c", "confidence": "99.9982237815857"}, {"result": "c", "confidence": "99.99456405639648"}, {"result": "c", "confidence": "100.0"}], "L": [{"result": "l", "confidence": "68.84782910346985"}, {"result": "c", "confidence": "96.42050266265869"}, {"result": "c", "confidence": "97.05550074577332"}, {"result": "i", "confidence": "52.54409909248352"}, {"result": "l", "confidence": "94.39217448234558"}, {"result": "c", "confidence": "99.7848629951477"}, {"result": "c", "confidence": "99.8353123664856"}], "I": [{"result": "i", "confidence": "99.9990701675415"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "i", "confidence": "99.99903440475464"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "c", "confidence": "98.82275462150574"}, {"result": "i", "confidence": "99.99881982803345"}]}, "400": {"C": [{"result": "l", "confidence": "78.46137285232544"}, {"result": "c", "confidence": "99.36375617980957"}, {"result": "c", "confidence": "99.99680519104004"}, {"result": "c", "confidence": "95.72116136550903"}, {"result": "c", "confidence": "99.64369535446167"}, {"result": "c", "confidence": "91.91946387290955"}], "L": [{"result": "l", "confidence": "77.79381275177002"}, {"result": "c", "confidence": "97.50154614448547"}, {"result": "l", "confidence": "87.3197615146637"}, {"result": "c", "confidence": "99.27393794059753"}, {"result": "i", "confidence": "97.71486520767212"}, {"result": "c", "confidence": "81.04536533355713"}, {"result": "l", "confidence": "60.83188056945801"}], "I": [{"result": "i", "confidence": "99.99903440475464"}, {"result": "i", "confidence": "70.42229175567627"}, {"result": "i", "confidence": "99.98855590820312"}, {"result": "i", "confidence": "98.28422665596008"}, {"result": "i", "confidence": "99.98877048492432"}, {"result": "i", "confidence": "99.98247027397156"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.386663306550595, "angulo_head": 127.45621697283309}], "10": [{"angulo_tronco": 70.79070815862502, "angulo_head": 131.03087719277573}], "20": [{"angulo_tronco": 57.60547026927022, "angulo_head": 140.07989399546068}], "30": [{"angulo_tronco": 60.20051365989525, "angulo_head": 29.90628630522383}], "40": [{"angulo_tronco": 56.25053342149898, "angulo_head": 28.249152206055125}], "50": [{"angulo_tronco": 67.54887111796852, "angulo_head": 155.16485498617664}], "60": [{"angulo_tronco": 74.49936038556093, "angulo_head": 7.170206614035131}], "70": [{"angulo_tronco": 81.34040016244545, "angulo_head": 8.62163567332764}], "80": [{"angulo_tronco": 85.73112729756035, "angulo_head": 21.8677892208914}], "90": [{"angulo_tronco": 87.13215538178936, "angulo_head": 19.452031505990355}], "100": [{"angulo_tronco": 98.4870804644207, "angulo_head": 135.58952432032788}], "110": [{"angulo_tronco": 98.30270157869019, "angulo_head": 171.6438005364622}], "120": [{"angulo_tronco": 111.56499012449633, "angulo_head": 167.87928521729302}], "130": [{"angulo_tronco": 110.38670225909976, "angulo_head": 30.218290742937686}], "140": [{"angulo_tronco": 118.99584306674939, "angulo_head": 35.33177706828631}], "150": [{"angulo_tronco": 120.26957928327994, "angulo_head": 40.23846407332815}], "160": [{"angulo_tronco": 124.94491752458302, "angulo_head": 55.379887106647296}], "170": [{"angulo_tronco": 132.4559348363482, "angulo_head": 61.55000259459894}], "180": [{"angulo_tronco": 100.67628306200959, "angulo_head": 60.42641033755926}]}, "300": {"0": [{"angulo_tronco": 97.4597549038032, "angulo_head": 133.0384813522326}], "10": [{"angulo_tronco": 65.35947238622754, "angulo_head": 135.80202569106584}], "20": [{"angulo_tronco": 72.8697935555347, "angulo_head": 143.94896590772936}], "30": [{"angulo_tronco": 65.47464772033727, "angulo_head": 141.93852447458548}], "40": [{"angulo_tronco": 64.09269168327616, "angulo_head": 144.32026942932978}], "50": [{"angulo_tronco": 62.38266590170093, "angulo_head": 129.2964533249162}], "60": [{"angulo_tronco": 67.99879835248683, "angulo_head": 144.29681428133935}], "70": [{"angulo_tronco": 73.51689605948367, "angulo_head": 155.25103748555418}], "80": [{"angulo_tronco": 83.03937209895004, "angulo_head": 17.107545037010258}], "90": [{"angulo_tronco": 88.36611151515058, "angulo_head": 77.32623559733481}], "100": [{"angulo_tronco": 97.05515643859653, "angulo_head": 170.09415321145443}], "110": [{"angulo_tronco": 94.50631450310621, "angulo_head": 29.650653517433003}], "120": [{"angulo_tronco": 101.42413351648636, "angulo_head": 14.899826591107061}], "130": [{"angulo_tronco": 104.01752815911546, "angulo_head": 46.96815084926203}], "140": [{"angulo_tronco": 106.64763411793479, "angulo_head": 49.65985177816348}], "150": [{"angulo_tronco": 115.20923225064911, "angulo_head": 46.390899609991024}], "160": [{"angulo_tronco": 126.57369902454381, "angulo_head": 159.67525636474457}], "170": [{"angulo_tronco": 115.97754841186757, "angulo_head": 47.450216181952314}], "180": [{"angulo_tronco": 105.89863186657685, "angulo_head": 53.83489256826431}]}, "400": {"0": [{"angulo_tronco": 81.95413978768038, "angulo_head": 30.519843391903247}], "10": [{"angulo_tronco": 67.96268482487541, "angulo_head": 134.49261102795057}], "20": [{"angulo_tronco": 65.12530361645462, "angulo_head": 148.12014951788677}], "30": [{"angulo_tronco": 66.41390511413206, "angulo_head": 148.96355141058808}], "40": [{"angulo_tronco": 67.0647473892199, "angulo_head": 154.25902808786566}], "50": [{"angulo_tronco": 72.90118953025981, "angulo_head": 0.6663215036573228}], "60": [{"angulo_tronco": 83.45014149002415, "angulo_head": 130.61087638160913}], "70": [{"angulo_tronco": 82.50579325973867, "angulo_head": 171.87659353224524}], "80": [{"angulo_tronco": 75.25571547066319, "angulo_head": 30.927428886877475}], "90": [{"angulo_tronco": 93.152779949733, "angulo_head": 52.137916100950086}], "100": [{"angulo_tronco": 98.54328344142755, "angulo_head": 169.76081859501446}], "110": [{"angulo_tronco": 99.17718516910448, "angulo_head": 86.71950368510286}], "120": [{"angulo_tronco": 103.95761003702178, "angulo_head": 167.25384918290743}], "130": [{"angulo_tronco": 108.87734852644182, "angulo_head": 25.192009250495868}], "140": [{"angulo_tronco": 109.69336045542191, "angulo_head": 56.13723141143659}], "150": [{"angulo_tronco": 111.8829871414338, "angulo_head": 38.297719425424894}], "160": [{"angulo_tronco": 114.62365717375266, "angulo_head": 33.33436592019702}], "170": [{"angulo_tronco": 109.76864514118364, "angulo_head": 45.027062821330674}], "180": [{"angulo_tronco": 81.74458220793049, "angulo_head": 100.738822265784}]}}, "centroide": {"200": [{"respuesta": 216.64093885867544}], "250": [{"respuesta": 259.1393236906849}], "300": [{"respuesta": 306.7902581979072}], "350": [{"respuesta": 342.6807754686696}], "400": [{"respuesta": 377.5605381065107}], "450": [{"respuesta": 415.0391148435324}], "500": [{"respuesta": 441.821443118625}], "550": [{"respuesta": 477.65853093171745}], "600": [{"respuesta": 499.88361184413725}]}}

json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "99.7918426990509"}, {"result": "l", "confidence": "99.93430972099304"}, {"result": "l", "confidence": "99.93626475334167"}, {"result": "l", "confidence": "99.67965483665466"}, {"result": "c", "confidence": "98.77870678901672"}, {"result": "l", "confidence": "78.95211577415466"}, {"result": "l", "confidence": "99.70307350158691"}, {"result": "l", "confidence": "98.121178150177"}], "L": [{"result": "l", "confidence": "97.95929193496704"}, {"result": "l", "confidence": "99.60184693336487"}, {"result": "i", "confidence": "54.99337911605835"}, {"result": "i", "confidence": "77.96856760978699"}, {"result": "i", "confidence": "99.91514682769775"}, {"result": "i", "confidence": "56.562042236328125"}, {"result": "i", "confidence": "99.19829964637756"}], "I": [{"result": "i", "confidence": "99.99771118164062"}, {"result": "i", "confidence": "99.28483963012695"}, {"result": "i", "confidence": "98.9891529083252"}, {"result": "i", "confidence": "92.11738705635071"}, {"result": "c", "confidence": "96.04439735412598"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.16389584541321"}]}, "400": {"C": [{"result": "l", "confidence": "92.0781135559082"}, {"result": "l", "confidence": "90.21356105804443"}, {"result": "l", "confidence": "96.37677073478699"}, {"result": "l", "confidence": "97.27256298065186"}, {"result": "i", "confidence": "95.37464380264282"}], "L": [{"result": "i", "confidence": "88.92126679420471"}, {"result": "i", "confidence": "77.22364068031311"}, {"result": "l", "confidence": "59.46840047836304"}, {"result": "l", "confidence": "75.59521794319153"}, {"result": "i", "confidence": "58.22567343711853"}, {"result": "i", "confidence": "99.96726512908936"}, {"result": "i", "confidence": "99.37809109687805"}], "I": [{"result": "i", "confidence": "99.99814033508301"}, {"result": "c", "confidence": "98.54605793952942"}, {"result": "i", "confidence": "92.53442883491516"}, {"result": "i", "confidence": "99.99003410339355"}, {"result": "i", "confidence": "99.98971223831177"}, {"result": "i", "confidence": "96.41077518463135"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.9991774559021"}, {"result": "c", "confidence": "99.9972939491272"}, {"result": "c", "confidence": "99.9982237815857"}, {"result": "c", "confidence": "99.99456405639648"}, {"result": "c", "confidence": "100.0"}], "L": [{"result": "l", "confidence": "68.84782910346985"}, {"result": "c", "confidence": "96.42050266265869"}, {"result": "c", "confidence": "97.05550074577332"}, {"result": "i", "confidence": "52.54409909248352"}, {"result": "l", "confidence": "94.39217448234558"}, {"result": "c", "confidence": "99.7848629951477"}, {"result": "c", "confidence": "99.8353123664856"}], "I": [{"result": "i", "confidence": "98.44139814376831"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "i", "confidence": "97.25480079650879"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "c", "confidence": "98.82275462150574"}, {"result": "i", "confidence": "99.97692704200745"}]}, "400": {"C": [{"result": "l", "confidence": "78.46137285232544"}, {"result": "c", "confidence": "99.36375617980957"}, {"result": "c", "confidence": "99.99680519104004"}, {"result": "c", "confidence": "95.72116136550903"}, {"result": "c", "confidence": "99.64369535446167"}, {"result": "c", "confidence": "91.91946387290955"}], "L": [{"result": "l", "confidence": "77.79381275177002"}, {"result": "c", "confidence": "97.50154614448547"}, {"result": "l", "confidence": "87.3197615146637"}, {"result": "c", "confidence": "99.27393794059753"}, {"result": "i", "confidence": "97.71486520767212"}, {"result": "c", "confidence": "81.04536533355713"}, {"result": "l", "confidence": "60.83188056945801"}], "I": [{"result": "i", "confidence": "99.99903440475464"}, {"result": "i", "confidence": "70.42229175567627"}, {"result": "i", "confidence": "87.94270157814026"}, {"result": "i", "confidence": "99.96032118797302"}, {"result": "i", "confidence": "99.98877048492432"}, {"result": "i", "confidence": "99.98247027397156"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.38819655510472, "angulo_head": 127.44129155304869}], "10": [{"angulo_tronco": 70.77906003667363, "angulo_head": 131.00042408118185}], "20": [{"angulo_tronco": 57.60583765066129, "angulo_head": 140.06709181179076}], "30": [{"angulo_tronco": 60.19535077000784, "angulo_head": 29.920599020430547}], "40": [{"angulo_tronco": 56.24480752563044, "angulo_head": 28.22731600758698}], "50": [{"angulo_tronco": 67.53555231407402, "angulo_head": 155.057514704917}], "60": [{"angulo_tronco": 74.51596235725303, "angulo_head": 7.166561105017586}], "70": [{"angulo_tronco": 81.33439935639771, "angulo_head": 8.579844520467255}], "80": [{"angulo_tronco": 85.73984998627704, "angulo_head": 21.92021691961338}], "90": [{"angulo_tronco": 87.1502610798903, "angulo_head": 19.75188385946832}], "100": [{"angulo_tronco": 98.48002388285408, "angulo_head": 135.49075734999425}], "110": [{"angulo_tronco": 98.29411687609282, "angulo_head": 171.86283671693036}], "120": [{"angulo_tronco": 111.56389157015303, "angulo_head": 167.47857210062912}], "130": [{"angulo_tronco": 110.36458964682642, "angulo_head": 29.972255693330435}], "140": [{"angulo_tronco": 118.99434382577242, "angulo_head": 35.395899690493124}], "150": [{"angulo_tronco": 120.27762135834267, "angulo_head": 40.229227519720126}], "160": [{"angulo_tronco": 124.95506347615304, "angulo_head": 55.34853347990946}], "170": [{"angulo_tronco": 132.46617864941396, "angulo_head": 61.57306591844206}], "180": [{"angulo_tronco": 100.80897422522172, "angulo_head": 60.4187689213502}]}, "300": {"0": [{"angulo_tronco": 97.53410813492184, "angulo_head": 133.0558963867819}], "10": [{"angulo_tronco": 65.32151908233966, "angulo_head": 135.8104072418223}], "20": [{"angulo_tronco": 72.84299773455622, "angulo_head": 143.92997591031576}], "30": [{"angulo_tronco": 65.46572623467094, "angulo_head": 141.8856843766371}], "40": [{"angulo_tronco": 64.10125086244592, "angulo_head": 144.34124958981351}], "50": [{"angulo_tronco": 62.377907653323675, "angulo_head": 129.37093981154166}], "60": [{"angulo_tronco": 67.99576084147519, "angulo_head": 144.37224824073738}], "70": [{"angulo_tronco": 73.50736107405334, "angulo_head": 155.20393087233901}], "80": [{"angulo_tronco": 83.0742385427944, "angulo_head": 17.031067034597882}], "90": [{"angulo_tronco": 88.35566368208154, "angulo_head": 77.376166745577}], "100": [{"angulo_tronco": 97.05922599223484, "angulo_head": 170.31049114979913}], "110": [{"angulo_tronco": 94.50384852386594, "angulo_head": 29.72534118596905}], "120": [{"angulo_tronco": 101.40859194190388, "angulo_head": 14.865271183776114}], "130": [{"angulo_tronco": 104.06481707366316, "angulo_head": 47.11478855723276}], "140": [{"angulo_tronco": 106.662939190352, "angulo_head": 49.62913622168825}], "150": [{"angulo_tronco": 115.35023629585089, "angulo_head": 46.38057606422806}], "160": [{"angulo_tronco": 126.55420676738292, "angulo_head": 159.66531966135776}], "170": [{"angulo_tronco": 115.98112769827861, "angulo_head": 47.45396808683946}], "180": [{"angulo_tronco": 105.85593621585551, "angulo_head": 53.86559838841466}]}, "400": {"0": [{"angulo_tronco": 82.05898732730572, "angulo_head": 30.498893836229914}], "10": [{"angulo_tronco": 68.68700462384146, "angulo_head": 134.4867515340041}], "20": [{"angulo_tronco": 65.07554107429873, "angulo_head": 148.13884446146605}], "30": [{"angulo_tronco": 66.42898066230651, "angulo_head": 149.0107692119235}], "40": [{"angulo_tronco": 67.0242232742384, "angulo_head": 154.28434708344165}], "50": [{"angulo_tronco": 72.95650932396204, "angulo_head": 1.1695602934157865}], "60": [{"angulo_tronco": 83.27086699606261, "angulo_head": 131.02898030983334}], "70": [{"angulo_tronco": 82.51758736096635, "angulo_head": 7.482120558188608}], "80": [{"angulo_tronco": 75.21832647538717, "angulo_head": 31.175492845657566}], "90": [{"angulo_tronco": 93.1716033844731, "angulo_head": 52.29908626011}], "100": [{"angulo_tronco": 98.46185277714773, "angulo_head": 170.50827868599458}], "110": [{"angulo_tronco": 99.11416131463409, "angulo_head": 86.74821587737937}], "120": [{"angulo_tronco": 103.92872097904944, "angulo_head": 167.06111472095822}], "130": [{"angulo_tronco": 108.88092227663007, "angulo_head": 25.193955465040275}], "140": [{"angulo_tronco": 109.65870821778918, "angulo_head": 55.849274858185986}], "150": [{"angulo_tronco": 111.92409769713954, "angulo_head": 38.60032047017582}], "160": [{"angulo_tronco": 114.76813506226904, "angulo_head": 33.29651113250553}], "170": [{"angulo_tronco": 109.64372697083283, "angulo_head": 44.98012572167089}], "180": [{"angulo_tronco": 81.91624228879611, "angulo_head": 100.74186400988552}]}}, "centroide": {"200": [{"respuesta": 216.6416765561653}], "250": [{"respuesta": 259.13570642492425}], "300": [{"respuesta": 306.79338954523905}], "350": [{"respuesta": 342.6867186595623}], "400": [{"respuesta": 377.56072697972513}], "450": [{"respuesta": 415.0484119485136}], "500": [{"respuesta": 441.82398782947007}], "550": [{"respuesta": 477.6620112232532}], "600": [{"respuesta": 499.88258706392156}]}}

json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "99.7918426990509"}, {"result": "l", "confidence": "99.93430972099304"}, {"result": "l", "confidence": "99.93626475334167"}, {"result": "l", "confidence": "99.67965483665466"}, {"result": "c", "confidence": "98.77133369445801"}, {"result": "l", "confidence": "96.08646631240845"}, {"result": "l", "confidence": "99.70307350158691"}, {"result": "l", "confidence": "99.3213415145874"}], "L": [{"result": "l", "confidence": "97.95929193496704"}, {"result": "l", "confidence": "99.60184693336487"}, {"result": "i", "confidence": "54.99337911605835"}, {"result": "i", "confidence": "77.96856760978699"}, {"result": "i", "confidence": "99.91514682769775"}, {"result": "i", "confidence": "56.562042236328125"}, {"result": "i", "confidence": "99.19829964637756"}], "I": [{"result": "i", "confidence": "99.99771118164062"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.9987006187439"}, {"result": "i", "confidence": "99.99513626098633"}, {"result": "i", "confidence": "99.98878240585327"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.99922513961792"}]}, "400": {"C": [{"result": "l", "confidence": "96.66241407394409"}, {"result": "l", "confidence": "98.63150119781494"}, {"result": "l", "confidence": "98.64605665206909"}, {"result": "l", "confidence": "98.83607625961304"}, {"result": "i", "confidence": "89.94575142860413"}], "L": [{"result": "i", "confidence": "84.17730927467346"}, {"result": "i", "confidence": "71.803879737854"}, {"result": "l", "confidence": "80.74436783790588"}, {"result": "l", "confidence": "89.21656608581543"}, {"result": "l", "confidence": "52.49587893486023"}, {"result": "i", "confidence": "99.95794892311096"}, {"result": "i", "confidence": "98.83536100387573"}], "I": [{"result": "i", "confidence": "99.99960660934448"}, {"result": "i", "confidence": "99.99746084213257"}, {"result": "i", "confidence": "99.9887466430664"}, {"result": "i", "confidence": "99.99818801879883"}, {"result": "i", "confidence": "99.99659061431885"}, {"result": "i", "confidence": "99.996018409729"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.9991774559021"}, {"result": "c", "confidence": "99.84478950500488"}, {"result": "c", "confidence": "99.9886155128479"}, {"result": "c", "confidence": "99.98939037322998"}, {"result": "c", "confidence": "100.0"}], "L": [{"result": "l", "confidence": "73.81341457366943"}, {"result": "c", "confidence": "52.9876172542572"}, {"result": "c", "confidence": "71.6536283493042"}, {"result": "i", "confidence": "52.54409909248352"}, {"result": "l", "confidence": "99.31221604347229"}, {"result": "c", "confidence": "99.1144061088562"}, {"result": "c", "confidence": "97.5374162197113"}], "I": [{"result": "i", "confidence": "99.9990701675415"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "i", "confidence": "99.99903440475464"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "c", "confidence": "98.82275462150574"}, {"result": "i", "confidence": "99.99881982803345"}]}, "400": {"C": [{"result": "l", "confidence": "95.68471312522888"}, {"result": "c", "confidence": "92.70158410072327"}, {"result": "c", "confidence": "99.98952150344849"}, {"result": "c", "confidence": "91.73703789710999"}, {"result": "c", "confidence": "98.61830472946167"}, {"result": "c", "confidence": "86.40267848968506"}], "L": [{"result": "l", "confidence": "90.43501019477844"}, {"result": "l", "confidence": "66.11368656158447"}, {"result": "l", "confidence": "98.26091527938843"}, {"result": "c", "confidence": "50.4316508769989"}, {"result": "i", "confidence": "98.67225289344788"}, {"result": "l", "confidence": "90.22610783576965"}, {"result": "l", "confidence": "95.85312008857727"}], "I": [{"result": "i", "confidence": "99.99972581863403"}, {"result": "i", "confidence": "99.99634027481079"}, {"result": "i", "confidence": "99.99828338623047"}, {"result": "i", "confidence": "99.29503202438354"}, {"result": "i", "confidence": "99.99908208847046"}, {"result": "i", "confidence": "99.99817609786987"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.34580556533165, "angulo_head": 127.44540502217549}], "10": [{"angulo_tronco": 70.81070750335415, "angulo_head": 131.0375639794286}], "20": [{"angulo_tronco": 57.60420139183012, "angulo_head": 140.07805787880844}], "30": [{"angulo_tronco": 60.20761281118466, "angulo_head": 29.931720206660025}], "40": [{"angulo_tronco": 56.243474576747744, "angulo_head": 28.230804331762727}], "50": [{"angulo_tronco": 67.54148507256245, "angulo_head": 155.09466286317328}], "60": [{"angulo_tronco": 74.51318361371669, "angulo_head": 7.209363850603672}], "70": [{"angulo_tronco": 81.34056473439213, "angulo_head": 8.589627828357845}], "80": [{"angulo_tronco": 85.7238633459838, "angulo_head": 21.905899968308336}], "90": [{"angulo_tronco": 87.1341426915828, "angulo_head": 19.596566229887035}], "100": [{"angulo_tronco": 98.4840054342633, "angulo_head": 135.6428259613105}], "110": [{"angulo_tronco": 98.31548069352361, "angulo_head": 172.00994200359008}], "120": [{"angulo_tronco": 111.57744445953178, "angulo_head": 168.30772931943324}], "130": [{"angulo_tronco": 110.36379763890105, "angulo_head": 29.78280252610885}], "140": [{"angulo_tronco": 118.98645587413928, "angulo_head": 35.38214970595001}], "150": [{"angulo_tronco": 120.2916853147711, "angulo_head": 40.225950315996236}], "160": [{"angulo_tronco": 124.92892644138676, "angulo_head": 55.32022393593755}], "170": [{"angulo_tronco": 132.46907107412537, "angulo_head": 61.5692808031376}], "180": [{"angulo_tronco": 100.6584405395183, "angulo_head": 60.416341531041205}]}, "300": {"0": [{"angulo_tronco": 97.44982603072856, "angulo_head": 133.04883802590922}], "10": [{"angulo_tronco": 65.31508680463926, "angulo_head": 135.80036424065116}], "20": [{"angulo_tronco": 72.83805949723076, "angulo_head": 143.9337004183226}], "30": [{"angulo_tronco": 65.47773871491371, "angulo_head": 141.84273497103433}], "40": [{"angulo_tronco": 64.10491574891017, "angulo_head": 144.30638695690183}], "50": [{"angulo_tronco": 62.397459946997245, "angulo_head": 129.29654867148173}], "60": [{"angulo_tronco": 68.00163440815797, "angulo_head": 144.38056840074935}], "70": [{"angulo_tronco": 73.50198416827587, "angulo_head": 155.24206851320236}], "80": [{"angulo_tronco": 83.06762047455618, "angulo_head": 17.065137727666343}], "90": [{"angulo_tronco": 88.37416797192596, "angulo_head": 77.3535648603969}], "100": [{"angulo_tronco": 97.01509746137322, "angulo_head": 170.85576309672717}], "110": [{"angulo_tronco": 94.49001011972682, "angulo_head": 29.60244561549964}], "120": [{"angulo_tronco": 101.41009585681331, "angulo_head": 14.890105489205403}], "130": [{"angulo_tronco": 104.05701942327494, "angulo_head": 47.13429342453116}], "140": [{"angulo_tronco": 106.65350154457744, "angulo_head": 49.60591091135091}], "150": [{"angulo_tronco": 115.32443628493007, "angulo_head": 46.352868842110375}], "160": [{"angulo_tronco": 126.32024782462655, "angulo_head": 160.04606127223772}], "170": [{"angulo_tronco": 115.98186284598376, "angulo_head": 47.43869698859744}], "180": [{"angulo_tronco": 105.91003891137764, "angulo_head": 53.83246794021045}]}, "400": {"0": [{"angulo_tronco": 82.27876266525891, "angulo_head": 30.45780872318533}], "10": [{"angulo_tronco": 68.74354691790691, "angulo_head": 134.4779403195826}], "20": [{"angulo_tronco": 65.02807336474453, "angulo_head": 148.10925586600555}], "30": [{"angulo_tronco": 66.48844247953741, "angulo_head": 149.01166588399863}], "40": [{"angulo_tronco": 67.02069792422216, "angulo_head": 154.16444092808936}], "50": [{"angulo_tronco": 72.92219786518156, "angulo_head": 0.9488441877415317}], "60": [{"angulo_tronco": 83.47285400783035, "angulo_head": 130.54443581747327}], "70": [{"angulo_tronco": 82.53771737818471, "angulo_head": 171.80755025617705}], "80": [{"angulo_tronco": 75.17336401097074, "angulo_head": 31.102896447827373}], "90": [{"angulo_tronco": 93.22146093166648, "angulo_head": 52.387613383364474}], "100": [{"angulo_tronco": 98.57466825867533, "angulo_head": 169.43906451293392}], "110": [{"angulo_tronco": 99.08312820193747, "angulo_head": 86.77147526839696}], "120": [{"angulo_tronco": 103.90951387222907, "angulo_head": 166.8955715802933}], "130": [{"angulo_tronco": 108.86674748583687, "angulo_head": 25.123419682229716}], "140": [{"angulo_tronco": 109.68515081464705, "angulo_head": 56.07892309703602}], "150": [{"angulo_tronco": 111.85793107042194, "angulo_head": 38.43152658201716}], "160": [{"angulo_tronco": 114.70513550573423, "angulo_head": 33.320308439539026}], "170": [{"angulo_tronco": 109.5727214815635, "angulo_head": 45.014688958782465}], "180": [{"angulo_tronco": 81.91171178860041, "angulo_head": 100.73752087493972}]}}, "centroide": {"200": [{"respuesta": 216.64052277163808}], "250": [{"respuesta": 259.14082667208527}], "300": [{"respuesta": 306.79679658510435}], "350": [{"respuesta": 342.6899127603548}], "400": [{"respuesta": 377.55673136661574}], "450": [{"respuesta": 415.0313527789773}], "500": [{"respuesta": 441.81683183965595}], "550": [{"respuesta": 477.65313967526095}], "600": [{"respuesta": 499.8810259962649}]}}

# Modelo V3
json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "99.7918426990509"}, {"result": "l", "confidence": "99.93430972099304"}, {"result": "l", "confidence": "99.93626475334167"}, {"result": "l", "confidence": "99.67965483665466"}, {"result": "c", "confidence": "98.77133369445801"}, {"result": "l", "confidence": "96.08646631240845"}, {"result": "l", "confidence": "99.70307350158691"}, {"result": "l", "confidence": "99.3213415145874"}], "L": [{"result": "l", "confidence": "97.95929193496704"}, {"result": "l", "confidence": "99.60184693336487"}, {"result": "i", "confidence": "54.99337911605835"}, {"result": "i", "confidence": "77.96856760978699"}, {"result": "i", "confidence": "99.91514682769775"}, {"result": "i", "confidence": "56.562042236328125"}, {"result": "i", "confidence": "99.19829964637756"}], "I": [{"result": "i", "confidence": "99.99771118164062"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.9987006187439"}, {"result": "i", "confidence": "99.99513626098633"}, {"result": "i", "confidence": "99.98878240585327"}, {"result": "i", "confidence": "99.99892711639404"}, {"result": "i", "confidence": "99.99922513961792"}]}, "400": {"C": [{"result": "l", "confidence": "96.66241407394409"}, {"result": "l", "confidence": "98.63150119781494"}, {"result": "l", "confidence": "98.64605665206909"}, {"result": "l", "confidence": "98.83607625961304"}, {"result": "i", "confidence": "89.94575142860413"}], "L": [{"result": "i", "confidence": "84.17730927467346"}, {"result": "i", "confidence": "71.803879737854"}, {"result": "l", "confidence": "80.74436783790588"}, {"result": "l", "confidence": "89.21656608581543"}, {"result": "l", "confidence": "52.49587893486023"}, {"result": "i", "confidence": "99.95794892311096"}, {"result": "i", "confidence": "98.83536100387573"}], "I": [{"result": "i", "confidence": "99.99960660934448"}, {"result": "i", "confidence": "99.99746084213257"}, {"result": "i", "confidence": "99.9887466430664"}, {"result": "i", "confidence": "99.99818801879883"}, {"result": "i", "confidence": "99.99659061431885"}, {"result": "i", "confidence": "99.996018409729"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.9991774559021"}, {"result": "c", "confidence": "99.84478950500488"}, {"result": "c", "confidence": "99.9886155128479"}, {"result": "c", "confidence": "99.98939037322998"}, {"result": "c", "confidence": "100.0"}], "L": [{"result": "l", "confidence": "73.81341457366943"}, {"result": "c", "confidence": "52.9876172542572"}, {"result": "c", "confidence": "71.6536283493042"}, {"result": "i", "confidence": "52.54409909248352"}, {"result": "l", "confidence": "99.31221604347229"}, {"result": "c", "confidence": "99.1144061088562"}, {"result": "c", "confidence": "97.5374162197113"}], "I": [{"result": "i", "confidence": "99.9990701675415"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "i", "confidence": "99.99903440475464"}, {"result": "i", "confidence": "99.99998807907104"}, {"result": "c", "confidence": "98.82275462150574"}, {"result": "i", "confidence": "99.99881982803345"}]}, "400": {"C": [{"result": "l", "confidence": "95.68471312522888"}, {"result": "c", "confidence": "92.70158410072327"}, {"result": "c", "confidence": "99.98952150344849"}, {"result": "c", "confidence": "91.73703789710999"}, {"result": "c", "confidence": "98.61830472946167"}, {"result": "c", "confidence": "86.40267848968506"}], "L": [{"result": "l", "confidence": "90.43501019477844"}, {"result": "l", "confidence": "66.11368656158447"}, {"result": "l", "confidence": "98.26091527938843"}, {"result": "c", "confidence": "50.4316508769989"}, {"result": "i", "confidence": "98.67225289344788"}, {"result": "l", "confidence": "90.22610783576965"}, {"result": "l", "confidence": "95.85312008857727"}], "I": [{"result": "i", "confidence": "99.99972581863403"}, {"result": "i", "confidence": "99.99634027481079"}, {"result": "i", "confidence": "99.99828338623047"}, {"result": "i", "confidence": "99.29503202438354"}, {"result": "i", "confidence": "99.99908208847046"}, {"result": "i", "confidence": "99.99817609786987"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.32965460772939, "angulo_head": 127.47075067998735}], "10": [{"angulo_tronco": 70.77786769783293, "angulo_head": 131.02313889147112}], "20": [{"angulo_tronco": 57.608675288835684, "angulo_head": 140.05403115224064}], "30": [{"angulo_tronco": 60.203914669104904, "angulo_head": 29.914304030342947}], "40": [{"angulo_tronco": 56.247361194958195, "angulo_head": 28.232711808443856}], "50": [{"angulo_tronco": 67.53922454689254, "angulo_head": 155.15082010919787}], "60": [{"angulo_tronco": 74.51609474155677, "angulo_head": 7.151734866267172}], "70": [{"angulo_tronco": 81.34170288107919, "angulo_head": 8.565042807067018}], "80": [{"angulo_tronco": 85.72069158254745, "angulo_head": 21.893893225185536}], "90": [{"angulo_tronco": 87.13095444884867, "angulo_head": 19.443690188336156}], "100": [{"angulo_tronco": 98.47468749960805, "angulo_head": 135.64768141926154}], "110": [{"angulo_tronco": 98.29810951578189, "angulo_head": 171.64073328402705}], "120": [{"angulo_tronco": 111.56550078913884, "angulo_head": 167.67391996704464}], "130": [{"angulo_tronco": 110.36892783786732, "angulo_head": 29.836186137698625}], "140": [{"angulo_tronco": 118.99615339483152, "angulo_head": 35.383594683241924}], "150": [{"angulo_tronco": 120.28370315695626, "angulo_head": 40.253751438048816}], "160": [{"angulo_tronco": 124.94553441918491, "angulo_head": 55.332527272151076}], "170": [{"angulo_tronco": 132.4768636066167, "angulo_head": 61.564786289992846}], "180": [{"angulo_tronco": 100.65463108748786, "angulo_head": 60.428213027992506}]}, "300": {"0": [{"angulo_tronco": 97.54456573894394, "angulo_head": 133.05497293702723}], "10": [{"angulo_tronco": 65.30531911145587, "angulo_head": 135.79276407182894}], "20": [{"angulo_tronco": 72.88827483628732, "angulo_head": 143.93233044076317}], "30": [{"angulo_tronco": 65.48732514091387, "angulo_head": 141.91916992103347}], "40": [{"angulo_tronco": 64.12724325935736, "angulo_head": 144.3371234298573}], "50": [{"angulo_tronco": 62.35862552051582, "angulo_head": 129.3531772407472}], "60": [{"angulo_tronco": 67.98628589077427, "angulo_head": 144.27968315435416}], "70": [{"angulo_tronco": 73.50916405243335, "angulo_head": 155.297870065497}], "80": [{"angulo_tronco": 83.07631606092643, "angulo_head": 17.07625886435563}], "90": [{"angulo_tronco": 88.3643745810826, "angulo_head": 77.37024696030879}], "100": [{"angulo_tronco": 97.02772702656395, "angulo_head": 170.90757073695292}], "110": [{"angulo_tronco": 94.51297913501014, "angulo_head": 29.654796585529546}], "120": [{"angulo_tronco": 101.4237574903347, "angulo_head": 14.771258832275903}], "130": [{"angulo_tronco": 104.02024315709959, "angulo_head": 47.268072557494015}], "140": [{"angulo_tronco": 106.67427093499775, "angulo_head": 49.68121467846586}], "150": [{"angulo_tronco": 115.23483778681111, "angulo_head": 46.432222193519145}], "160": [{"angulo_tronco": 126.29118691732745, "angulo_head": 160.11263772832098}], "170": [{"angulo_tronco": 115.94368658514433, "angulo_head": 47.42101421624475}], "180": [{"angulo_tronco": 106.03598368775079, "angulo_head": 53.85350875965651}]}, "400": {"0": [{"angulo_tronco": 82.52979142378516, "angulo_head": 30.476166008233616}], "10": [{"angulo_tronco": 67.21453616522244, "angulo_head": 134.4877683078118}], "20": [{"angulo_tronco": 64.98215442798264, "angulo_head": 148.08062097264153}], "30": [{"angulo_tronco": 66.45226310752112, "angulo_head": 149.00051451353383}], "40": [{"angulo_tronco": 67.03118901939392, "angulo_head": 154.19250196268476}], "50": [{"angulo_tronco": 72.9268478271812, "angulo_head": 0.8824572639279504}], "60": [{"angulo_tronco": 83.25584484029895, "angulo_head": 130.89537341644905}], "70": [{"angulo_tronco": 82.55367698796151, "angulo_head": 172.2560395779073}], "80": [{"angulo_tronco": 75.19914830578756, "angulo_head": 31.17638859625937}], "90": [{"angulo_tronco": 93.25825692721537, "angulo_head": 52.55451457838398}], "100": [{"angulo_tronco": 98.56742503297421, "angulo_head": 169.9933546657725}], "110": [{"angulo_tronco": 99.07604202100234, "angulo_head": 86.77873047788134}], "120": [{"angulo_tronco": 103.9474321958225, "angulo_head": 167.06956477852717}], "130": [{"angulo_tronco": 108.90324137255699, "angulo_head": 25.092433994943292}], "140": [{"angulo_tronco": 109.59264147945004, "angulo_head": 56.02353263902335}], "150": [{"angulo_tronco": 111.86587991574164, "angulo_head": 38.739278314283226}], "160": [{"angulo_tronco": 114.52752533406539, "angulo_head": 33.31947007156306}], "170": [{"angulo_tronco": 109.63150227418039, "angulo_head": 45.00296077609751}], "180": [{"angulo_tronco": 81.8702816293253, "angulo_head": 100.73813273670444}]}}, "centroide": {"200": [{"respuesta": 216.6406172471944}], "250": [{"respuesta": 259.1404142723207}], "300": [{"respuesta": 306.79371977789975}], "350": [{"respuesta": 342.68566568203147}], "400": [{"respuesta": 377.5649198151008}], "450": [{"respuesta": 415.0422711999671}], "500": [{"respuesta": 441.8118592698195}], "550": [{"respuesta": 477.6980769737864}], "600": [{"respuesta": 499.88955776461887}]}, "height_167": {"200": [{"respuesta": 179.4245907184716}], "250": [{"respuesta": 173.59138885683976}], "300": [{"respuesta": 166.9855188105557}], "350": [{"respuesta": 158.13720778898795}], "400": [{"respuesta": 152.08905925438975}], "450": [{"respuesta": 147.33212951707762}], "500": [{"respuesta": 145.056895938686}], "550": [{"respuesta": 137.887713778874}], "600": [{"respuesta": 133.66581849937086}]}}

# Modelo V4
json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "l", "confidence": "94.90298628807068"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.68764781951904"}, {"result": "i", "confidence": "54.89735007286072"}, {"result": "l", "confidence": "51.197320222854614"}, {"result": "i", "confidence": "75.51838755607605"}]}, "400": {"C": [{"result": "c", "confidence": "99.89907145500183"}, {"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.69454407691956"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "l", "confidence": "87.46050596237183"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "82.42610096931458"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "96.72553539276123"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "c", "confidence": "99.52154159545898"}, {"result": "i", "confidence": "99.83118772506714"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "99.97468590736389"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "88.83863687515259"}, {"result": "i", "confidence": "99.65736865997314"}, {"result": "i", "confidence": "99.60086345672607"}, {"result": "l", "confidence": "78.88910174369812"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.345906748076736, "angulo_head": 127.47311575074166}], "10": [{"angulo_tronco": 70.80676610865237, "angulo_head": 131.00679114875967}], "20": [{"angulo_tronco": 57.603759198752044, "angulo_head": 140.06083823431155}], "30": [{"angulo_tronco": 60.20950445633049, "angulo_head": 29.878553204347995}], "40": [{"angulo_tronco": 56.237923760982746, "angulo_head": 28.22949818858889}], "50": [{"angulo_tronco": 67.54376275291575, "angulo_head": 155.1118484875054}], "60": [{"angulo_tronco": 74.51035326060442, "angulo_head": 7.115080196665964}], "70": [{"angulo_tronco": 81.33794598640728, "angulo_head": 8.624403538089476}], "80": [{"angulo_tronco": 85.73281823195359, "angulo_head": 21.928623491998188}], "90": [{"angulo_tronco": 87.14317671618294, "angulo_head": 19.510783848540182}], "100": [{"angulo_tronco": 98.48962868098918, "angulo_head": 135.60744931728144}], "110": [{"angulo_tronco": 98.30017454016831, "angulo_head": 171.4489167946555}], "120": [{"angulo_tronco": 111.57018279088534, "angulo_head": 167.88013863001797}], "130": [{"angulo_tronco": 110.3593524432353, "angulo_head": 30.298190967954692}], "140": [{"angulo_tronco": 118.98651695388573, "angulo_head": 35.367698979356845}], "150": [{"angulo_tronco": 120.28156368302086, "angulo_head": 40.25183099839206}], "160": [{"angulo_tronco": 124.92814086648369, "angulo_head": 55.35235562124311}], "170": [{"angulo_tronco": 132.47415974494635, "angulo_head": 61.560282685166065}], "180": [{"angulo_tronco": 100.8463930153738, "angulo_head": 60.42179183813872}]}, "300": {"0": [{"angulo_tronco": 97.48737198738212, "angulo_head": 133.03829890397648}], "10": [{"angulo_tronco": 65.38271748862483, "angulo_head": 135.796573527078}], "20": [{"angulo_tronco": 72.88802301390557, "angulo_head": 143.94731727182443}], "30": [{"angulo_tronco": 65.46105284588995, "angulo_head": 141.89542154996533}], "40": [{"angulo_tronco": 64.09032507080843, "angulo_head": 144.29890448292534}], "50": [{"angulo_tronco": 62.36018254006163, "angulo_head": 129.3454226192008}], "60": [{"angulo_tronco": 68.01342592969466, "angulo_head": 144.38175312319657}], "70": [{"angulo_tronco": 73.49998713248401, "angulo_head": 155.19726567130846}], "80": [{"angulo_tronco": 83.06025363173111, "angulo_head": 17.093361233463973}], "90": [{"angulo_tronco": 88.37367670902056, "angulo_head": 77.32650072084634}], "100": [{"angulo_tronco": 97.07107851479599, "angulo_head": 170.43548915734524}], "110": [{"angulo_tronco": 94.51588931811686, "angulo_head": 29.70331747437123}], "120": [{"angulo_tronco": 101.4109504988567, "angulo_head": 14.896702738951877}], "130": [{"angulo_tronco": 104.03334658215836, "angulo_head": 47.1588764025633}], "140": [{"angulo_tronco": 106.63792630121435, "angulo_head": 49.75073650232904}], "150": [{"angulo_tronco": 115.2188147602646, "angulo_head": 46.37448401496871}], "160": [{"angulo_tronco": 126.54271290508325, "angulo_head": 159.67829716494018}], "170": [{"angulo_tronco": 115.98815469230298, "angulo_head": 47.483184442584104}], "180": [{"angulo_tronco": 105.86504815446173, "angulo_head": 53.84298410537096}]}, "400": {"0": [{"angulo_tronco": 82.67809066787643, "angulo_head": 30.442767035671068}], "10": [{"angulo_tronco": 69.77970790975299, "angulo_head": 134.5062093598137}], "20": [{"angulo_tronco": 65.07375999739244, "angulo_head": 148.04306511996023}], "30": [{"angulo_tronco": 66.39992601956085, "angulo_head": 149.01427340441504}], "40": [{"angulo_tronco": 66.98890795996705, "angulo_head": 154.05742373882595}], "50": [{"angulo_tronco": 72.93279974631967, "angulo_head": 0.9670364415193756}], "60": [{"angulo_tronco": 83.46288261430853, "angulo_head": 130.61719584547734}], "70": [{"angulo_tronco": 82.5042190649513, "angulo_head": 172.27011813554677}], "80": [{"angulo_tronco": 75.19726619723816, "angulo_head": 31.1159380616428}], "90": [{"angulo_tronco": 93.14635295245868, "angulo_head": 52.53829235992687}], "100": [{"angulo_tronco": 98.52121841876294, "angulo_head": 168.87074120259882}], "110": [{"angulo_tronco": 99.09061022307259, "angulo_head": 86.76423774933052}], "120": [{"angulo_tronco": 103.87818946089003, "angulo_head": 166.9783511162742}], "130": [{"angulo_tronco": 108.87163909692147, "angulo_head": 25.148328103075826}], "140": [{"angulo_tronco": 109.59440594287553, "angulo_head": 55.882790406350196}], "150": [{"angulo_tronco": 111.7877258646999, "angulo_head": 38.66931432657693}], "160": [{"angulo_tronco": 114.70074509418875, "angulo_head": 33.34778514320098}], "170": [{"angulo_tronco": 109.83628867553537, "angulo_head": 45.004602900519295}], "180": [{"angulo_tronco": 81.71606979803676, "angulo_head": 100.73982100568132}]}}, "centroide": {"200": [{"respuesta": 216.64195443337394}], "250": [{"respuesta": 259.13935902799744}], "300": [{"respuesta": 306.79286763904537}], "350": [{"respuesta": 342.68532637336835}], "400": [{"respuesta": 377.5630351140951}], "450": [{"respuesta": 415.0409028466161}], "500": [{"respuesta": 441.81015778664676}], "550": [{"respuesta": 477.69722797785283}], "600": [{"respuesta": 499.8880379517359}]}, "height_167": {"200": [{"respuesta": 179.42339826091722}], "250": [{"respuesta": 173.5946622937641}], "300": [{"respuesta": 166.98554771732393}], "350": [{"respuesta": 158.0948933008692}], "400": [{"respuesta": 152.0810118961565}], "450": [{"respuesta": 147.33341891101634}], "500": [{"respuesta": 145.0176223953738}], "550": [{"respuesta": 137.89063627737525}], "600": [{"respuesta": 133.60844266865558}]}}

# %% [markdown]
# # Formas

# %%
val_formas = json["formas"]

# %%
data = []
for key2, value2 in val_formas["3"]["300"].items():
    for i in value2:
        data.append([key2, i["result"], i["confidence"]])
df_formas_3_300 = pd.DataFrame(data, columns=["forma", "result", "confidence"])

data = []
for key2, value2 in val_formas["3"]["400"].items():
    for i in value2:
        data.append([key2, i["result"], i["confidence"]])
df_formas_3_400 = pd.DataFrame(data, columns=["forma", "result", "confidence"])

data = []
for key2, value2 in val_formas["4"]["300"].items():
    for i in value2:
        data.append([key2, i["result"], i["confidence"]])
df_formas_4_300 = pd.DataFrame(data, columns=["forma", "result", "confidence"])

data = []
for key2, value2 in val_formas["4"]["400"].items():
    for i in value2:
        data.append([key2, i["result"], i["confidence"]])
df_formas_4_400 = pd.DataFrame(data, columns=["forma", "result", "confidence"])

# %%
val_formas["4"]["400"]
# Out:
# {'C': [{'result': 'c', 'confidence': '54.35415506362915'},
#   {'result': 'c', 'confidence': '99.97468590736389'},
#   {'result': 'c', 'confidence': '99.9851942062378'},
#   {'result': 'c', 'confidence': '99.97286200523376'},
#   {'result': 'c', 'confidence': '99.98914003372192'},
#   {'result': 'c', 'confidence': '99.97867941856384'}],
#  'L': [{'result': 'l', 'confidence': '97.13733196258545'},
#   {'result': 'c', 'confidence': '91.54804944992065'},
#   {'result': 'l', 'confidence': '96.16655707359314'},
#   {'result': 'c', 'confidence': '95.46051621437073'},
#   {'result': 'l', 'confidence': '99.33972358703613'},
#   {'result': 'c', 'confidence': '91.21657013893127'},
#   {'result': 'l', 'confidence': '97.19358086585999'}],
#  'I': [{'result': 'i', 'confidence': '99.8841941356659'},
#   {'result': 'i', 'confidence': '97.84833192825317'},
#   {'result': 'i', 'confidence': '88.83863687515259'},
#   {'result': 'i', 'confidence': '99.65736865997314'},
# ...

# %%
df_formas_3_300_L = df_formas_3_300.copy()
df_formas_3_300_L["forma"] = df_formas_3_300_L["forma"].replace("C", "L")
df_formas_3_300_L["result"] = df_formas_3_300_L["result"].replace("c", "l")
df_formas_3_300_L
# Out:
#    forma result          confidence
# 0      L      l   94.66618299484253
# 1      L      l   97.70745635032654
# 2      L      l   92.57453083992004
# 3      L      l    98.7033486366272
# 4      L      l   99.95419979095459
# 5      L      l   99.55000281333923
# 6      L      l   89.43145871162415
# 7      L      l   70.10448575019836
# 8      L      l   99.42315816879272
# 9      L      l   97.83556461334229
# 10     L      l   99.25950169563293
# 11     L      l   99.22016859054565
# 12     L      l   92.49844551086426
# 13     L      l   99.59307312965393
# 14     L      l   97.59870767593384
# 15     I      l   94.90298628807068
# 16     I      i   99.63322281837463
# 17     I      i   99.30071830749512
# 18     I      i   99.68764781951904
# 19     I      i   54.89735007286072
# 20     I      l  51.197320222854614
# 21     I      i   75.51838755607605

# %%
# matriz de confunsión con df_formas_3_300
confusion_matrix = pd.crosstab(df_formas_3_300["forma"], df_formas_3_300["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  c  i  l
# forma
# C       6  0  2
# I       0  5  2
# L       0  0  7

# %%
# cambiar de C a L en df_formas_3_300_L
confusion_matrix = pd.crosstab(df_formas_3_300_L["forma"], df_formas_3_300_L["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  i   l
# forma
# I       5   2
# L       0  15

# %%
df_formas_3_400_L = df_formas_3_400.copy()
df_formas_3_400_L["forma"] = df_formas_3_400_L["forma"].replace("C", "L")
df_formas_3_400_L["result"] = df_formas_3_400_L["result"].replace("c", "l")
df_formas_3_400_L
# Out:
#    forma result         confidence
# 0      L      l  99.89907145500183
# 1      L      l  99.25323128700256
# 2      L      l  99.59290623664856
# 3      L      l  96.79073095321655
# 4      L      l  97.28830456733704
# 5      L      l  99.23157691955566
# 6      L      l  99.23850297927856
# 7      L      l  98.85578155517578
# 8      L      l   97.6033866405487
# 9      L      l  99.13877844810486
# 10     L      l   97.0491111278534
# 11     L      l  99.13724660873413
# 12     I      i  83.18315148353577
# 13     I      i  94.77227926254272
# 14     I      i  99.69454407691956
# 15     I      i  99.94762539863586
# 16     I      l  87.46050596237183
# 17     I      i   99.9307632446289

# %%
confusion_matrix = pd.crosstab(df_formas_3_400["forma"], df_formas_3_400["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  c  i  l
# forma
# C       3  0  2
# I       0  5  1
# L       0  0  7

# %%
confusion_matrix = pd.crosstab(df_formas_3_400_L["forma"], df_formas_3_400_L["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  i   l
# forma
# I       5   1
# L       0  12

# %%
df_formas_4_300_C = df_formas_4_300.copy()
df_formas_4_300_C["forma"] = df_formas_4_300_C["forma"].replace("L", "C")
df_formas_4_300_C["result"] = df_formas_4_300_C["result"].replace("l", "c")
df_formas_4_300_C
# Out:
#    forma result         confidence
# 0      C      c  99.99717473983765
# 1      C      c  99.98743534088135
# 2      C      c   99.9535322189331
# 3      C      c  99.99730587005615
# 4      C      c  99.99983310699463
# 5      C      c  94.98176574707031
# 6      C      c  94.83665823936462
# 7      C      c  97.92482852935791
# 8      C      c  98.82170557975769
# 9      C      c  97.99842238426208
# 10     C      c  99.27946925163269
# 11     C      c  66.54711365699768
# 12     I      i  82.42610096931458
# 13     I      i  99.74244832992554
# 14     I      i  96.72553539276123
# 15     I      i  99.92966651916504
# 16     I      c  99.52154159545898
# 17     I      i  99.83118772506714

# %%
confusion_matrix = pd.crosstab(df_formas_4_300["forma"], df_formas_4_300["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  c  i  l
# forma
# C       5  0  0
# I       1  5  0
# L       5  0  2

# %%
confusion_matrix = pd.crosstab(df_formas_4_300_C["forma"], df_formas_4_300_C["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result   c  i
# forma
# C       12  0
# I        1  5

# %%
df_formas_4_400_C = df_formas_4_400.copy()
df_formas_4_400_C["forma"] = df_formas_4_400_C["forma"].replace("L", "C")
df_formas_4_400_C["result"] = df_formas_4_400_C["result"].replace("l", "c")
df_formas_4_400_C
# Out:
#    forma result         confidence
# 0      C      c  54.35415506362915
# 1      C      c  99.97468590736389
# 2      C      c   99.9851942062378
# 3      C      c  99.97286200523376
# 4      C      c  99.98914003372192
# 5      C      c  99.97867941856384
# 6      C      c  97.13733196258545
# 7      C      c  91.54804944992065
# 8      C      c  96.16655707359314
# 9      C      c  95.46051621437073
# 10     C      c  99.33972358703613
# 11     C      c  91.21657013893127
# 12     C      c  97.19358086585999
# 13     I      i   99.8841941356659
# 14     I      i  97.84833192825317
# 15     I      i  88.83863687515259
# 16     I      i  99.65736865997314
# 17     I      i  99.60086345672607
# 18     I      c  78.88910174369812

# %%
confusion_matrix = pd.crosstab(df_formas_4_400["forma"], df_formas_4_400["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  c  i  l
# forma
# C       6  0  0
# I       0  5  1
# L       3  0  4

# %%
confusion_matrix = pd.crosstab(df_formas_4_400_C["forma"], df_formas_4_400_C["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result   c  i
# forma
# C       13  0
# I        1  5

# %% [markdown]
# # Centroide

# %%
val_centroides = json["centroide"]

# %%
data = []

for key, value in val_centroides.items():
    data.append([key, value[0]["respuesta"]])

df_centroides = pd.DataFrame(data, columns=["centroide", "respuesta"])

# %%
df_centroides
# Out:
#   centroide   respuesta
# 0       200  216.641954
# 1       250  259.139359
# 2       300  306.792868
# 3       350  342.685326
# 4       400  377.563035
# 5       450  415.040903
# 6       500  441.810158
# 7       550  477.697228
# 8       600  499.888038

# %%
# margen de error de centroide con respuesta de df_centroides
df_centroides["error"] = df_centroides["respuesta"] - df_centroides["centroide"].astype(int)
df_centroides
# Out:
#   centroide   respuesta       error
# 0       200  216.641954   16.641954
# 1       250  259.139359    9.139359
# 2       300  306.792868    6.792868
# 3       350  342.685326   -7.314674
# 4       400  377.563035  -22.436965
# 5       450  415.040903  -34.959097
# 6       500  441.810158  -58.189842
# 7       550  477.697228  -72.302772
# 8       600  499.888038 -100.111962

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_centroides.index, df_centroides["centroide"].astype(int), label='Centroide', marker='o')
ax.plot(df_centroides.index, df_centroides["respuesta"], label='Centroide estimado', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Centroide y Centroide estimado')
ax.set_xlabel('Índice')
ax.set_ylabel('Centroide (cm)')

# Añadir una leyenda
ax.legend()

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# # Orientacion

# %%
val_orientacion = json["orientacion"]

# %%
data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["200"].keys():
    data.append({"angulo": key, "angulo_tronco": val_orientacion["200"][key][0]["angulo_tronco"]})#, "angulo_head": val_orientacion["300"][key][0]["angulo_head"]})

df_orientaciones_200 = pd.DataFrame(data)

data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["300"].keys():
    data.append({"angulo": key, "angulo_tronco": val_orientacion["300"][key][0]["angulo_tronco"]})#, "angulo_head": val_orientacion["300"][key][0]["angulo_head"]})

df_orientaciones_300 = pd.DataFrame(data)

data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["400"].keys():
    data.append({"angulo": key, "angulo_tronco": val_orientacion["400"][key][0]["angulo_tronco"]})#, "angulo_head": val_orientacion["300"][key][0]["angulo_head"]})

df_orientaciones_400 = pd.DataFrame(data)

# %%
df_orientaciones_200
# Out:
#    angulo  angulo_tronco
# 0       0      61.345907
# 1      10      70.806766
# 2      20      57.603759
# 3      30      60.209504
# 4      40      56.237924
# 5      50      67.543763
# 6      60      74.510353
# 7      70      81.337946
# 8      80      85.732818
# 9      90      87.143177
# 10    100      98.489629
# 11    110      98.300175
# 12    120     111.570183
# 13    130     110.359352
# 14    140     118.986517
# 15    150     120.281564
# 16    160     124.928141
# 17    170     132.474160
# 18    180     100.846393

# %%
df_orientaciones_200["error"] = df_orientaciones_200["angulo_tronco"] - df_orientaciones_200["angulo"].astype(int)
df_orientaciones_200
# Out:
#    angulo  angulo_tronco      error
# 0       0      61.345907  61.345907
# 1      10      70.806766  60.806766
# 2      20      57.603759  37.603759
# 3      30      60.209504  30.209504
# 4      40      56.237924  16.237924
# 5      50      67.543763  17.543763
# 6      60      74.510353  14.510353
# 7      70      81.337946  11.337946
# 8      80      85.732818   5.732818
# 9      90      87.143177  -2.856823
# 10    100      98.489629  -1.510371
# 11    110      98.300175 -11.699825
# 12    120     111.570183  -8.429817
# 13    130     110.359352 -19.640648
# 14    140     118.986517 -21.013483
# 15    150     120.281564 -29.718436
# 16    160     124.928141 -35.071859
# 17    170     132.474160 -37.525840
# 18    180     100.846393 -79.153607

# %%
# grafica el angulo de Y, con valores en x de los indices de df_orientaciones_200
# plt.plot(df_orientaciones_200["angulo_tronco"])
# plt.plot(df_orientaciones_200["angulo"].astype(int))

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_200.index, df_orientaciones_200["angulo"].astype(int), label='Ángulo', marker='o')
ax.plot(df_orientaciones_200.index, df_orientaciones_200["angulo_tronco"], label='Ángulo estimado', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Ángulo y Ángulo estimado')
ax.set_xlabel('Índice')
ax.set_ylabel('Ángulo (grados)')

# Añadir una leyenda
ax.legend()

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
df_orientaciones_300# , df_orientaciones_300.dtypes
# Out:
#    angulo  angulo_tronco
# 0       0      97.487372
# 1      10      65.382717
# 2      20      72.888023
# 3      30      65.461053
# 4      40      64.090325
# 5      50      62.360183
# 6      60      68.013426
# 7      70      73.499987
# 8      80      83.060254
# 9      90      88.373677
# 10    100      97.071079
# 11    110      94.515889
# 12    120     101.410950
# 13    130     104.033347
# 14    140     106.637926
# 15    150     115.218815
# 16    160     126.542713
# 17    170     115.988155
# 18    180     105.865048

# %%
df_orientaciones_300["error"] = df_orientaciones_300["angulo_tronco"] - df_orientaciones_300["angulo"].astype(int)
df_orientaciones_300
# Out:
#    angulo  angulo_tronco      error
# 0       0      97.487372  97.487372
# 1      10      65.382717  55.382717
# 2      20      72.888023  52.888023
# 3      30      65.461053  35.461053
# 4      40      64.090325  24.090325
# 5      50      62.360183  12.360183
# 6      60      68.013426   8.013426
# 7      70      73.499987   3.499987
# 8      80      83.060254   3.060254
# 9      90      88.373677  -1.626323
# 10    100      97.071079  -2.928921
# 11    110      94.515889 -15.484111
# 12    120     101.410950 -18.589050
# 13    130     104.033347 -25.966653
# 14    140     106.637926 -33.362074
# 15    150     115.218815 -34.781185
# 16    160     126.542713 -33.457287
# 17    170     115.988155 -54.011845
# 18    180     105.865048 -74.134952

# %%
# grafica el angulo de Y, con valores en x de los indices de df_orientaciones_300
# plt.plot(df_orientaciones_300["angulo_tronco"])
# plt.plot(df_orientaciones_300["angulo"].astype(int))

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_300.index, df_orientaciones_300["angulo"].astype(int), label='Ángulo', marker='o')
ax.plot(df_orientaciones_300.index, df_orientaciones_300["angulo_tronco"], label='Ángulo estimado', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Ángulo y Ángulo estimado')
ax.set_xlabel('Índice')
ax.set_ylabel('Ángulo (grados)')

# Añadir una leyenda
ax.legend()

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
df_orientaciones_400
# Out:
#    angulo  angulo_tronco
# 0       0      82.678091
# 1      10      69.779708
# 2      20      65.073760
# 3      30      66.399926
# 4      40      66.988908
# 5      50      72.932800
# 6      60      83.462883
# 7      70      82.504219
# 8      80      75.197266
# 9      90      93.146353
# 10    100      98.521218
# 11    110      99.090610
# 12    120     103.878189
# 13    130     108.871639
# 14    140     109.594406
# 15    150     111.787726
# 16    160     114.700745
# 17    170     109.836289
# 18    180      81.716070

# %%
df_orientaciones_400["error"] = df_orientaciones_400["angulo_tronco"] - df_orientaciones_400["angulo"].astype(int)
df_orientaciones_400
# Out:
#    angulo  angulo_tronco      error
# 0       0      82.678091  82.678091
# 1      10      69.779708  59.779708
# 2      20      65.073760  45.073760
# 3      30      66.399926  36.399926
# 4      40      66.988908  26.988908
# 5      50      72.932800  22.932800
# 6      60      83.462883  23.462883
# 7      70      82.504219  12.504219
# 8      80      75.197266  -4.802734
# 9      90      93.146353   3.146353
# 10    100      98.521218  -1.478782
# 11    110      99.090610 -10.909390
# 12    120     103.878189 -16.121811
# 13    130     108.871639 -21.128361
# 14    140     109.594406 -30.405594
# 15    150     111.787726 -38.212274
# 16    160     114.700745 -45.299255
# 17    170     109.836289 -60.163711
# 18    180      81.716070 -98.283930

# %%
# grafica el angulo de Y, con valores en x de los indices de df_orientaciones_300
# plt.plot(df_orientaciones_400["angulo_tronco"])
# plt.plot(df_orientaciones_400["angulo"].astype(int))

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_400.index, df_orientaciones_400["angulo"].astype(int), label='Ángulo', marker='o')
ax.plot(df_orientaciones_400.index, df_orientaciones_400["angulo_tronco"], label='Ángulo estimado', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Ángulo y Ángulo estimado')
ax.set_xlabel('Índice')
ax.set_ylabel('Ángulo (grados)')

# Añadir una leyenda
ax.legend()

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# # Altura

# %%
val_height = json["height_167"]

# %%
data = []

# crear un dataframe con las orientaciones
for key in val_height.keys():
    data.append({"distancia": key, "altura_estimada": val_height[key][0]["respuesta"]})#, "angulo_head": val_orientacion["300"][key][0]["angulo_head"]})

df_val_height = pd.DataFrame(data)
df_val_height["altura_real"] = 167

# %%
df_val_height
# Out:
#   distancia  altura_estimada  altura_real
# 0       200       179.423398          167
# 1       250       173.594662          167
# 2       300       166.985548          167
# 3       350       158.094893          167
# 4       400       152.081012          167
# 5       450       147.333419          167
# 6       500       145.017622          167
# 7       550       137.890636          167
# 8       600       133.608443          167

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_val_height.distancia, df_val_height["altura_real"].astype(int), label='Altura', marker='o')
ax.plot(df_val_height.distancia, df_val_height["altura_estimada"], label='Altura estimado', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Altura y Altura estimada')
ax.set_xlabel('Distancia (cm)')
ax.set_ylabel('Altura (cm)')

# Añadir una leyenda
ax.legend()

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# WLS con eliminacion de recta de intersepcion
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.87710118293762"}, {"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}, {"result": "c", "confidence": "99.3501365184784"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "l", "confidence": "96.73730134963989"}, {"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 110.73278974509492}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 128.31053122379498}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 128.2105957898153}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 143.60163560655764}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 150.5711195493649}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 157.9873118276424}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 169.69774410540066}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 8.042085580697112}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 153.97910413599044}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 71.62315471090737}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 168.15449799964972}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 36.05308929166006}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 41.80731681759982}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 28.667941463505553}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 58.50066267952917}], "150": [], "160": [], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 75.77271637070398}], "180": []}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 130.04711846086084}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 131.04975449101136}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 139.14275793057465}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 141.4051441556828}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 144.0428452566465}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 8.811871816274595}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 15.300092479629946}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 6.797027419096756}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 6.272807234216817}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 84.63351147558681}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 61.37413321994165}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 43.022920725742146}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 8.964082099443635}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 63.58781155939626}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 175.26768883185954}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 57.43076882144278}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 57.37948088645875}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 59.708409531644314}], "180": []}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 45.59135426024826}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 169.7622989804069}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 10.859176258499621}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 145.5822487119823}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 28.748731555522703}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 65.49547273903194}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 69.11813343890181}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 69.29119978762922}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 43.46298425144143}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 73.03375749369279}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 68.7274330624475}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 89.14696445198672}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 18.206977684950434}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 179.98203455087264}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 72.8039499671519}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 26.723538521361878}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 45.7407710780215}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 63.803495697988595}], "180": []}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 101.63685901726309}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 101.38121450791061}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 103.08440185272826}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 105.13288560094193}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 128.54544032333445}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 153.32963768469784}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 157.47800255829006}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 47.814482765261005}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 33.51775328850454}], "90": [{"angulo_tronco": 90.0, "angulo_head": 90.08244006369567}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 17.236971172486065}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 22.32751069257215}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 49.58064843740568}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 54.77790419021126}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 73.40158468354129}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 84.31432743953673}], "160": [], "170": [], "180": []}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 121.7575875838981}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 140.35904955221196}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 143.1672164912054}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 156.0983503202574}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 168.56523546187864}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 7.851427787864808}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 25.656326920083803}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 35.20977247966808}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 41.95605434521824}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 88.37931055108025}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 77.99739752888516}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 66.59432652052412}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 71.33800484577526}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 52.469769164818}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 74.67471787539552}], "150": [], "160": [], "170": [], "180": []}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 126.87693614050661}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 116.93650039748937}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 147.37882500224885}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 26.871582389186614}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 51.148529265583036}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 157.73634304583416}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 63.00236373222088}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 0.05811316606602781}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 111.15183707505702}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 15.907426312872191}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 139.92405737605594}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 63.348031726578434}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 173.85885269029174}], "140": [{"angulo_tronco": 90.0, "angulo_head": 51.795499330328155}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 30.97407530215984}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 15.196249431513012}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 53.46502748766247}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# Orientacion cabeza corregida
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.87710118293762"}, {"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}, {"result": "c", "confidence": "99.3501365184784"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "l", "confidence": "96.73730134963989"}, {"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 65.64690506347812}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 68.69590785020968}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 68.93660593910693}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 89.57938561456564}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 89.95249167873573}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 90.7098374685131}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 91.60178962011948}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 90.79035865161053}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 91.70124898639709}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 92.79157342048464}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 94.5225390938155}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 94.81978740208874}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 96.14670552206282}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 97.74425512766804}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 98.36529522774165}], "150": [], "160": [], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 101.252657818194}], "180": []}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 86.99366559975901}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 87.34997988204735}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 87.73669207601193}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 88.3777615617291}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 89.91342599299497}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 90.4719157727275}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 90.3740397700877}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 88.80195124713167}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 92.3901331391102}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 90.8308099276303}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 90.27665460897576}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 90.0659749405948}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 92.11564291554313}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 90.35625546133818}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 90.13019721968416}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 91.95776694316292}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 91.2611365700056}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 91.51881701606537}], "180": []}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 93.3435827405465}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 87.33132137825375}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 87.93669510866249}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 88.22829533389314}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 88.6544636103437}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 89.26643415019181}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 89.54177626209399}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 89.10488358164453}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 88.65392644165638}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 89.01245244465423}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 88.69899467073465}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 88.44020523571443}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 89.10396996078661}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 89.40211317706294}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 88.49821577936532}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 88.77642601045612}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 91.0661007620435}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 91.10394931768144}], "180": []}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 55.814713229163445}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 57.4715358670173}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 86.25235464949559}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 87.62929431040851}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 88.66815756696657}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 89.35688802823985}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 90.08282390125292}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 89.8889731914896}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 90.60990150280382}], "90": [{"angulo_tronco": 90.0, "angulo_head": 92.29968033971319}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 93.44736703453727}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 93.76550708300731}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 93.94924027123945}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 94.50743225032393}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 94.37928681228831}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 94.48675446805905}], "160": [], "170": [], "180": []}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 75.37361646179735}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 76.52035906904877}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 89.47586027569244}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 89.40846247997084}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 90.07864402484364}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 89.75898163182268}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 90.35615673061982}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 90.99215270284809}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 91.53100817940894}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 91.80018430516633}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 92.48591296303431}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 92.58293531725687}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 93.2916752265016}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 93.04658106267586}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 93.28046625182675}], "150": [], "160": [], "170": [], "180": []}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 89.80197730276201}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 91.2439681823459}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 90.76989251100711}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 91.17212402874598}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 91.65868005657443}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 92.15381228280067}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 91.99711778265286}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 92.04186219444762}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 92.35069214396496}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 92.6155024912549}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 92.66957414921737}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 92.48207570643473}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 92.60420473896674}], "140": [{"angulo_tronco": 90.0, "angulo_head": 93.15468722683585}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 92.92702224473571}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 93.44201330990316}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 93.86336499257962}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# Correcion de cada vector a la direccion correcta
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.87710118293762"}, {"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}, {"result": "c", "confidence": "99.3501365184784"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "l", "confidence": "96.73730134963989"}, {"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 14.60159163775054}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 6.088250455626199}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 6.697362689680133}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 144.4779666463356}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 141.42482831275032}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 144.56076115078667}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 145.7334595299987}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 87.69453599004724}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 127.61491919347658}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 122.74169228539962}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 156.39996859100668}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 57.33261299263167}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 54.55946609733804}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 73.94468946706506}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 64.09405416445219}], "150": [], "160": [], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 84.43947255939793}], "180": []}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 128.6572644903385}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 128.1037262580328}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 125.36923173696108}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 139.7162508795827}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 137.6224643063771}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 7.362964945719955}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 11.645784658469212}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 49.70574001451763}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 0.21703698731910162}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 80.96494799929026}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 42.05010399679801}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 109.60094944755444}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 62.90820746659482}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 147.3465853578114}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 160.65256315760055}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 63.75866066504532}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 60.63881417254795}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 66.75713475621461}], "180": []}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 43.648023982848095}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 171.550042196412}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 4.021888843232577}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 144.07336196832006}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 28.058152761688003}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 61.789884873338956}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 65.34403737723385}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 71.67976940281024}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 38.1559062671939}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 74.64032052865774}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 152.15197707557235}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 93.36346515999021}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 27.396977750070278}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 24.665361771509513}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 79.97646914064826}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 49.66727219850445}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 44.19699885441302}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 62.78046355672222}], "180": []}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 152.48561017991753}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 13.899372659124522}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 107.0373798383262}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 114.85700565378504}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 134.63949614278707}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 150.8964843219913}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 147.28436456110202}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 44.09914280910142}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 40.874420353499346}], "90": [{"angulo_tronco": 90.0, "angulo_head": 147.65895102505328}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 35.86516518552729}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 39.62479542052724}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 58.55440096753474}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 61.04527461194597}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 67.478664985532}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 83.56277351147067}], "160": [], "170": [], "180": []}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 27.105405369170228}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 27.609660461413867}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 140.36561677206888}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 127.39020136080912}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 163.5596077259913}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 2.791610619569728}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 27.468705930768206}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 108.02486515852578}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 126.43902558902595}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 144.63685932412722}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 119.6552602059388}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 65.67063656064883}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 83.31013028646494}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 62.72599913022381}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 72.79163989575878}], "150": [], "160": [], "170": [], "180": []}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 124.78844801107456}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 128.42796420453573}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 152.4487069116245}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 84.0830545312145}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 42.86573578546716}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 61.860995909854836}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 51.83027694907997}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 111.47371374010257}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 119.71317779538644}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 103.81074125661904}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 134.29931813562695}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 66.57801489619}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 147.27517397573192}], "140": [{"angulo_tronco": 90.0, "angulo_head": 51.71936474024806}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 41.030910867275175}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 25.52041389947195}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 55.30514534955629}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}


# WLS con eliminacion de recta mas larga
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.5866060256958"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "l", "confidence": "99.86996650695801"}, {"result": "i", "confidence": "99.93085861206055"}, {"result": "i", "confidence": "92.41398572921753"}, {"result": "i", "confidence": "99.8475730419159"}, {"result": "l", "confidence": "92.70986914634705"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "l", "confidence": "90.02370834350586"}]}, "400": {"C": [{"result": "c", "confidence": "99.87710118293762"}, {"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}, {"result": "c", "confidence": "99.3501365184784"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "l", "confidence": "97.93516397476196"}, {"result": "l", "confidence": "86.11145615577698"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "99.98427629470825"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "l", "confidence": "64.25772309303284"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.72322583198547"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "99.99580383300781"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "l", "confidence": "96.73730134963989"}, {"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "87.88073658943176"}, {"result": "i", "confidence": "94.24360394477844"}, {"result": "i", "confidence": "98.9936113357544"}, {"result": "i", "confidence": "99.84750151634216"}, {"result": "l", "confidence": "66.6887879371643"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 110.73278974509492}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 128.31053122379498}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 128.2105957898153}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 143.60163560655764}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 150.5711195493649}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 157.9873118276424}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 169.69774410540066}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 8.042085580697112}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 153.97910413599044}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 71.62315471090737}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 168.15449799964972}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 36.05308929166006}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 41.80731681759982}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 28.667941463505553}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 58.50066267952917}], "150": [], "160": [], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 75.77271637070398}], "180": []}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 130.04711846086084}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 131.04975449101136}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 139.14275793057465}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 141.4051441556828}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 144.0428452566465}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 8.811871816274595}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 15.300092479629946}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 6.797027419096756}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 6.272807234216817}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 84.63351147558681}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 61.37413321994165}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 43.022920725742146}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 8.964082099443635}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 63.58781155939626}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 175.26768883185954}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 57.43076882144278}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 57.37948088645875}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 59.708409531644314}], "180": []}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 45.59135426024826}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 169.7622989804069}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 10.859176258499621}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 145.5822487119823}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 28.748731555522703}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 65.49547273903194}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 69.11813343890181}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 69.29119978762922}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 43.46298425144143}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 73.03375749369279}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 68.7274330624475}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 89.14696445198672}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 18.206977684950434}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 179.98203455087264}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 72.8039499671519}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 26.723538521361878}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 45.7407710780215}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 63.803495697988595}], "180": []}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 101.63685901726309}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 101.38121450791061}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 103.08440185272826}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 105.13288560094193}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 128.54544032333445}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 153.32963768469784}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 157.47800255829006}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 47.814482765261005}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 33.51775328850454}], "90": [{"angulo_tronco": 90.0, "angulo_head": 90.08244006369567}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 17.236971172486065}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 22.32751069257215}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 49.58064843740568}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 54.77790419021126}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 73.40158468354129}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 84.31432743953673}], "160": [], "170": [], "180": []}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 121.7575875838981}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 140.35904955221196}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 143.1672164912054}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 156.0983503202574}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 168.56523546187864}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 7.851427787864808}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 25.656326920083803}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 35.20977247966808}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 41.95605434521824}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 88.37931055108025}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 77.99739752888516}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 66.59432652052412}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 71.33800484577526}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 52.469769164818}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 74.67471787539552}], "150": [], "160": [], "170": [], "180": []}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 126.87693614050661}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 116.93650039748937}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 147.37882500224885}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 26.871582389186614}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 51.148529265583036}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 157.73634304583416}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 63.00236373222088}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 0.05811316606602781}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 111.15183707505702}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 15.907426312872191}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 139.92405737605594}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 63.348031726578434}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 173.85885269029174}], "140": [{"angulo_tronco": 90.0, "angulo_head": 51.795499330328155}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 30.97407530215984}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 15.196249431513012}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 53.46502748766247}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# WLS con el modelo de yolo mas grande y solo el promedio de todos los puntos de la cabeza
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "99.3725836277008"}, {"result": "c", "confidence": "99.90789890289307"}, {"result": "c", "confidence": "99.19987320899963"}, {"result": "i", "confidence": "49.00380074977875"}, {"result": "c", "confidence": "99.88853335380554"}, {"result": "c", "confidence": "99.9653697013855"}, {"result": "c", "confidence": "93.12952756881714"}, {"result": "c", "confidence": "99.71290230751038"}], "L": [{"result": "l", "confidence": "80.28239011764526"}, {"result": "i", "confidence": "96.16537094116211"}, {"result": "c", "confidence": "99.98856782913208"}, {"result": "l", "confidence": "96.29062414169312"}, {"result": "l", "confidence": "96.46492004394531"}, {"result": "l", "confidence": "99.50089454650879"}, {"result": "c", "confidence": "88.53585124015808"}], "I": [{"result": "c", "confidence": "99.97437596321106"}, {"result": "c", "confidence": "92.31049418449402"}, {"result": "c", "confidence": "99.99665021896362"}, {"result": "i", "confidence": "99.36919212341309"}, {"result": "c", "confidence": "92.75941848754883"}, {"result": "c", "confidence": "99.93450045585632"}, {"result": "i", "confidence": "96.95206880569458"}]}, "400": {"C": [{"result": "c", "confidence": "99.61056113243103"}, {"result": "c", "confidence": "99.86648559570312"}, {"result": "c", "confidence": "99.78081583976746"}, {"result": "c", "confidence": "99.76732134819031"}, {"result": "c", "confidence": "99.80327486991882"}], "L": [{"result": "l", "confidence": "95.77175974845886"}, {"result": "c", "confidence": "81.50678277015686"}, {"result": "l", "confidence": "61.35790944099426"}, {"result": "l", "confidence": "80.09523749351501"}, {"result": "l", "confidence": "93.20094585418701"}, {"result": "l", "confidence": "99.89944100379944"}, {"result": "l", "confidence": "99.79649782180786"}], "I": [{"result": "l", "confidence": "99.93526339530945"}, {"result": "c", "confidence": "97.3517656326294"}, {"result": "i", "confidence": "89.7002637386322"}, {"result": "i", "confidence": "84.1883659362793"}, {"result": "l", "confidence": "99.77201819419861"}, {"result": "i", "confidence": "84.22012329101562"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99481439590454"}, {"result": "c", "confidence": "99.99552965164185"}, {"result": "c", "confidence": "96.65007591247559"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.99995231628418"}], "L": [{"result": "l", "confidence": "71.92121744155884"}, {"result": "c", "confidence": "99.99887943267822"}, {"result": "c", "confidence": "99.5751142501831"}, {"result": "c", "confidence": "53.31079959869385"}, {"result": "c", "confidence": "99.93102550506592"}, {"result": "c", "confidence": "99.93976354598999"}, {"result": "c", "confidence": "99.97633099555969"}], "I": [{"result": "i", "confidence": "99.46216344833374"}, {"result": "l", "confidence": "54.97701168060303"}, {"result": "i", "confidence": "99.01894927024841"}, {"result": "i", "confidence": "99.75244402885437"}, {"result": "l", "confidence": "96.9170331954956"}, {"result": "i", "confidence": "98.94134998321533"}]}, "400": {"C": [{"result": "c", "confidence": "99.866783618927"}, {"result": "c", "confidence": "99.99750852584839"}, {"result": "c", "confidence": "99.99955892562866"}, {"result": "c", "confidence": "99.99656677246094"}, {"result": "c", "confidence": "99.99698400497437"}, {"result": "c", "confidence": "99.99411106109619"}], "L": [{"result": "c", "confidence": "87.97686100006104"}, {"result": "c", "confidence": "99.94558691978455"}, {"result": "i", "confidence": "98.21856617927551"}, {"result": "c", "confidence": "99.9666690826416"}, {"result": "l", "confidence": "99.7480571269989"}, {"result": "c", "confidence": "99.77836012840271"}, {"result": "l", "confidence": "93.2134747505188"}], "I": [{"result": "i", "confidence": "98.92801642417908"}, {"result": "i", "confidence": "99.78723526000977"}, {"result": "i", "confidence": "99.36479926109314"}, {"result": "i", "confidence": "99.6012806892395"}, {"result": "i", "confidence": "99.95666146278381"}, {"result": "i", "confidence": "99.6825098991394"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 78.56923314806629, "angulo_head": 20.616907126282413}], "10": [{"angulo_tronco": 77.76809388997498, "angulo_head": 12.306069689096345}], "20": [{"angulo_tronco": 77.33832132497317, "angulo_head": 77.94462150384986}], "30": [{"angulo_tronco": 76.09674342840489, "angulo_head": 79.69881654763098}], "40": [{"angulo_tronco": 71.73581418749107, "angulo_head": 81.23641192877017}], "50": [{"angulo_tronco": 73.7579233056056, "angulo_head": 82.91115537272972}], "60": [{"angulo_tronco": 79.88192164392744, "angulo_head": 85.22586343468865}], "70": [{"angulo_tronco": 81.36990155134515, "angulo_head": 84.685081464395}], "80": [{"angulo_tronco": 88.47602448541566, "angulo_head": 86.41850912052053}], "90": [{"angulo_tronco": 91.29715958955629, "angulo_head": 88.81505961197713}], "100": [{"angulo_tronco": 96.1201408471013, "angulo_head": 92.52680906058315}], "110": [{"angulo_tronco": 97.05480775386457, "angulo_head": 91.74666052048696}], "120": [{"angulo_tronco": 100.79172792459066, "angulo_head": 94.24399722729254}], "130": [{"angulo_tronco": 104.89052437267802, "angulo_head": 94.27265624555831}], "140": [{"angulo_tronco": 111.79921691638084, "angulo_head": 95.83334948522236}], "150": [], "160": [], "170": [{"angulo_tronco": 117.1837251610876, "angulo_head": -1}], "180": []}, "300": {"0": [{"angulo_tronco": 54.20538179786629, "angulo_head": 74.33453638986649}], "10": [{"angulo_tronco": 66.71194219455542, "angulo_head": 75.08410481617531}], "20": [{"angulo_tronco": 77.45160782554412, "angulo_head": 75.88740499804199}], "30": [{"angulo_tronco": 76.97086905706104, "angulo_head": 76.60834273964862}], "40": [{"angulo_tronco": 90.0, "angulo_head": 66.0833667089725}], "50": [{"angulo_tronco": 72.72566056678802, "angulo_head": 90.35088571651536}], "60": [{"angulo_tronco": 74.21698491873804, "angulo_head": 86.51140644637694}], "70": [{"angulo_tronco": 76.2568733849912, "angulo_head": 75.80753660670192}], "80": [{"angulo_tronco": 76.25220973897154, "angulo_head": 97.34854281333703}], "90": [{"angulo_tronco": 85.92258632180533, "angulo_head": 89.12914511647672}], "100": [{"angulo_tronco": 88.55825205802319, "angulo_head": 85.3320025547323}], "110": [{"angulo_tronco": 91.17811251569871, "angulo_head": 84.5260163018092}], "120": [{"angulo_tronco": 93.26264660225831, "angulo_head": 98.31870065467078}], "130": [{"angulo_tronco": 100.9720682735056, "angulo_head": 87.65506318892042}], "140": [{"angulo_tronco": 99.0712041736648, "angulo_head": 85.9385892719536}], "150": [{"angulo_tronco": 100.0081987285591, "angulo_head": 15.59158926402823}], "160": [{"angulo_tronco": 105.68980228287397, "angulo_head": 94.38238443958566}], "170": [{"angulo_tronco": 102.58427900020462, "angulo_head": 96.54799491976215}], "180": [{"angulo_tronco": 91.71787895632559, "angulo_head": 20.291872472568972}]}, "400": {"0": [{"angulo_tronco": 114.97820800191636, "angulo_head": 76.20709043835781}], "10": [{"angulo_tronco": 73.25566907680357, "angulo_head": 78.53875831341139}], "20": [{"angulo_tronco": 66.16849156406481, "angulo_head": 79.02536186555001}], "30": [{"angulo_tronco": 63.912545633160455, "angulo_head": 77.42803533611405}], "40": [{"angulo_tronco": 72.66891214760994, "angulo_head": 81.9866951999576}], "50": [{"angulo_tronco": 72.21870271604682, "angulo_head": 86.40173839092088}], "60": [{"angulo_tronco": 73.53249218576939, "angulo_head": 87.12265914661988}], "70": [{"angulo_tronco": 80.01423057623329, "angulo_head": 89.74368555952542}], "80": [{"angulo_tronco": 77.6373511861172, "angulo_head": 84.21231590309}], "90": [{"angulo_tronco": 82.80567749238442, "angulo_head": 88.65063196963047}], "100": [{"angulo_tronco": 87.56522545438708, "angulo_head": 89.08372998254836}], "110": [{"angulo_tronco": 87.3970470396447, "angulo_head": 88.25522928718989}], "120": [{"angulo_tronco": 92.74586858936124, "angulo_head": 91.1033572388679}], "130": [{"angulo_tronco": 92.83855721537061, "angulo_head": 98.44939596832327}], "140": [{"angulo_tronco": 90.0, "angulo_head": 88.22724450639818}], "150": [{"angulo_tronco": 96.06167504466497, "angulo_head": 90.37213650839267}], "160": [{"angulo_tronco": 104.12553129168475, "angulo_head": 100.17429071293316}], "170": [{"angulo_tronco": 106.50705018708028, "angulo_head": 99.61404157815309}], "180": []}}, "orientacion_cabeza": {"200": {"0": [], "10": [], "20": [{"angulo_tronco": 74.16851141776833, "angulo_head": 80.2928836150654}], "30": [{"angulo_tronco": 74.28308148018209, "angulo_head": 81.64933016071517}], "40": [{"angulo_tronco": 76.68473949180242, "angulo_head": 80.7812837189726}], "50": [{"angulo_tronco": 77.43029607956936, "angulo_head": 83.03962168257019}], "60": [{"angulo_tronco": 80.49744935795965, "angulo_head": 84.82523036839956}], "70": [{"angulo_tronco": 83.35978067242793, "angulo_head": 84.03372183157109}], "80": [{"angulo_tronco": 84.31836173356419, "angulo_head": 86.02110475736629}], "90": [{"angulo_tronco": 90.0, "angulo_head": 89.67875394577192}], "100": [{"angulo_tronco": 96.61720186283928, "angulo_head": 92.88682429491266}], "110": [{"angulo_tronco": 96.70526382930463, "angulo_head": 93.81273156286616}], "120": [{"angulo_tronco": 98.97317673187982, "angulo_head": 94.13105712971516}], "130": [{"angulo_tronco": 100.11280937215898, "angulo_head": 94.85828175748722}], "140": [{"angulo_tronco": 103.4282924284909, "angulo_head": 95.72304466748528}], "150": [], "160": [], "170": [], "180": []}, "300": {"0": [{"angulo_tronco": 126.76785290676841, "angulo_head": 8.31939894247121}], "10": [{"angulo_tronco": 90.36914752066225, "angulo_head": 13.90878048448932}], "20": [{"angulo_tronco": 83.91069525288106, "angulo_head": 13.252351844572832}], "30": [{"angulo_tronco": 85.55691776939548, "angulo_head": 17.640347508142664}], "40": [{"angulo_tronco": 80.28536815307153, "angulo_head": 81.07737283645136}], "50": [{"angulo_tronco": 79.79626911450865, "angulo_head": 82.62514526913554}], "60": [{"angulo_tronco": 76.90826262415736, "angulo_head": 81.95777705878596}], "70": [{"angulo_tronco": 84.40546830190893, "angulo_head": 85.7426440505903}], "80": [{"angulo_tronco": 85.94310694898152, "angulo_head": 87.56062634793602}], "90": [{"angulo_tronco": 87.36751090763859, "angulo_head": 90.33562165368613}], "100": [{"angulo_tronco": 91.36005784904603, "angulo_head": 92.51005856718298}], "110": [{"angulo_tronco": 92.81742378867624, "angulo_head": 92.13996470956972}], "120": [{"angulo_tronco": 95.94023509608373, "angulo_head": 93.11191112567366}], "130": [{"angulo_tronco": 93.18198479436411, "angulo_head": 96.01624834986194}], "140": [{"angulo_tronco": 95.32241720965766, "angulo_head": 94.67611282462224}], "150": [], "160": [], "170": [], "180": []}, "400": {"0": [{"angulo_tronco": 93.72204349656843, "angulo_head": 78.8354994634589}], "10": [], "20": [{"angulo_tronco": 84.15325280462373, "angulo_head": 80.41938211380103}], "30": [{"angulo_tronco": 81.62371387645067, "angulo_head": 80.8276286465288}], "40": [{"angulo_tronco": 80.31846332954753, "angulo_head": 80.00091784855192}], "50": [{"angulo_tronco": 81.012418683046, "angulo_head": 81.04566773258931}], "60": [{"angulo_tronco": 84.72599048015879, "angulo_head": 83.89137121754905}], "70": [{"angulo_tronco": 82.67607303922982, "angulo_head": 85.77516445717097}], "80": [{"angulo_tronco": 87.6894251524751, "angulo_head": 87.09088711491098}], "90": [{"angulo_tronco": 87.71349662079798, "angulo_head": 88.87951280907332}], "100": [{"angulo_tronco": 90.0, "angulo_head": 91.98832507157083}], "110": [{"angulo_tronco": 90.17917455983495, "angulo_head": 93.0942137902182}], "120": [{"angulo_tronco": 90.0, "angulo_head": 94.25402905888278}], "130": [{"angulo_tronco": 95.9171084833094, "angulo_head": 95.95353931745379}], "140": [{"angulo_tronco": 90.48287789231978, "angulo_head": 96.11696874433605}], "150": [{"angulo_tronco": 90.51283541807383, "angulo_head": 98.0556404017531}], "160": [{"angulo_tronco": 95.93661053991984, "angulo_head": 97.36451092790577}], "170": [{"angulo_tronco": 89.01003407270166, "angulo_head": 97.80617566995143}], "180": [{"angulo_tronco": 89.57939501824852, "angulo_head": 100.45991198094019}]}}, "centroide": {"200": [{"respuesta": 203.80906869948788}], "250": [{"respuesta": 251.35894661159358}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.93633749302853}], "450": [{"respuesta": 461.57152165620136}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 612.031911950664}]}, "centroide_grupal": {"200": [{"respuesta": 213.91670068649097}], "250": [{"respuesta": 262.67258993122914}], "300": [{"respuesta": 314.3144172227957}, {"respuesta": 313.2743600724153}], "350": [{"respuesta": 369.6664918893046}, {"respuesta": 370.61364832516733}], "400": [{"respuesta": 413.92777965298563}], "450": [{"respuesta": 465.0720394540479}, {"respuesta": 466.8753607109213}], "500": [{"respuesta": 522.713369383389}], "550": [{"respuesta": 566.8599006795723}, {"respuesta": 608.4597295779301}], "600": [{"respuesta": 609.4229217116383}]}, "height_167": {"200": [{"respuesta": 170.2738618685427}], "250": [{"respuesta": 168.0035038772258}], "300": [{"respuesta": 166.6305399130764}], "350": [{"respuesta": 165.08925089303497}], "400": [{"respuesta": 165.36432479188528}], "450": [{"respuesta": 165.72202067329238}], "500": [{"respuesta": 166.62910832692768}], "550": [{"respuesta": 166.4317059038085}], "600": [{"respuesta": 169.77857017452362}]}}

# con el mas ligero de yolo
json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.87710118293762"}, {"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}, {"result": "c", "confidence": "99.3501365184784"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "l", "confidence": "96.73730134963989"}, {"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 17.706559988209655}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 11.744904706068828}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 11.30837979027404}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 79.63803502347524}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 80.70419040553351}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 82.13433205134821}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 84.47940937563192}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 83.15819908873132}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 85.46175396064416}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 88.19643281915458}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 92.07032766738443}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 91.39358000486733}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 93.6324312857268}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 94.27207950893337}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 95.19045533489633}], "150": [], "160": [], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 93.00587991588964}], "180": []}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 76.09303061174157}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 75.84695760462587}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 77.059465496468}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 78.76973833221456}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 82.2069788932872}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 87.65516555405465}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 85.85383190669023}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 77.05831911008671}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 97.74302768220318}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 89.10572230625324}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 86.4248672776234}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 85.65200963926502}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 97.1606776396648}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 88.85633412756073}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 87.35149208100815}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 96.71684475636705}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 94.54859196436459}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 95.1190486821136}], "180": []}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 73.48133095804711}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 73.13244149336738}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 78.9228738894569}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 79.40743924137392}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 81.60439097731319}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 86.08904708270873}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 87.57568436571817}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 87.7353219858077}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 85.06899207336835}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 88.57999621867039}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 88.62804747205188}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 89.63302965610505}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 94.14209922054795}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 98.63159839629748}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 91.26833109945517}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 91.97508976318426}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 103.63490950789435}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 100.82420724308227}], "180": []}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 27.560004707142173}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 26.299547779621847}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 81.09826969514297}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 80.89460280881087}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 80.84208995210008}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 82.59612210024267}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 84.94005304128999}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 84.62855343137403}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 85.69905945523081}], "90": [{"angulo_tronco": 90.0, "angulo_head": 89.85567153912386}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 92.10274837619534}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 93.38934611810437}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 93.15732219747935}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 94.05112852553239}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 94.8263325406338}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 93.02872410204374}], "160": [], "170": [], "180": []}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 9.686808611005826}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 13.723944814994391}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 78.76484144437676}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 78.11207737027274}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 80.41977047819876}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 81.33482303715586}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 81.72794188102536}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 85.85563946998009}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 87.86210249279623}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 89.92070220648526}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 91.57028619326354}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 91.64981839414203}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 92.88838199294479}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 93.86709393880099}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 94.50724292320002}], "150": [], "160": [], "170": [], "180": []}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 77.41550812687234}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 80.43291503027044}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 79.68312643380864}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 79.86290378996738}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 82.04845825753348}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 86.55795311722075}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 86.47965311111095}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 87.32360674208097}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 89.21306883674754}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 91.15154782808244}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 92.68591456262334}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 92.04430188663798}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 93.21561499653383}], "140": [{"angulo_tronco": 90.0, "angulo_head": 96.99022564069588}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 97.11878978811163}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 99.71977314792782}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 100.80854927117588}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# WLS con el mas ligero de yolo pero con correccion de frente
json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 162.4333945585971}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 11.178474540200712}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 10.8117512118006}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 144.4779666463356}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 141.42482831275032}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 151.33669468323157}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 150.06117710125255}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 1.2040964620854056}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 147.17148950372084}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 54.90903173395498}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 171.0282853033781}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 57.33261299263167}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 54.55946609733804}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 73.94468946706506}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 64.09405416445219}], "150": [{"angulo_tronco": 105.40653956449154, "angulo_head": 71.4673057988668}], "160": [{"angulo_tronco": 105.5653116282023, "angulo_head": 70.62913095824487}], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 84.43947255939793}], "180": [{"angulo_tronco": 90.22881297276098, "angulo_head": 168.78504084808006}]}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 128.6572644903385}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 128.1037262580328}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 125.36923173696108}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 139.7162508795827}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 137.6224643063771}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 16.914979098031605}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 11.645784658469212}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 160.3508946636613}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 0.21703698731910162}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 80.96494799929026}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 42.05010399679801}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 23.77098370226349}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 62.90820746659482}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 38.65417283727337}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 171.55765342048718}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 63.75866066504532}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 60.63881417254795}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 66.75713475621461}], "180": [{"angulo_tronco": 92.59079680974855, "angulo_head": 22.300380834937386}]}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 43.648023982848095}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 171.550042196412}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 4.021888843232577}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 144.07336196832006}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 28.058152761688003}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 61.789884873338956}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 65.34403737723385}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 71.67976940281024}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 38.1559062671939}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 74.64032052865774}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 30.42512856501636}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 93.36346515999021}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 27.396977750070278}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 7.254125814450413}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 79.97646914064826}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 49.66727219850445}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 44.19699885441302}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 62.78046355672222}], "180": [{"angulo_tronco": 91.16956371277506, "angulo_head": 169.81408421128216}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 152.48561017991753}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 153.7845035593115}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 107.0373798383262}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 114.85700565378504}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 150.98467921199492}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 150.8964843219913}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 147.28436456110202}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 44.09914280910142}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 40.874420353499346}], "90": [{"angulo_tronco": 90.0, "angulo_head": 44.10969846171719}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 35.86516518552729}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 39.62479542052724}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 58.55440096753474}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 61.04527461194597}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 67.478664985532}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 83.56277351147067}], "160": [{"angulo_tronco": 100.13484505212077, "angulo_head": 62.16498214588852}], "170": [{"angulo_tronco": 100.56493816441778, "angulo_head": 165.10163139940593}], "180": [{"angulo_tronco": 91.44724789522074, "angulo_head": 164.41522803842315}]}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 7.600466525133131}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 13.059028947566796}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 140.36561677206888}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 127.39020136080912}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 163.5596077259913}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 2.791610619569728}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 27.468705930768206}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 20.062372518615334}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 18.97104853635193}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 105.72392747999936}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 65.39618077586516}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 65.67063656064883}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 83.31013028646494}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 42.45566336385459}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 72.79163989575878}], "150": [{"angulo_tronco": 93.99755439085598, "angulo_head": 72.02848203158331}], "160": [{"angulo_tronco": 92.63869290613535, "angulo_head": 62.557618566011065}], "170": [{"angulo_tronco": 94.36762714443748, "angulo_head": 16.782775909207228}], "180": [{"angulo_tronco": 90.0, "angulo_head": 12.73342667622608}]}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 124.78844801107456}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 128.42796420453573}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 152.4487069116245}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 9.03208871778202}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 42.86573578546716}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 16.63197452830223}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 51.83027694907997}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 136.93482353604534}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 107.52006301736151}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 136.66188300878446}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 6.351624725956957}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 66.57801489619}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 161.5371181339294}], "140": [{"angulo_tronco": 90.0, "angulo_head": 51.71936474024806}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 41.030910867275175}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 25.52041389947195}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 55.30514534955629}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# ************************************************************************************************************************************************************************************************************
# Selective con eliminacion de recta de intersepcion
# json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "99.11893606185913"}]}, "400": {"C": [{"result": "c", "confidence": "99.89907145500183"}, {"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "c", "confidence": "99.52154159545898"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.317548613362504, "angulo_head": 127.4667706358166}], "10": [{"angulo_tronco": 70.7568944402178, "angulo_head": 131.022048242739}], "20": [{"angulo_tronco": 57.61419424120367, "angulo_head": 140.0945589819904}], "30": [{"angulo_tronco": 60.21076508263887, "angulo_head": 29.89274796232595}], "40": [{"angulo_tronco": 56.24355419427472, "angulo_head": 28.250953650323723}], "50": [{"angulo_tronco": 67.55040125223503, "angulo_head": 155.1123758524855}], "60": [{"angulo_tronco": 74.51820233222134, "angulo_head": 7.210873890083145}], "70": [{"angulo_tronco": 81.33469478933503, "angulo_head": 8.578629827960846}], "80": [{"angulo_tronco": 85.72532174706791, "angulo_head": 21.940851068069797}], "90": [{"angulo_tronco": 87.1377112568786, "angulo_head": 19.380333767685517}], "100": [{"angulo_tronco": 98.48401760474923, "angulo_head": 135.5639946264831}], "110": [{"angulo_tronco": 98.29519322500154, "angulo_head": 171.82510068658726}], "120": [{"angulo_tronco": 111.5722246462678, "angulo_head": 168.20317347574021}], "130": [{"angulo_tronco": 110.3884553147763, "angulo_head": 30.134307191258355}], "140": [{"angulo_tronco": 119.00002152381533, "angulo_head": 35.32162020218212}], "150": [{"angulo_tronco": 120.24099163064206, "angulo_head": 40.23872622024012}], "160": [{"angulo_tronco": 124.94606899867208, "angulo_head": 55.34774934261701}], "170": [{"angulo_tronco": 132.46809860701995, "angulo_head": 61.563787066232024}], "180": [{"angulo_tronco": 100.85266527533611, "angulo_head": 60.424850454259754}]}, "300": {"0": [{"angulo_tronco": 97.41641494334196, "angulo_head": 133.06603314432797}], "10": [{"angulo_tronco": 65.24717630461609, "angulo_head": 135.80309867087968}], "20": [{"angulo_tronco": 72.85029557141362, "angulo_head": 143.94428045902865}], "30": [{"angulo_tronco": 65.47466919216176, "angulo_head": 141.92896271964543}], "40": [{"angulo_tronco": 64.09324959518491, "angulo_head": 144.32323959474994}], "50": [{"angulo_tronco": 62.40676952062169, "angulo_head": 129.37806608902437}], "60": [{"angulo_tronco": 67.9967746887692, "angulo_head": 144.39441983828635}], "70": [{"angulo_tronco": 73.50423218138849, "angulo_head": 155.23084723095116}], "80": [{"angulo_tronco": 83.0590420676506, "angulo_head": 17.01432376961038}], "90": [{"angulo_tronco": 88.37734800206992, "angulo_head": 77.31487521572333}], "100": [{"angulo_tronco": 97.06075441285508, "angulo_head": 170.7939135062217}], "110": [{"angulo_tronco": 94.50703961631805, "angulo_head": 29.73306261989866}], "120": [{"angulo_tronco": 101.41084037019952, "angulo_head": 14.847619351934558}], "130": [{"angulo_tronco": 104.05304023385662, "angulo_head": 47.06089349898312}], "140": [{"angulo_tronco": 106.66936180608808, "angulo_head": 49.71577405552326}], "150": [{"angulo_tronco": 115.16782731345224, "angulo_head": 46.44131070536518}], "160": [{"angulo_tronco": 126.55555333556609, "angulo_head": 159.70289901641598}], "170": [{"angulo_tronco": 115.99627584481442, "angulo_head": 47.48648077814153}], "180": [{"angulo_tronco": 106.17353571696981, "angulo_head": 53.82056697804188}]}, "400": {"0": [{"angulo_tronco": 82.49261383354245, "angulo_head": 30.48537122383426}], "10": [{"angulo_tronco": 67.6062781800269, "angulo_head": 134.45695747348367}], "20": [{"angulo_tronco": 65.00482351379296, "angulo_head": 148.1230109616016}], "30": [{"angulo_tronco": 66.45421690281243, "angulo_head": 149.01304221430226}], "40": [{"angulo_tronco": 67.01296828073042, "angulo_head": 154.18658960389803}], "50": [{"angulo_tronco": 72.95074819474607, "angulo_head": 0.8320197670776996}], "60": [{"angulo_tronco": 83.42635429160849, "angulo_head": 130.5999400476665}], "70": [{"angulo_tronco": 82.54100749175316, "angulo_head": 172.17666437413814}], "80": [{"angulo_tronco": 75.19414173222533, "angulo_head": 31.14912592013548}], "90": [{"angulo_tronco": 93.13558453743296, "angulo_head": 52.40254356550234}], "100": [{"angulo_tronco": 98.59870351260903, "angulo_head": 168.71179379606096}], "110": [{"angulo_tronco": 99.19056380350963, "angulo_head": 86.76750963745418}], "120": [{"angulo_tronco": 103.90993059004963, "angulo_head": 166.97637782519374}], "130": [{"angulo_tronco": 108.91615431922928, "angulo_head": 25.088582850206038}], "140": [{"angulo_tronco": 109.5562558416899, "angulo_head": 56.014060009051455}], "150": [{"angulo_tronco": 111.91744382288326, "angulo_head": 38.39197101963397}], "160": [{"angulo_tronco": 114.77072886083877, "angulo_head": 33.308955587303245}], "170": [{"angulo_tronco": 109.60787240467528, "angulo_head": 45.03902536155643}], "180": [{"angulo_tronco": 81.84036682188393, "angulo_head": 100.73472199779063}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.93289896823896, "angulo_head": 130.74795753812475}], "10": [{"angulo_tronco": 72.09938220556297, "angulo_head": 133.37753732497222}], "20": [{"angulo_tronco": 55.937097122972084, "angulo_head": 139.26115276235547}], "30": [{"angulo_tronco": 60.27527834590391, "angulo_head": 147.64861314132}], "40": [{"angulo_tronco": 63.4556516404457, "angulo_head": 10.086252140468124}], "50": [{"angulo_tronco": 69.92528430366588, "angulo_head": 17.38547851029694}], "60": [{"angulo_tronco": 77.90036628707396, "angulo_head": 159.27804144085354}], "70": [{"angulo_tronco": 79.0260595006596, "angulo_head": 35.240099092365455}], "80": [{"angulo_tronco": 82.52494351723446, "angulo_head": 32.85785425388658}], "90": [{"angulo_tronco": 87.83356703432436, "angulo_head": 91.79697630100561}], "100": [{"angulo_tronco": 101.09887701613356, "angulo_head": 144.41894457146344}], "110": [{"angulo_tronco": 102.44157798089572, "angulo_head": 169.74457496391594}], "120": [{"angulo_tronco": 109.57410017364761, "angulo_head": 27.00124265417491}], "130": [{"angulo_tronco": 111.91353115913164, "angulo_head": 43.785236294991456}], "140": [{"angulo_tronco": 119.08488231982781, "angulo_head": 153.1090580170396}], "150": [{"angulo_tronco": 128.2264793047116, "angulo_head": 52.44057057786736}], "160": [{"angulo_tronco": 115.65196284045456, "angulo_head": 43.82550190663907}], "170": [{"angulo_tronco": 125.82277441142402, "angulo_head": 59.49636709769911}], "180": [{"angulo_tronco": 94.9862505627236, "angulo_head": 53.67268868270612}]}, "300": {"0": [{"angulo_tronco": 84.0588822217152, "angulo_head": 129.63742368437306}], "10": [{"angulo_tronco": 66.88044285214944, "angulo_head": 133.94192963496369}], "20": [{"angulo_tronco": 62.07349377559729, "angulo_head": 143.78437548745072}], "30": [{"angulo_tronco": 67.33901831203815, "angulo_head": 153.79006067270936}], "40": [{"angulo_tronco": 72.66257359779956, "angulo_head": 162.07964238675046}], "50": [{"angulo_tronco": 71.39764740480123, "angulo_head": 14.381114068120842}], "60": [{"angulo_tronco": 69.98961540792183, "angulo_head": 15.01852979582118}], "70": [{"angulo_tronco": 82.19090052733463, "angulo_head": 26.508263283115078}], "80": [{"angulo_tronco": 82.59342180346688, "angulo_head": 51.795958407255156}], "90": [{"angulo_tronco": 87.49342245205524, "angulo_head": 91.19040559756256}], "100": [{"angulo_tronco": 95.0575401882925, "angulo_head": 151.3207585712362}], "110": [{"angulo_tronco": 99.57150006037783, "angulo_head": 173.5333320174983}], "120": [{"angulo_tronco": 107.46520636571971, "angulo_head": 179.27868796310054}], "130": [{"angulo_tronco": 110.04970358569899, "angulo_head": 176.41107588065566}], "140": [{"angulo_tronco": 101.12304871843388, "angulo_head": 29.076295133066353}], "150": [{"angulo_tronco": 114.42615656639688, "angulo_head": 31.349306307137432}], "160": [{"angulo_tronco": 122.59211978051096, "angulo_head": 42.79180276082392}], "170": [{"angulo_tronco": 119.93895030964246, "angulo_head": 41.47561761000123}], "180": [{"angulo_tronco": 173.27584527026863, "angulo_head": 132.95956136284295}]}, "400": {"0": [{"angulo_tronco": 89.8646010115569, "angulo_head": 133.20991841476584}], "10": [], "20": [{"angulo_tronco": 57.810350494318236, "angulo_head": 141.19156543983053}], "30": [{"angulo_tronco": 65.8122923523088, "angulo_head": 21.963304127694578}], "40": [{"angulo_tronco": 73.89218241299405, "angulo_head": 4.696930726609239}], "50": [{"angulo_tronco": 76.57896975973908, "angulo_head": 11.470108746128481}], "60": [{"angulo_tronco": 76.07707629700484, "angulo_head": 12.69169410608938}], "70": [{"angulo_tronco": 77.65530347946053, "angulo_head": 26.194319616224035}], "80": [{"angulo_tronco": 82.50804898144987, "angulo_head": 1.0936755505877551}], "90": [{"angulo_tronco": 89.50129119668328, "angulo_head": 72.92065864794063}], "100": [{"angulo_tronco": 93.62344462070853, "angulo_head": 150.9203490549151}], "110": [{"angulo_tronco": 106.14838788051358, "angulo_head": 167.15364002671882}], "120": [{"angulo_tronco": 104.56615691135708, "angulo_head": 149.335005781457}], "130": [{"angulo_tronco": 110.6627270335833, "angulo_head": 152.64163378458954}], "140": [{"angulo_tronco": 109.45559615195077, "angulo_head": 163.1117499866563}], "150": [{"angulo_tronco": 111.5062251096677, "angulo_head": 34.93982249168433}], "160": [{"angulo_tronco": 105.34236909846888, "angulo_head": 42.76096279183788}], "170": [{"angulo_tronco": 114.23235673416917, "angulo_head": 44.36025435552966}], "180": []}}, "centroide": {"200": [{"respuesta": 216.64028355851374}], "250": [{"respuesta": 259.13717089905396}], "300": [{"respuesta": 306.79403502320605}], "350": [{"respuesta": 342.67649189766695}], "400": [{"respuesta": 377.55545720285437}], "450": [{"respuesta": 415.0528409642584}], "500": [{"respuesta": 441.81741875488206}], "550": [{"respuesta": 477.68812465330797}], "600": [{"respuesta": 499.8800436163979}]}, "centroide_grupal": {"200": [{"respuesta": 224.25428338326057}], "250": [{"respuesta": 268.10363303964476}], "300": [{"respuesta": 303.9930879492914}, {"respuesta": 303.9594429954724}], "350": [{"respuesta": 348.3743265222216}, {"respuesta": 348.84715855528646}], "400": [{"respuesta": 372.6080635318941}], "450": [{"respuesta": 412.35376427673623}, {"respuesta": 412.93657729725146}], "500": [{"respuesta": 437.19813737579074}], "550": [{"respuesta": 467.11791334436646}, {"respuesta": 445.28379279040314}], "600": [{"respuesta": 443.61628425811966}]}, "height_167": {"200": [{"respuesta": 179.42688396261534}], "250": [{"respuesta": 173.58844293897164}], "300": [{"respuesta": 166.98031190575932}], "350": [{"respuesta": 158.06400544197282}], "400": [{"respuesta": 152.0864865254189}], "450": [{"respuesta": 147.29258215828227}], "500": [{"respuesta": 145.14055702397764}], "550": [{"respuesta": 137.8952737696078}], "600": [{"respuesta": 133.66048738918323}]}}

# Orientacion cabeza corregido
# json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "98.96577000617981"}]}, "400": {"C": [{"result": "c", "confidence": "99.89907145500183"}, {"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "c", "confidence": "99.52154159545898"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.369771820325006, "angulo_head": 87.5300523331937}], "10": [{"angulo_tronco": 70.81309807437854, "angulo_head": 89.00452010982028}], "20": [{"angulo_tronco": 57.60499121819229, "angulo_head": 89.08495068571891}], "30": [{"angulo_tronco": 60.198203558054146, "angulo_head": 89.71413106031916}], "40": [{"angulo_tronco": 56.246825847907665, "angulo_head": 89.47494868341438}], "50": [{"angulo_tronco": 67.54078869094967, "angulo_head": 90.81844559986573}], "60": [{"angulo_tronco": 74.51479631322619, "angulo_head": 91.6880013394336}], "70": [{"angulo_tronco": 81.33269304693415, "angulo_head": 90.8469964272463}], "80": [{"angulo_tronco": 85.71795037936137, "angulo_head": 91.84239470739588}], "90": [{"angulo_tronco": 87.1276039272506, "angulo_head": 92.8724754399312}], "100": [{"angulo_tronco": 98.49062424230087, "angulo_head": 94.54426643509498}], "110": [{"angulo_tronco": 98.30603073498237, "angulo_head": 94.8829428197135}], "120": [{"angulo_tronco": 111.57171680769504, "angulo_head": 96.10453371299376}], "130": [{"angulo_tronco": 110.37020836578205, "angulo_head": 97.50347027495877}], "140": [{"angulo_tronco": 118.97998285730509, "angulo_head": 98.81545335141789}], "150": [{"angulo_tronco": 120.24485515433213, "angulo_head": 98.50465756811306}], "160": [{"angulo_tronco": 124.92572873975226, "angulo_head": 99.22105321263784}], "170": [{"angulo_tronco": 132.47818332218807, "angulo_head": 99.95265779559364}], "180": [{"angulo_tronco": 100.7419386001725, "angulo_head": 101.21205622782031}]}, "300": {"0": [{"angulo_tronco": 97.52022047237222, "angulo_head": 87.08519854422256}], "10": [{"angulo_tronco": 65.35182681661048, "angulo_head": 87.69146651007227}], "20": [{"angulo_tronco": 72.86602242201121, "angulo_head": 87.89113183601702}], "30": [{"angulo_tronco": 65.48778635565908, "angulo_head": 88.01430417141154}], "40": [{"angulo_tronco": 64.0941121926984, "angulo_head": 89.43577773361073}], "50": [{"angulo_tronco": 62.38303276018569, "angulo_head": 90.5542642004435}], "60": [{"angulo_tronco": 67.99989181427077, "angulo_head": 90.45159229494088}], "70": [{"angulo_tronco": 73.49990864800343, "angulo_head": 89.14351412286669}], "80": [{"angulo_tronco": 83.05955215646149, "angulo_head": 92.4764640091408}], "90": [{"angulo_tronco": 88.39047961485466, "angulo_head": 90.88795627205974}], "100": [{"angulo_tronco": 97.05684478362916, "angulo_head": 90.29512620433529}], "110": [{"angulo_tronco": 94.50828396659807, "angulo_head": 90.12239690821868}], "120": [{"angulo_tronco": 101.42371765625869, "angulo_head": 92.01681234959646}], "130": [{"angulo_tronco": 104.07257858209125, "angulo_head": 90.40688344432695}], "140": [{"angulo_tronco": 106.66648427823866, "angulo_head": 90.16473554094674}], "150": [{"angulo_tronco": 115.19341607594099, "angulo_head": 92.18521000854275}], "160": [{"angulo_tronco": 126.5424540089657, "angulo_head": 91.26211132561276}], "170": [{"angulo_tronco": 115.97757469824457, "angulo_head": 91.53478875865589}], "180": [{"angulo_tronco": 106.28936899122475, "angulo_head": 93.40849353145218}]}, "400": {"0": [{"angulo_tronco": 82.77635823447443, "angulo_head": 71.34953408846239}], "10": [{"angulo_tronco": 67.68166654692712, "angulo_head": 109.5345683020479}], "20": [{"angulo_tronco": 65.09853504598162, "angulo_head": 109.37394471257848}], "30": [{"angulo_tronco": 66.42783527091476, "angulo_head": 109.77898780574895}], "40": [{"angulo_tronco": 67.0065854409266, "angulo_head": 88.65094902180313}], "50": [{"angulo_tronco": 72.91359693560067, "angulo_head": 89.30930734230806}], "60": [{"angulo_tronco": 83.29140722915594, "angulo_head": 89.57108926443188}], "70": [{"angulo_tronco": 82.53315845373696, "angulo_head": 89.14662118149877}], "80": [{"angulo_tronco": 75.23873519110978, "angulo_head": 88.71375731771494}], "90": [{"angulo_tronco": 93.18114733293396, "angulo_head": 89.04979017685072}], "100": [{"angulo_tronco": 98.52486770680176, "angulo_head": 88.732777759954}], "110": [{"angulo_tronco": 99.15857068004681, "angulo_head": 88.50074547258421}], "120": [{"angulo_tronco": 103.97991297184565, "angulo_head": 89.13447571467998}], "130": [{"angulo_tronco": 108.86932223570304, "angulo_head": 89.46119778632317}], "140": [{"angulo_tronco": 109.60834830781232, "angulo_head": 88.54425392080324}], "150": [{"angulo_tronco": 111.88551022779723, "angulo_head": 88.82059204009633}], "160": [{"angulo_tronco": 114.71112050905164, "angulo_head": 111.3753323938062}], "170": [{"angulo_tronco": 109.52749429251107, "angulo_head": 111.94468004704441}], "180": [{"angulo_tronco": 81.8107803981284, "angulo_head": 65.50256216659118}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.92099426931794, "angulo_head": 85.53796113616824}], "10": [{"angulo_tronco": 72.07961346282207, "angulo_head": 85.70836014041224}], "20": [{"angulo_tronco": 55.9313969652618, "angulo_head": 87.7103060174855}], "30": [{"angulo_tronco": 60.26720383525337, "angulo_head": 88.74063503472489}], "40": [{"angulo_tronco": 63.4550455908179, "angulo_head": 88.93379979383346}], "50": [{"angulo_tronco": 69.93189638719379, "angulo_head": 89.49783179182783}], "60": [{"angulo_tronco": 77.88956747043983, "angulo_head": 90.1856712708599}], "70": [{"angulo_tronco": 79.01184619685579, "angulo_head": 89.97985004350612}], "80": [{"angulo_tronco": 82.53213066410478, "angulo_head": 90.67122109479968}], "90": [{"angulo_tronco": 87.83573681061891, "angulo_head": 92.37580555281953}], "100": [{"angulo_tronco": 101.09000192100821, "angulo_head": 93.4463139174069}], "110": [{"angulo_tronco": 102.4493289044865, "angulo_head": 93.74741652513187}], "120": [{"angulo_tronco": 109.5526073401955, "angulo_head": 93.90686937460391}], "130": [{"angulo_tronco": 111.91692120995481, "angulo_head": 94.44296182794422}], "140": [{"angulo_tronco": 119.10273617182028, "angulo_head": 94.1572780930094}], "150": [{"angulo_tronco": 128.23062197516253, "angulo_head": 93.81969850805069}], "160": [{"angulo_tronco": 115.66111838804615, "angulo_head": 95.16508762127465}], "170": [{"angulo_tronco": 125.80414251416329, "angulo_head": 96.02135598569315}], "180": [{"angulo_tronco": 94.99243464323857, "angulo_head": 97.71193479184883}]}, "300": {"0": [{"angulo_tronco": 84.41640259668159, "angulo_head": 88.83592679908111}], "10": [{"angulo_tronco": 66.97099161522475, "angulo_head": 88.92887804449137}], "20": [{"angulo_tronco": 62.102079380855706, "angulo_head": 89.55856887490044}], "30": [{"angulo_tronco": 67.36701400290583, "angulo_head": 89.94234462942795}], "40": [{"angulo_tronco": 72.66261497878298, "angulo_head": 90.131203602611}], "50": [{"angulo_tronco": 71.40088565119329, "angulo_head": 89.80102801147873}], "60": [{"angulo_tronco": 69.98876471353135, "angulo_head": 90.42940732917639}], "70": [{"angulo_tronco": 82.19138323109065, "angulo_head": 91.07582260140275}], "80": [{"angulo_tronco": 82.63494008128455, "angulo_head": 91.61132869022676}], "90": [{"angulo_tronco": 87.49838265693285, "angulo_head": 91.87156135278805}], "100": [{"angulo_tronco": 95.05579214486728, "angulo_head": 92.52332925574908}], "110": [{"angulo_tronco": 99.58508597294808, "angulo_head": 92.62636616925754}], "120": [{"angulo_tronco": 107.48302555475833, "angulo_head": 93.08982686522182}], "130": [{"angulo_tronco": 110.04798149250786, "angulo_head": 93.38903656146357}], "140": [{"angulo_tronco": 101.11115259295221, "angulo_head": 93.52940468911436}], "150": [{"angulo_tronco": 114.40839365430682, "angulo_head": 93.19061861983688}], "160": [{"angulo_tronco": 122.51991888781188, "angulo_head": 93.75321522453137}], "170": [{"angulo_tronco": 119.8552333318352, "angulo_head": 94.01060271747927}], "180": [{"angulo_tronco": 173.279406405827, "angulo_head": 94.75605910149962}]}, "400": {"0": [{"angulo_tronco": 89.83560856759611, "angulo_head": 112.43416303003745}], "10": [], "20": [{"angulo_tronco": 57.76819552567765, "angulo_head": 91.34348253346856}], "30": [{"angulo_tronco": 65.85503702733567, "angulo_head": 90.5646313326423}], "40": [{"angulo_tronco": 73.92078950674926, "angulo_head": 91.23126438610034}], "50": [{"angulo_tronco": 76.58914994263759, "angulo_head": 91.71241199158794}], "60": [{"angulo_tronco": 76.06034736859777, "angulo_head": 92.22615546872787}], "70": [{"angulo_tronco": 77.72805648834891, "angulo_head": 92.0705508981916}], "80": [{"angulo_tronco": 82.50724821385249, "angulo_head": 92.12573498394102}], "90": [{"angulo_tronco": 89.53487317294407, "angulo_head": 92.41976457549686}], "100": [{"angulo_tronco": 93.53595024418026, "angulo_head": 92.67457693510327}], "110": [{"angulo_tronco": 106.14010394443157, "angulo_head": 92.72293115840625}], "120": [{"angulo_tronco": 104.56338240946818, "angulo_head": 92.52017858742246}], "130": [{"angulo_tronco": 110.665274531314, "angulo_head": 92.65642445731727}], "140": [{"angulo_tronco": 109.52050327409994, "angulo_head": 93.17599982009651}], "150": [{"angulo_tronco": 111.4763522689236, "angulo_head": 93.19995028541747}], "160": [{"angulo_tronco": 105.2033588160318, "angulo_head": 114.54281143574157}], "170": [{"angulo_tronco": 114.37440492962669, "angulo_head": 115.02366185576808}], "180": []}}, "centroide": {"200": [{"respuesta": 216.64060233635522}], "250": [{"respuesta": 259.1399880877087}], "300": [{"respuesta": 306.79063068092387}], "350": [{"respuesta": 342.6801343789846}], "400": [{"respuesta": 377.5613662155413}], "450": [{"respuesta": 415.04112489642733}], "500": [{"respuesta": 441.8124165441458}], "550": [{"respuesta": 477.6602406760172}], "600": [{"respuesta": 499.8834728819131}]}, "centroide_grupal": {"200": [{"respuesta": 224.25224906674856}], "250": [{"respuesta": 268.1033668961228}], "300": [{"respuesta": 303.9918492577323}, {"respuesta": 303.95930725887615}], "350": [{"respuesta": 348.3723180915337}, {"respuesta": 348.844848163322}], "400": [{"respuesta": 372.6041296801665}], "450": [{"respuesta": 412.35812762253477}, {"respuesta": 412.94155749880474}], "500": [{"respuesta": 437.1967810491018}], "550": [{"respuesta": 467.11374453475923}, {"respuesta": 445.2797370983461}], "600": [{"respuesta": 443.6084868536376}]}, "height_167": {"200": [{"respuesta": 179.42402849906378}], "250": [{"respuesta": 173.5855070746231}], "300": [{"respuesta": 166.98554544711152}], "350": [{"respuesta": 158.1156670455812}], "400": [{"respuesta": 152.08553426638932}], "450": [{"respuesta": 147.34334926917205}], "500": [{"respuesta": 145.0153609286262}], "550": [{"respuesta": 137.89033855041785}], "600": [{"respuesta": 133.62944867223635}]}}

# Correcion de cada vector a la direccion correcta
# json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "99.11893606185913"}]}, "400": {"C": [{"result": "c", "confidence": "99.89907145500183"}, {"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "c", "confidence": "99.52154159545898"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.3683480761488, "angulo_head": 128.2387283121339}], "10": [{"angulo_tronco": 70.8123982077292, "angulo_head": 129.25777545101752}], "20": [{"angulo_tronco": 57.59999142871085, "angulo_head": 139.43190008549254}], "30": [{"angulo_tronco": 60.21681895180247, "angulo_head": 16.91110089285148}], "40": [{"angulo_tronco": 56.25518138676701, "angulo_head": 101.83274069091438}], "50": [{"angulo_tronco": 67.5387265336684, "angulo_head": 150.22274969910455}], "60": [{"angulo_tronco": 74.51542471912602, "angulo_head": 107.70762061963217}], "70": [{"angulo_tronco": 81.33691819635519, "angulo_head": 2.053833812582674}], "80": [{"angulo_tronco": 85.72642289681373, "angulo_head": 17.01087926228247}], "90": [{"angulo_tronco": 87.12519318988312, "angulo_head": 125.36970123182748}], "100": [{"angulo_tronco": 98.47746741378067, "angulo_head": 146.28409066155785}], "110": [{"angulo_tronco": 98.30632294015273, "angulo_head": 72.24364986294414}], "120": [{"angulo_tronco": 111.57307331631463, "angulo_head": 67.54323910868726}], "130": [{"angulo_tronco": 110.3677092310998, "angulo_head": 41.08889794706059}], "140": [{"angulo_tronco": 118.9937852115873, "angulo_head": 63.18924156204395}], "150": [{"angulo_tronco": 120.27540879590806, "angulo_head": 48.43207865996261}], "160": [{"angulo_tronco": 124.9528029556145, "angulo_head": 59.67877237169085}], "170": [{"angulo_tronco": 132.46103855789207, "angulo_head": 65.25835691441995}], "180": [{"angulo_tronco": 100.66419711084059, "angulo_head": 62.68865418957765}]}, "300": {"0": [{"angulo_tronco": 97.41129960784289, "angulo_head": 131.3940277946023}], "10": [{"angulo_tronco": 65.34649649797753, "angulo_head": 133.47229405210035}], "20": [{"angulo_tronco": 72.84886667199328, "angulo_head": 133.62427397652507}], "30": [{"angulo_tronco": 65.44291769987201, "angulo_head": 123.90830800691761}], "40": [{"angulo_tronco": 64.09448848244429, "angulo_head": 110.89150085861365}], "50": [{"angulo_tronco": 62.40013038103276, "angulo_head": 123.73041371382631}], "60": [{"angulo_tronco": 67.99180464903682, "angulo_head": 141.96243485297637}], "70": [{"angulo_tronco": 73.52683798086836, "angulo_head": 152.71913779616574}], "80": [{"angulo_tronco": 83.06499872377597, "angulo_head": 21.74771636706872}], "90": [{"angulo_tronco": 88.37868661032034, "angulo_head": 70.24904468197559}], "100": [{"angulo_tronco": 97.05039697431143, "angulo_head": 169.36814054041366}], "110": [{"angulo_tronco": 94.50184950487024, "angulo_head": 25.919644897633155}], "120": [{"angulo_tronco": 101.43806326723391, "angulo_head": 20.026054984321334}], "130": [{"angulo_tronco": 104.07716134127735, "angulo_head": 159.91737000363395}], "140": [{"angulo_tronco": 106.65294145319271, "angulo_head": 42.14618216202447}], "150": [{"angulo_tronco": 115.2414174237012, "angulo_head": 53.49930699172382}], "160": [{"angulo_tronco": 126.53053075029298, "angulo_head": 161.4866833564643}], "170": [{"angulo_tronco": 115.96968994879079, "angulo_head": 50.85338869398715}], "180": [{"angulo_tronco": 105.67096311050207, "angulo_head": 55.66755725887713}]}, "400": {"0": [{"angulo_tronco": 82.27743531993403, "angulo_head": 4.282097580996667}], "10": [{"angulo_tronco": 67.7263389171777, "angulo_head": 11.355118478240497}], "20": [{"angulo_tronco": 64.9890650366771, "angulo_head": 8.864255062394733}], "30": [{"angulo_tronco": 66.40573961269061, "angulo_head": 8.799303853869464}], "40": [{"angulo_tronco": 67.03889297088053, "angulo_head": 149.93840724017087}], "50": [{"angulo_tronco": 72.94758186014053, "angulo_head": 5.009139675150163}], "60": [{"angulo_tronco": 83.3829982003411, "angulo_head": 127.84121418148256}], "70": [{"angulo_tronco": 82.52057577564675, "angulo_head": 164.71156920264008}], "80": [{"angulo_tronco": 75.23804326806456, "angulo_head": 27.467685410663112}], "90": [{"angulo_tronco": 93.1731295282342, "angulo_head": 47.86116696026509}], "100": [{"angulo_tronco": 98.50210433183551, "angulo_head": 171.24920193213845}], "110": [{"angulo_tronco": 99.08737744349399, "angulo_head": 66.13643305221682}], "120": [{"angulo_tronco": 103.96192258728466, "angulo_head": 170.34478587569834}], "130": [{"angulo_tronco": 108.87228012697945, "angulo_head": 28.716921824506446}], "140": [{"angulo_tronco": 109.58879741117026, "angulo_head": 69.30981382247492}], "150": [{"angulo_tronco": 111.84561820395542, "angulo_head": 56.15444431458047}], "160": [{"angulo_tronco": 114.7427200577543, "angulo_head": 174.9993762016807}], "170": [{"angulo_tronco": 109.4067330438046, "angulo_head": 175.35655968762052}], "180": [{"angulo_tronco": 81.88117199117411, "angulo_head": 6.33096899249948}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.88096500375055, "angulo_head": 128.95695314257938}], "10": [{"angulo_tronco": 72.08838825122798, "angulo_head": 130.49798502438114}], "20": [{"angulo_tronco": 55.94104727747674, "angulo_head": 136.88651515178435}], "30": [{"angulo_tronco": 60.27382296111582, "angulo_head": 144.47616868095676}], "40": [{"angulo_tronco": 63.451579819142616, "angulo_head": 14.006670183084479}], "50": [{"angulo_tronco": 69.92906074868412, "angulo_head": 142.3068820099229}], "60": [{"angulo_tronco": 77.91687015977317, "angulo_head": 152.60228835050776}], "70": [{"angulo_tronco": 79.01011553970679, "angulo_head": 32.74920346762892}], "80": [{"angulo_tronco": 82.51695304347147, "angulo_head": 116.59244106961161}], "90": [{"angulo_tronco": 87.85871490611206, "angulo_head": 153.01119825101122}], "100": [{"angulo_tronco": 101.10793886746433, "angulo_head": 167.5977417180566}], "110": [{"angulo_tronco": 102.45843160585324, "angulo_head": 60.63393556200141}], "120": [{"angulo_tronco": 109.57514260774555, "angulo_head": 48.31160851955266}], "130": [{"angulo_tronco": 111.92133368285572, "angulo_head": 52.69541870130867}], "140": [{"angulo_tronco": 119.0770109819242, "angulo_head": 56.09008994959512}], "150": [{"angulo_tronco": 128.24500728882904, "angulo_head": 63.19099094932065}], "160": [{"angulo_tronco": 115.654119245781, "angulo_head": 49.22427245346189}], "170": [{"angulo_tronco": 125.81055749701922, "angulo_head": 63.673641377780335}], "180": [{"angulo_tronco": 94.98666886648654, "angulo_head": 55.257389901534886}]}, "300": {"0": [{"angulo_tronco": 84.16608641442251, "angulo_head": 127.46534699374062}], "10": [{"angulo_tronco": 66.98510746201973, "angulo_head": 133.64164324214758}], "20": [{"angulo_tronco": 62.09800833136173, "angulo_head": 140.61753376437406}], "30": [{"angulo_tronco": 67.33401805999557, "angulo_head": 153.1185648783618}], "40": [{"angulo_tronco": 72.64823278292367, "angulo_head": 154.57237881878197}], "50": [{"angulo_tronco": 71.41224155038617, "angulo_head": 143.34165983623245}], "60": [{"angulo_tronco": 70.007585328923, "angulo_head": 9.510202965610413}], "70": [{"angulo_tronco": 82.19956285805227, "angulo_head": 19.38488635521238}], "80": [{"angulo_tronco": 82.61482403068887, "angulo_head": 132.4579758288964}], "90": [{"angulo_tronco": 87.48645286954518, "angulo_head": 90.81049227707739}], "100": [{"angulo_tronco": 95.03691553085844, "angulo_head": 162.46220557779097}], "110": [{"angulo_tronco": 99.56495816807829, "angulo_head": 175.8762009941926}], "120": [{"angulo_tronco": 107.49733079839984, "angulo_head": 175.56063825298736}], "130": [{"angulo_tronco": 110.03861435061614, "angulo_head": 75.6871396895118}], "140": [{"angulo_tronco": 101.13941013597895, "angulo_head": 40.85294408965905}], "150": [{"angulo_tronco": 114.37795384717731, "angulo_head": 40.75972868813441}], "160": [{"angulo_tronco": 122.55628113344865, "angulo_head": 56.989283176746845}], "170": [{"angulo_tronco": 119.90949013817756, "angulo_head": 46.50378342359316}], "180": [{"angulo_tronco": 173.13081664784826, "angulo_head": 131.19316656321774}]}, "400": {"0": [{"angulo_tronco": 89.84172954465465, "angulo_head": 10.860117088119035}], "10": [], "20": [{"angulo_tronco": 57.74271966792117, "angulo_head": 137.9513581709052}], "30": [{"angulo_tronco": 65.83372690089243, "angulo_head": 4.784654247623673}], "40": [{"angulo_tronco": 73.93383846546116, "angulo_head": 7.994549755826091}], "50": [{"angulo_tronco": 76.58631583604048, "angulo_head": 7.447357663006766}], "60": [{"angulo_tronco": 76.06499389733759, "angulo_head": 4.726397856678527}], "70": [{"angulo_tronco": 77.59168627624904, "angulo_head": 21.895633422309487}], "80": [{"angulo_tronco": 82.50010419840002, "angulo_head": 0.5583772953136971}], "90": [{"angulo_tronco": 89.59588718175772, "angulo_head": 158.13664016750764}], "100": [{"angulo_tronco": 93.54751971839022, "angulo_head": 155.37429626440615}], "110": [{"angulo_tronco": 106.16491884161599, "angulo_head": 177.58402337447367}], "120": [{"angulo_tronco": 104.55913130013388, "angulo_head": 147.46012199891416}], "130": [{"angulo_tronco": 110.69603702145852, "angulo_head": 155.65106801460058}], "140": [{"angulo_tronco": 109.40046464654779, "angulo_head": 176.26133799716192}], "150": [{"angulo_tronco": 111.49018280388718, "angulo_head": 36.14839570749443}], "160": [{"angulo_tronco": 105.1164135640267, "angulo_head": 175.58314051584458}], "170": [{"angulo_tronco": 114.40387992090284, "angulo_head": 175.71259984471027}], "180": []}}, "centroide": {"200": [{"respuesta": 216.63879867935145}], "250": [{"respuesta": 259.13865038234394}], "300": [{"respuesta": 306.78870873061703}], "350": [{"respuesta": 342.68348080072707}], "400": [{"respuesta": 377.5574880123577}], "450": [{"respuesta": 415.0361971647985}], "500": [{"respuesta": 441.8155656757205}], "550": [{"respuesta": 477.68021102271246}], "600": [{"respuesta": 499.88102127844775}]}, "centroide_grupal": {"200": [{"respuesta": 224.2526016009238}], "250": [{"respuesta": 268.1045829296296}], "300": [{"respuesta": 303.9934720520746}, {"respuesta": 303.9601376706163}], "350": [{"respuesta": 348.3720014417921}, {"respuesta": 348.8426765608589}], "400": [{"respuesta": 372.6042806039072}], "450": [{"respuesta": 412.3515018518759}, {"respuesta": 412.9341552383284}], "500": [{"respuesta": 437.2028724640107}], "550": [{"respuesta": 467.107185606698}, {"respuesta": 445.28215928085467}], "600": [{"respuesta": 443.61411044088027}]}, "height_167": {"200": [{"respuesta": 179.42009758553291}], "250": [{"respuesta": 173.58714914099548}], "300": [{"respuesta": 166.983210303634}], "350": [{"respuesta": 158.1164192469068}], "400": [{"respuesta": 152.07786777945353}], "450": [{"respuesta": 147.33796053345975}], "500": [{"respuesta": 145.03904893140728}], "550": [{"respuesta": 137.89411945931414}], "600": [{"respuesta": 133.59932700524024}]}}

# Selective con eliminacion de recta mas larga
# json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "l", "confidence": "94.90298628807068"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.68764781951904"}, {"result": "i", "confidence": "54.89735007286072"}, {"result": "l", "confidence": "51.197320222854614"}, {"result": "i", "confidence": "75.51838755607605"}]}, "400": {"C": [{"result": "c", "confidence": "99.89907145500183"}, {"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.69454407691956"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "l", "confidence": "87.46050596237183"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "82.42610096931458"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "96.72553539276123"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "c", "confidence": "99.52154159545898"}, {"result": "i", "confidence": "99.83118772506714"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "99.97468590736389"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "88.83863687515259"}, {"result": "i", "confidence": "99.65736865997314"}, {"result": "i", "confidence": "99.60086345672607"}, {"result": "l", "confidence": "78.88910174369812"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.36899178336337, "angulo_head": 127.4660729590205}], "10": [{"angulo_tronco": 70.79361021916978, "angulo_head": 130.99738455733112}], "20": [{"angulo_tronco": 57.62796171972494, "angulo_head": 140.04236005772086}], "30": [{"angulo_tronco": 60.217623734986326, "angulo_head": 29.89235046994359}], "40": [{"angulo_tronco": 56.245095240677, "angulo_head": 28.223253671130145}], "50": [{"angulo_tronco": 67.54084758283793, "angulo_head": 155.08863304445822}], "60": [{"angulo_tronco": 74.52275698402178, "angulo_head": 7.178027396236668}], "70": [{"angulo_tronco": 81.32994438980046, "angulo_head": 8.582518351750844}], "80": [{"angulo_tronco": 85.72385922699394, "angulo_head": 21.92825353150941}], "90": [{"angulo_tronco": 87.13802745528008, "angulo_head": 19.884166291572843}], "100": [{"angulo_tronco": 98.4810321237003, "angulo_head": 135.65530564071082}], "110": [{"angulo_tronco": 98.31222178879548, "angulo_head": 171.92918373781183}], "120": [{"angulo_tronco": 111.56774323623306, "angulo_head": 167.41959842170104}], "130": [{"angulo_tronco": 110.3872559533334, "angulo_head": 30.339590402875075}], "140": [{"angulo_tronco": 118.99704216257895, "angulo_head": 35.39684546529204}], "150": [{"angulo_tronco": 120.26218071604913, "angulo_head": 40.234613211179045}], "160": [{"angulo_tronco": 124.93862551206787, "angulo_head": 55.33273464205321}], "170": [{"angulo_tronco": 132.4759383983803, "angulo_head": 61.566324909114385}], "180": [{"angulo_tronco": 100.76696633483162, "angulo_head": 60.41734289416172}]}, "300": {"0": [{"angulo_tronco": 97.41241931289825, "angulo_head": 133.05958040992684}], "10": [{"angulo_tronco": 65.26528654541383, "angulo_head": 135.8090976258977}], "20": [{"angulo_tronco": 72.85711321436276, "angulo_head": 143.94003630081488}], "30": [{"angulo_tronco": 65.46039568000683, "angulo_head": 141.8912993176647}], "40": [{"angulo_tronco": 64.08590927207855, "angulo_head": 144.33955097960106}], "50": [{"angulo_tronco": 62.39809428828664, "angulo_head": 129.3534380206977}], "60": [{"angulo_tronco": 67.98562988103437, "angulo_head": 144.3046007742989}], "70": [{"angulo_tronco": 73.49200274273754, "angulo_head": 155.2345880877011}], "80": [{"angulo_tronco": 83.06754964227468, "angulo_head": 17.071835603037236}], "90": [{"angulo_tronco": 88.38774067483423, "angulo_head": 77.36128012591115}], "100": [{"angulo_tronco": 97.03604066959062, "angulo_head": 170.52610249429853}], "110": [{"angulo_tronco": 94.50072556089943, "angulo_head": 29.761781814851055}], "120": [{"angulo_tronco": 101.42103807051484, "angulo_head": 14.883974471560727}], "130": [{"angulo_tronco": 104.0717747134406, "angulo_head": 47.277893937651804}], "140": [{"angulo_tronco": 106.67927310464337, "angulo_head": 49.71659052594146}], "150": [{"angulo_tronco": 115.27594868110519, "angulo_head": 46.40074356536961}], "160": [{"angulo_tronco": 126.53726741465525, "angulo_head": 159.75106336627653}], "170": [{"angulo_tronco": 115.97754736848053, "angulo_head": 47.501385996991075}], "180": [{"angulo_tronco": 105.7790142556621, "angulo_head": 53.84941106919289}]}, "400": {"0": [{"angulo_tronco": 82.53252356947046, "angulo_head": 30.47492817174882}], "10": [{"angulo_tronco": 68.56208698299142, "angulo_head": 134.48982241550067}], "20": [{"angulo_tronco": 65.06828345733337, "angulo_head": 148.15510168839393}], "30": [{"angulo_tronco": 66.43426122448054, "angulo_head": 148.98919333510665}], "40": [{"angulo_tronco": 67.01854014760798, "angulo_head": 154.2537738422565}], "50": [{"angulo_tronco": 72.9120273781693, "angulo_head": 1.2132114781726224}], "60": [{"angulo_tronco": 83.30935721488217, "angulo_head": 130.70748411321796}], "70": [{"angulo_tronco": 82.51363677374164, "angulo_head": 172.139499559968}], "80": [{"angulo_tronco": 75.169883775055, "angulo_head": 31.07447380423142}], "90": [{"angulo_tronco": 93.15690513844686, "angulo_head": 52.444637362469216}], "100": [{"angulo_tronco": 98.54634040900972, "angulo_head": 168.87168779757405}], "110": [{"angulo_tronco": 99.09572494333167, "angulo_head": 86.75225441207776}], "120": [{"angulo_tronco": 103.91993065119236, "angulo_head": 167.0670012294127}], "130": [{"angulo_tronco": 108.90507030379446, "angulo_head": 25.16775260588543}], "140": [{"angulo_tronco": 109.67099472250747, "angulo_head": 56.03735573273618}], "150": [{"angulo_tronco": 111.83363669752113, "angulo_head": 38.57877587897342}], "160": [{"angulo_tronco": 114.79794703988475, "angulo_head": 33.27183465536588}], "170": [{"angulo_tronco": 109.55034489038717, "angulo_head": 45.021547548161394}], "180": [{"angulo_tronco": 81.77628888386502, "angulo_head": 100.74319788503416}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.94527636482607, "angulo_head": 130.73887801763544}], "10": [{"angulo_tronco": 72.10571281212185, "angulo_head": 133.3694250370807}], "20": [{"angulo_tronco": 55.94032108465598, "angulo_head": 139.28003964357666}], "30": [{"angulo_tronco": 60.27994250963532, "angulo_head": 147.63815882181234}], "40": [{"angulo_tronco": 63.45845175619532, "angulo_head": 10.057272806016538}], "50": [{"angulo_tronco": 69.96024434973961, "angulo_head": 17.433044724020846}], "60": [{"angulo_tronco": 77.87713157800641, "angulo_head": 159.3151228224742}], "70": [{"angulo_tronco": 79.01129449596806, "angulo_head": 35.269333830739626}], "80": [{"angulo_tronco": 82.52570382831696, "angulo_head": 32.84729111054727}], "90": [{"angulo_tronco": 87.8468545886438, "angulo_head": 91.78814088537024}], "100": [{"angulo_tronco": 101.0925015012265, "angulo_head": 143.332865845173}], "110": [{"angulo_tronco": 102.44660083814304, "angulo_head": 170.03058729686865}], "120": [{"angulo_tronco": 109.5689300600874, "angulo_head": 27.06070402681676}], "130": [{"angulo_tronco": 111.91763630779256, "angulo_head": 43.8055910449635}], "140": [{"angulo_tronco": 119.09519517345886, "angulo_head": 153.2385667526894}], "150": [{"angulo_tronco": 128.24322054102987, "angulo_head": 52.43492111007117}], "160": [{"angulo_tronco": 115.65024648877653, "angulo_head": 43.79806316725263}], "170": [{"angulo_tronco": 125.81515886304862, "angulo_head": 59.483490775696126}], "180": [{"angulo_tronco": 94.99519303275605, "angulo_head": 53.681006965352914}]}, "300": {"0": [{"angulo_tronco": 84.25762989199062, "angulo_head": 129.64861482425752}], "10": [{"angulo_tronco": 66.98970313084108, "angulo_head": 133.92332638366395}], "20": [{"angulo_tronco": 62.1129051160451, "angulo_head": 143.81360227707506}], "30": [{"angulo_tronco": 67.33829682189446, "angulo_head": 153.7790235353387}], "40": [{"angulo_tronco": 72.65773567044462, "angulo_head": 162.14749843909797}], "50": [{"angulo_tronco": 71.40880947457678, "angulo_head": 14.287025383847274}], "60": [{"angulo_tronco": 69.9976533522752, "angulo_head": 15.136428266018271}], "70": [{"angulo_tronco": 82.19753271949237, "angulo_head": 26.44516151191186}], "80": [{"angulo_tronco": 82.61604403662837, "angulo_head": 51.799784621423626}], "90": [{"angulo_tronco": 87.47568975238738, "angulo_head": 91.19305499510452}], "100": [{"angulo_tronco": 95.03510061873972, "angulo_head": 151.30123353361995}], "110": [{"angulo_tronco": 99.57009002423875, "angulo_head": 173.63448028006522}], "120": [{"angulo_tronco": 107.47384254624201, "angulo_head": 179.22851402571558}], "130": [{"angulo_tronco": 110.06750874157446, "angulo_head": 176.42936978712376}], "140": [{"angulo_tronco": 101.0405549911366, "angulo_head": 29.11729825750635}], "150": [{"angulo_tronco": 114.43936481522096, "angulo_head": 31.43036927041406}], "160": [{"angulo_tronco": 122.53742201376635, "angulo_head": 42.78217922344147}], "170": [{"angulo_tronco": 119.92637084829796, "angulo_head": 41.464696433246075}], "180": [{"angulo_tronco": 173.1973881282809, "angulo_head": 133.0191634042605}]}, "400": {"0": [{"angulo_tronco": 89.86344256719322, "angulo_head": 133.23526159662808}], "10": [], "20": [{"angulo_tronco": 57.8190091034504, "angulo_head": 141.2007792694014}], "30": [{"angulo_tronco": 65.83543756971463, "angulo_head": 22.0515048719554}], "40": [{"angulo_tronco": 73.87141441106483, "angulo_head": 4.567126014866288}], "50": [{"angulo_tronco": 76.58532794220973, "angulo_head": 11.305091061430007}], "60": [{"angulo_tronco": 76.08295734726337, "angulo_head": 12.715002273885364}], "70": [{"angulo_tronco": 77.6951416504534, "angulo_head": 26.064971456666736}], "80": [{"angulo_tronco": 82.53760552723409, "angulo_head": 0.4463607411763678}], "90": [{"angulo_tronco": 89.58409201839868, "angulo_head": 72.89341109718055}], "100": [{"angulo_tronco": 93.44027782038272, "angulo_head": 150.11880567109796}], "110": [{"angulo_tronco": 106.11330898453775, "angulo_head": 167.4243871522169}], "120": [{"angulo_tronco": 104.57679209833623, "angulo_head": 149.5771520065856}], "130": [{"angulo_tronco": 110.6235345011007, "angulo_head": 152.6542531471694}], "140": [{"angulo_tronco": 109.4660862811248, "angulo_head": 163.17314492155336}], "150": [{"angulo_tronco": 111.42676349662273, "angulo_head": 35.03218424460436}], "160": [{"angulo_tronco": 105.16075615769046, "angulo_head": 42.763561420481174}], "170": [{"angulo_tronco": 114.35215831701879, "angulo_head": 44.30012396857584}], "180": []}}, "centroide": {"200": [{"respuesta": 216.6390520168943}], "250": [{"respuesta": 259.1388055702122}], "300": [{"respuesta": 306.7918231730864}], "350": [{"respuesta": 342.6789730288077}], "400": [{"respuesta": 377.5612655762298}], "450": [{"respuesta": 415.0332937305916}], "500": [{"respuesta": 441.8148523035795}], "550": [{"respuesta": 477.66935460186244}], "600": [{"respuesta": 499.89450334674206}]}, "centroide_grupal": {"200": [{"respuesta": 224.25181061488504}], "250": [{"respuesta": 268.10307129222616}], "300": [{"respuesta": 303.9944959634947}, {"respuesta": 303.9581833897481}], "350": [{"respuesta": 348.3738213206875}, {"respuesta": 348.84863375406934}], "400": [{"respuesta": 372.6033669273145}], "450": [{"respuesta": 412.3573584820789}, {"respuesta": 412.94112742883925}], "500": [{"respuesta": 437.2049618609068}], "550": [{"respuesta": 467.11516475834316}, {"respuesta": 445.2859826392763}], "600": [{"respuesta": 443.62385915328025}]}, "height_167": {"200": [{"respuesta": 179.41929948751593}], "250": [{"respuesta": 173.5936229186919}], "300": [{"respuesta": 166.9814179481329}], "350": [{"respuesta": 158.08538055382968}], "400": [{"respuesta": 152.08271599638007}], "450": [{"respuesta": 147.31500343732748}], "500": [{"respuesta": 145.08508520133208}], "550": [{"respuesta": 137.89219148758013}], "600": [{"respuesta": 133.58154913602985}]}}


# SELECTIVE con el modelo de yolo mas grande y solo el promedio de todos los puntos de la cabeza
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "92.3799216747284"}, {"result": "c", "confidence": "99.93988275527954"}, {"result": "c", "confidence": "89.91405367851257"}, {"result": "c", "confidence": "96.72872424125671"}, {"result": "c", "confidence": "99.93389248847961"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "90.43493270874023"}, {"result": "c", "confidence": "70.06658911705017"}], "L": [{"result": "l", "confidence": "99.51462149620056"}, {"result": "i", "confidence": "85.79096794128418"}, {"result": "c", "confidence": "97.05079793930054"}, {"result": "l", "confidence": "99.1970419883728"}, {"result": "l", "confidence": "88.92841935157776"}, {"result": "l", "confidence": "99.53547716140747"}, {"result": "c", "confidence": "88.88895511627197"}], "I": [{"result": "i", "confidence": "53.639888763427734"}, {"result": "c", "confidence": "81.54907822608948"}, {"result": "c", "confidence": "94.46764588356018"}, {"result": "i", "confidence": "99.80781078338623"}, {"result": "i", "confidence": "58.3850622177124"}, {"result": "c", "confidence": "90.22946357727051"}, {"result": "i", "confidence": "97.94939756393433"}]}, "400": {"C": [{"result": "c", "confidence": "99.89487528800964"}, {"result": "c", "confidence": "99.38585162162781"}, {"result": "c", "confidence": "99.69425797462463"}, {"result": "l", "confidence": "81.30024671554565"}, {"result": "c", "confidence": "99.85753297805786"}], "L": [{"result": "l", "confidence": "99.37485456466675"}, {"result": "l", "confidence": "99.27632212638855"}, {"result": "l", "confidence": "97.52500057220459"}, {"result": "l", "confidence": "97.86285161972046"}, {"result": "l", "confidence": "99.15781021118164"}, {"result": "l", "confidence": "98.86634945869446"}, {"result": "l", "confidence": "99.5371401309967"}], "I": [{"result": "i", "confidence": "76.18757486343384"}, {"result": "i", "confidence": "95.75640559196472"}, {"result": "i", "confidence": "99.8844861984253"}, {"result": "i", "confidence": "99.94946718215942"}, {"result": "c", "confidence": "90.88532328605652"}, {"result": "i", "confidence": "99.92997646331787"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99682903289795"}, {"result": "c", "confidence": "99.9843955039978"}, {"result": "c", "confidence": "99.95174407958984"}, {"result": "c", "confidence": "99.99668598175049"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "97.11640477180481"}, {"result": "c", "confidence": "91.4011538028717"}, {"result": "c", "confidence": "97.95340299606323"}, {"result": "l", "confidence": "98.7933874130249"}, {"result": "c", "confidence": "97.36284017562866"}, {"result": "c", "confidence": "99.08254742622375"}, {"result": "c", "confidence": "54.50602173805237"}], "I": [{"result": "i", "confidence": "99.49933886528015"}, {"result": "i", "confidence": "99.76714253425598"}, {"result": "i", "confidence": "99.420565366745"}, {"result": "i", "confidence": "99.94149208068848"}, {"result": "i", "confidence": "98.83014559745789"}, {"result": "i", "confidence": "99.55260157585144"}]}, "400": {"C": [{"result": "i", "confidence": "91.1717414855957"}, {"result": "c", "confidence": "99.982351064682"}, {"result": "c", "confidence": "99.98631477355957"}, {"result": "c", "confidence": "99.96824264526367"}, {"result": "c", "confidence": "99.99147653579712"}, {"result": "c", "confidence": "99.98775720596313"}], "L": [{"result": "l", "confidence": "58.10627341270447"}, {"result": "c", "confidence": "91.647207736969"}, {"result": "l", "confidence": "74.11438822746277"}, {"result": "c", "confidence": "96.13969922065735"}, {"result": "i", "confidence": "96.70355319976807"}, {"result": "c", "confidence": "88.14548850059509"}, {"result": "l", "confidence": "96.93432450294495"}], "I": [{"result": "i", "confidence": "99.81889128684998"}, {"result": "i", "confidence": "97.9246437549591"}, {"result": "i", "confidence": "98.95510077476501"}, {"result": "i", "confidence": "99.69558715820312"}, {"result": "i", "confidence": "99.78197813034058"}, {"result": "i", "confidence": "99.75827932357788"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 69.93462007771066, "angulo_head": 75.85994795407733}], "10": [{"angulo_tronco": 71.49160009267572, "angulo_head": 77.8469019408021}], "20": [{"angulo_tronco": 55.482925062001954, "angulo_head": 77.8110908144458}], "30": [{"angulo_tronco": 53.260228873179294, "angulo_head": 79.84615407088256}], "40": [{"angulo_tronco": 52.91032398894187, "angulo_head": 81.40996398835959}], "50": [{"angulo_tronco": 66.17691173714246, "angulo_head": 82.97008776609182}], "60": [{"angulo_tronco": 71.87552615196047, "angulo_head": 85.35500988796329}], "70": [{"angulo_tronco": 78.87561321615115, "angulo_head": 84.706604039503}], "80": [{"angulo_tronco": 84.0611112521616, "angulo_head": 86.68793087832981}], "90": [{"angulo_tronco": 86.47379042956298, "angulo_head": 88.73601584001875}], "100": [{"angulo_tronco": 98.66440654290221, "angulo_head": 92.58184458635904}], "110": [{"angulo_tronco": 98.92131354477128, "angulo_head": 91.92931008825241}], "120": [{"angulo_tronco": 112.18662245094076, "angulo_head": 94.36283118217708}], "130": [{"angulo_tronco": 113.93515843358479, "angulo_head": 94.54137840900944}], "140": [{"angulo_tronco": 122.50057576468298, "angulo_head": 96.28981170503558}], "150": [{"angulo_tronco": 123.83113400063976, "angulo_head": 96.47204382501454}], "160": [{"angulo_tronco": 125.90247977501778, "angulo_head": 96.83533383672601}], "170": [{"angulo_tronco": 94.44644507583529, "angulo_head": 122.38398595651043}], "180": [{"angulo_tronco": 76.94447250300999, "angulo_head": 99.07399919746106}]}, "300": {"0": [{"angulo_tronco": 86.46635239000403, "angulo_head": 74.24468299753012}], "10": [{"angulo_tronco": 64.19146320660639, "angulo_head": 74.918926614287}], "20": [{"angulo_tronco": 70.24275296577072, "angulo_head": 75.84936652002546}], "30": [{"angulo_tronco": 66.06669909790952, "angulo_head": 76.68630664231772}], "40": [{"angulo_tronco": 89.44314582304168, "angulo_head": 147.6527901586954}], "50": [{"angulo_tronco": 61.80095914652851, "angulo_head": 90.45203174660529}], "60": [{"angulo_tronco": 67.76812955123269, "angulo_head": 86.51620863415638}], "70": [{"angulo_tronco": 72.43940774037036, "angulo_head": 75.80756545820915}], "80": [{"angulo_tronco": 81.70996496838313, "angulo_head": 97.31778003324806}], "90": [{"angulo_tronco": 87.37962773839362, "angulo_head": 89.09068125132339}], "100": [{"angulo_tronco": 98.09736686331848, "angulo_head": 85.13425806909606}], "110": [{"angulo_tronco": 96.52708193842784, "angulo_head": 84.48591398068898}], "120": [{"angulo_tronco": 100.31704908255351, "angulo_head": 98.2808267507576}], "130": [{"angulo_tronco": 105.23738326038682, "angulo_head": 87.59316568353371}], "140": [{"angulo_tronco": 106.94232063545552, "angulo_head": 85.87098189030958}], "150": [{"angulo_tronco": 114.9122527716914, "angulo_head": 99.09638504784843}], "160": [{"angulo_tronco": 124.56293416377535, "angulo_head": 94.41768732139568}], "170": [{"angulo_tronco": 109.90498352052253, "angulo_head": 96.6024747861725}], "180": [{"angulo_tronco": 101.39833021564874, "angulo_head": 102.23626196024995}]}, "400": {"0": [{"angulo_tronco": 71.06891110419049, "angulo_head": 139.3304152667407}], "10": [{"angulo_tronco": 75.94561381443897, "angulo_head": 139.91591179770646}], "20": [{"angulo_tronco": 66.61847370243497, "angulo_head": 79.14593058014725}], "30": [{"angulo_tronco": 65.6890500048676, "angulo_head": 139.29846448109623}], "40": [{"angulo_tronco": 66.85510556822466, "angulo_head": 81.9636868177107}], "50": [{"angulo_tronco": 73.12686906860309, "angulo_head": 86.3637491727075}], "60": [{"angulo_tronco": 84.20570038136853, "angulo_head": 87.04784766867346}], "70": [{"angulo_tronco": 81.32421423423554, "angulo_head": 89.78907198470574}], "80": [{"angulo_tronco": 74.96002605303372, "angulo_head": 84.23904652253475}], "90": [{"angulo_tronco": 92.0547383329028, "angulo_head": 88.59655590032233}], "100": [{"angulo_tronco": 97.976795739204, "angulo_head": 89.00963242284656}], "110": [{"angulo_tronco": 100.01223809881415, "angulo_head": 88.07071945861024}], "120": [{"angulo_tronco": 101.67319893835543, "angulo_head": 90.95595228375164}], "130": [{"angulo_tronco": 111.22051415507323, "angulo_head": 98.46194013864493}], "140": [{"angulo_tronco": 111.33815962336715, "angulo_head": 87.99925462354093}], "150": [{"angulo_tronco": 109.99425605146212, "angulo_head": 90.27066563838929}], "160": [{"angulo_tronco": 112.8974334647203, "angulo_head": 141.84946186145353}], "170": [{"angulo_tronco": 102.82777415029615, "angulo_head": 142.06214407253813}], "180": [{"angulo_tronco": 117.6062034822875, "angulo_head": 142.32280291644645}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 69.45190675351087, "angulo_head": 77.78871440189528}], "10": [{"angulo_tronco": 69.21063525054122, "angulo_head": 79.23917023563652}], "20": [{"angulo_tronco": 52.58014667960127, "angulo_head": 80.06893149741097}], "30": [{"angulo_tronco": 58.11057147169497, "angulo_head": 81.61587632976115}], "40": [{"angulo_tronco": 62.240907559482146, "angulo_head": 80.99814534303724}], "50": [{"angulo_tronco": 69.39287734415771, "angulo_head": 83.14109929043308}], "60": [{"angulo_tronco": 76.92849926721539, "angulo_head": 84.88503836524436}], "70": [{"angulo_tronco": 78.61662578537009, "angulo_head": 84.05970232697929}], "80": [{"angulo_tronco": 81.95152524082991, "angulo_head": 85.96741486147255}], "90": [{"angulo_tronco": 88.29828374447624, "angulo_head": 89.75042663882267}], "100": [{"angulo_tronco": 101.0724107129542, "angulo_head": 92.91487028808693}], "110": [{"angulo_tronco": 101.94389750752674, "angulo_head": 93.95386839031636}], "120": [{"angulo_tronco": 109.57007383561255, "angulo_head": 94.12182747582384}], "130": [{"angulo_tronco": 112.41761033951094, "angulo_head": 94.89517998262639}], "140": [{"angulo_tronco": 118.81476582088328, "angulo_head": 95.93318014270778}], "150": [{"angulo_tronco": 128.2253582167361, "angulo_head": 95.46174589561345}], "160": [{"angulo_tronco": 124.35034706340242, "angulo_head": 97.40993066861786}], "170": [{"angulo_tronco": 121.68116763607162, "angulo_head": 97.61140809870749}], "180": [{"angulo_tronco": 68.80567007324937, "angulo_head": 100.65637599721667}]}, "300": {"0": [{"angulo_tronco": 72.88642104924763, "angulo_head": 77.94573788886585}], "10": [{"angulo_tronco": 68.11057745843445, "angulo_head": 78.03383481252098}], "20": [{"angulo_tronco": 61.17892575713647, "angulo_head": 78.97800777579758}], "30": [{"angulo_tronco": 66.68372882418792, "angulo_head": 79.28642546746681}], "40": [{"angulo_tronco": 71.06843380360887, "angulo_head": 81.02798669517111}], "50": [{"angulo_tronco": 68.956592983279, "angulo_head": 82.59526368546022}], "60": [{"angulo_tronco": 71.3108461172883, "angulo_head": 81.86181867345336}], "70": [{"angulo_tronco": 81.26958770618761, "angulo_head": 85.81592410170646}], "80": [{"angulo_tronco": 82.73119839775892, "angulo_head": 87.60582832208698}], "90": [{"angulo_tronco": 87.8002297309525, "angulo_head": 90.43681077183095}], "100": [{"angulo_tronco": 95.11619452295332, "angulo_head": 92.70956931766003}], "110": [{"angulo_tronco": 100.36984821548684, "angulo_head": 93.01541735767879}], "120": [{"angulo_tronco": 108.9942836799013, "angulo_head": 93.8911517688166}], "130": [{"angulo_tronco": 109.09795356833183, "angulo_head": 96.1054901270145}], "140": [{"angulo_tronco": 101.21221562769108, "angulo_head": 96.01633657148327}], "150": [{"angulo_tronco": 113.36250502811993, "angulo_head": 97.29651312809871}], "160": [{"angulo_tronco": 121.96564372133483, "angulo_head": 98.11370712683332}], "170": [{"angulo_tronco": 127.97464723370429, "angulo_head": 99.02853106139993}], "180": [{"angulo_tronco": 72.07066117192686, "angulo_head": 101.57333359340208}]}, "400": {"0": [{"angulo_tronco": 67.41472477562813, "angulo_head": 139.37039349808026}], "10": [{"angulo_tronco": 57.37428475270929, "angulo_head": 139.95504770235894}], "20": [{"angulo_tronco": 63.7523841183754, "angulo_head": 140.18278025149564}], "30": [{"angulo_tronco": 67.39315718075545, "angulo_head": 140.4087897354907}], "40": [{"angulo_tronco": 73.07056040156475, "angulo_head": 80.08879286202999}], "50": [{"angulo_tronco": 78.0118429832598, "angulo_head": 80.83596057572245}], "60": [{"angulo_tronco": 75.64798529708719, "angulo_head": 83.85884270584859}], "70": [{"angulo_tronco": 77.84319676057262, "angulo_head": 85.78337325740168}], "80": [{"angulo_tronco": 82.17170310207104, "angulo_head": 86.98441077545523}], "90": [{"angulo_tronco": 89.66440698627353, "angulo_head": 88.95811716417073}], "100": [{"angulo_tronco": 93.05596413200544, "angulo_head": 91.98619849051495}], "110": [{"angulo_tronco": 106.48609375202506, "angulo_head": 93.06968972776276}], "120": [{"angulo_tronco": 104.69592136465522, "angulo_head": 94.33164132176942}], "130": [{"angulo_tronco": 109.17257374111766, "angulo_head": 95.87784411105203}], "140": [{"angulo_tronco": 108.68871831990721, "angulo_head": 96.2658501751115}], "150": [{"angulo_tronco": 110.82726997938015, "angulo_head": 98.22879123753714}], "160": [{"angulo_tronco": 102.775700548169, "angulo_head": 142.28640953629179}], "170": [{"angulo_tronco": 106.26210886976406, "angulo_head": 142.46474523969817}], "180": [{"angulo_tronco": 112.245015488628, "angulo_head": 142.85024182671265}]}}, "centroide": {"200": [{"respuesta": 216.96629711441733}], "250": [{"respuesta": 259.19535726707295}], "300": [{"respuesta": 307.13106336382754}], "350": [{"respuesta": 342.7399709353809}], "400": [{"respuesta": 378.02004777542504}], "450": [{"respuesta": 414.82054346961183}], "500": [{"respuesta": 442.11153271908404}], "550": [{"respuesta": 477.8045643342341}], "600": [{"respuesta": 499.7842169404048}]}, "centroide_grupal": {"200": [{"respuesta": 224.40364987504654}], "250": [{"respuesta": 268.20661315337884}], "300": [{"respuesta": 304.15215839745}, {"respuesta": 304.05748876409245}], "350": [{"respuesta": 348.5750513905228}, {"respuesta": 348.9966055446287}], "400": [{"respuesta": 372.2480450215206}], "450": [{"respuesta": 412.08984329504324}, {"respuesta": 412.6735249633499}], "500": [{"respuesta": 437.27358048281667}], "550": [{"respuesta": 467.1882704624189}, {"respuesta": 493.53227447895205}], "600": [{"respuesta": 491.9409953518382}]}, "height_167": {"200": [{"respuesta": 182.5485255329461}], "250": [{"respuesta": 173.9391925384619}], "300": [{"respuesta": 166.06575309482395}], "350": [{"respuesta": 324.99135059243883}], "400": [{"respuesta": 153.06249789034118}], "450": [{"respuesta": 148.5808293536491}], "500": [{"respuesta": 145.17733726777362}], "550": [{"respuesta": 138.8780944488873}], "600": [{"respuesta": 134.537426240367}]}}

# con el mas ligero de yolo
json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "99.11893606185913"}]}, "400": {"C": [{"result": "c", "confidence": "99.89907145500183"}, {"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "c", "confidence": "99.52154159545898"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.82301592826843"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.374861001139955, "angulo_head": 77.2931178404306}], "10": [{"angulo_tronco": 70.79678102967449, "angulo_head": 78.4081034190861}], "20": [{"angulo_tronco": 57.597494965106385, "angulo_head": 77.68595262936633}], "30": [{"angulo_tronco": 60.213194066437374, "angulo_head": 79.67510369402653}], "40": [{"angulo_tronco": 56.2452794573684, "angulo_head": 80.5982214003402}], "50": [{"angulo_tronco": 67.53921887456873, "angulo_head": 82.19534963603306}], "60": [{"angulo_tronco": 74.51677514737712, "angulo_head": 84.58947788393323}], "70": [{"angulo_tronco": 81.34060692796426, "angulo_head": 83.15032650592751}], "80": [{"angulo_tronco": 85.72585591352568, "angulo_head": 85.75076022100068}], "90": [{"angulo_tronco": 87.13361291505561, "angulo_head": 88.10277965571127}], "100": [{"angulo_tronco": 98.48804105783428, "angulo_head": 92.13793386426295}], "110": [{"angulo_tronco": 98.30913689964781, "angulo_head": 91.57299160641098}], "120": [{"angulo_tronco": 111.56426972157001, "angulo_head": 93.82467685353295}], "130": [{"angulo_tronco": 110.35969613096393, "angulo_head": 95.34069800693986}], "140": [{"angulo_tronco": 118.99146014393129, "angulo_head": 96.20038435635105}], "150": [{"angulo_tronco": 120.25890622942755, "angulo_head": 96.23764936959444}], "160": [{"angulo_tronco": 124.92278932057164, "angulo_head": 95.51818608690999}], "170": [{"angulo_tronco": 132.46081265275657, "angulo_head": 95.73096490200686}], "180": [{"angulo_tronco": 100.50924953161531, "angulo_head": 98.93761284647059}]}, "300": {"0": [{"angulo_tronco": 97.47301794528747, "angulo_head": 75.92962114363}], "10": [{"angulo_tronco": 65.29325257885448, "angulo_head": 76.34364639455985}], "20": [{"angulo_tronco": 72.81246930873954, "angulo_head": 76.83471232660571}], "30": [{"angulo_tronco": 65.47647115736845, "angulo_head": 77.89703445540441}], "40": [{"angulo_tronco": 64.10182402307792, "angulo_head": 81.00318641238015}], "50": [{"angulo_tronco": 62.40715271073084, "angulo_head": 87.67447031188085}], "60": [{"angulo_tronco": 68.01487882051637, "angulo_head": 85.845545304196}], "70": [{"angulo_tronco": 73.50337056791227, "angulo_head": 78.3750511003972}], "80": [{"angulo_tronco": 83.07290541977969, "angulo_head": 97.70884840205667}], "90": [{"angulo_tronco": 88.36615773173692, "angulo_head": 89.06223481683759}], "100": [{"angulo_tronco": 97.04141596325793, "angulo_head": 86.26667682365148}], "110": [{"angulo_tronco": 94.50777340375728, "angulo_head": 85.63857521619097}], "120": [{"angulo_tronco": 101.42670790489991, "angulo_head": 97.3282516178178}], "130": [{"angulo_tronco": 104.05077305172273, "angulo_head": 88.82463477487637}], "140": [{"angulo_tronco": 106.66687599786408, "angulo_head": 87.29587960592065}], "150": [{"angulo_tronco": 115.18072879751907, "angulo_head": 97.77976175006167}], "160": [{"angulo_tronco": 126.54830226358396, "angulo_head": 94.57988412519153}], "170": [{"angulo_tronco": 115.93864528841891, "angulo_head": 95.23350812090995}], "180": [{"angulo_tronco": 105.96199813332865, "angulo_head": 101.20882405481488}]}, "400": {"0": [{"angulo_tronco": 82.35579548243021, "angulo_head": 139.48316712503788}], "10": [{"angulo_tronco": 68.0610597170858, "angulo_head": 139.2366115411537}], "20": [{"angulo_tronco": 65.12516094240829, "angulo_head": 139.742387086716}], "30": [{"angulo_tronco": 66.40668207857486, "angulo_head": 139.75693579849417}], "40": [{"angulo_tronco": 67.02521498855306, "angulo_head": 81.56265133841393}], "50": [{"angulo_tronco": 72.95260900145463, "angulo_head": 86.07529017322764}], "60": [{"angulo_tronco": 83.16044705340211, "angulo_head": 87.51423733740623}], "70": [{"angulo_tronco": 82.55429189724657, "angulo_head": 87.77166453702996}], "80": [{"angulo_tronco": 75.20010379207969, "angulo_head": 85.09184602736934}], "90": [{"angulo_tronco": 93.18074916822341, "angulo_head": 88.55951784826966}], "100": [{"angulo_tronco": 98.51757665608203, "angulo_head": 88.57065972934903}], "110": [{"angulo_tronco": 99.10212020957128, "angulo_head": 89.45477627021195}], "120": [{"angulo_tronco": 103.8877856213203, "angulo_head": 94.00491153884582}], "130": [{"angulo_tronco": 108.83231225212766, "angulo_head": 98.67599164794862}], "140": [{"angulo_tronco": 109.6601568818388, "angulo_head": 91.13171500609403}], "150": [{"angulo_tronco": 111.90021039494931, "angulo_head": 91.9473199008256}], "160": [{"angulo_tronco": 114.77770689627583, "angulo_head": 142.98401761110458}], "170": [{"angulo_tronco": 109.47179225005517, "angulo_head": 142.49522975021034}], "180": [{"angulo_tronco": 81.84455498357583, "angulo_head": 140.78469616294444}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.86206139180383, "angulo_head": 79.1198541919814}], "10": [{"angulo_tronco": 72.09868547979772, "angulo_head": 79.15271204627733}], "20": [{"angulo_tronco": 55.920419073810805, "angulo_head": 80.31057111886977}], "30": [{"angulo_tronco": 60.27415706870575, "angulo_head": 81.82118421023881}], "40": [{"angulo_tronco": 63.45346770206003, "angulo_head": 81.02903346824533}], "50": [{"angulo_tronco": 69.9404821342096, "angulo_head": 82.68515850131585}], "60": [{"angulo_tronco": 77.89157581651477, "angulo_head": 84.99745137637973}], "70": [{"angulo_tronco": 79.00834300712987, "angulo_head": 84.65095851568957}], "80": [{"angulo_tronco": 82.51605004576166, "angulo_head": 85.65187087142331}], "90": [{"angulo_tronco": 87.85120308024635, "angulo_head": 89.92848980492421}], "100": [{"angulo_tronco": 101.09908608503706, "angulo_head": 92.15562425762698}], "110": [{"angulo_tronco": 102.45742973286346, "angulo_head": 93.43704490128653}], "120": [{"angulo_tronco": 109.56785309918203, "angulo_head": 93.16218986780193}], "130": [{"angulo_tronco": 111.90651301069545, "angulo_head": 94.08096604055388}], "140": [{"angulo_tronco": 119.06973057596247, "angulo_head": 95.1560284594078}], "150": [{"angulo_tronco": 128.2430726786717, "angulo_head": 93.97199306268448}], "160": [{"angulo_tronco": 115.6688430748664, "angulo_head": 98.22513124314241}], "170": [{"angulo_tronco": 125.79877984593085, "angulo_head": 97.48138929635482}], "180": [{"angulo_tronco": 94.9876629641297, "angulo_head": 101.2886739261873}]}, "300": {"0": [{"angulo_tronco": 84.40848734089226, "angulo_head": 78.94647475559701}], "10": [{"angulo_tronco": 67.11228299490242, "angulo_head": 78.0842534148448}], "20": [{"angulo_tronco": 62.1285567837158, "angulo_head": 78.8000570861365}], "30": [{"angulo_tronco": 67.31758493256527, "angulo_head": 79.1953882543826}], "40": [{"angulo_tronco": 72.65529376245281, "angulo_head": 80.35286602506223}], "50": [{"angulo_tronco": 71.42769015548843, "angulo_head": 81.26431200447213}], "60": [{"angulo_tronco": 69.99151144444225, "angulo_head": 81.66894339390065}], "70": [{"angulo_tronco": 82.21797976375619, "angulo_head": 85.91553206509957}], "80": [{"angulo_tronco": 82.6353686680904, "angulo_head": 87.89050909722202}], "90": [{"angulo_tronco": 87.48216849117753, "angulo_head": 90.02587037502829}], "100": [{"angulo_tronco": 95.05611451263547, "angulo_head": 91.69271123648795}], "110": [{"angulo_tronco": 99.56785156129432, "angulo_head": 91.73102022432184}], "120": [{"angulo_tronco": 107.51286601058364, "angulo_head": 93.92245750448134}], "130": [{"angulo_tronco": 110.07413413835762, "angulo_head": 95.54697658561426}], "140": [{"angulo_tronco": 101.09484784432938, "angulo_head": 96.20353427712577}], "150": [{"angulo_tronco": 114.41420909572818, "angulo_head": 95.4895685460226}], "160": [{"angulo_tronco": 122.52830399005094, "angulo_head": 97.83272485862517}], "170": [{"angulo_tronco": 119.93445981923458, "angulo_head": 99.6036009346887}], "180": [{"angulo_tronco": 173.32747162489514, "angulo_head": 101.41708386762521}]}, "400": {"0": [{"angulo_tronco": 89.8606728664207, "angulo_head": 140.23033411780267}], "10": [], "20": [{"angulo_tronco": 57.79811744081165, "angulo_head": 80.51350608116195}], "30": [{"angulo_tronco": 65.82467792045846, "angulo_head": 81.15109960610694}], "40": [{"angulo_tronco": 73.88120236844094, "angulo_head": 79.77008846468101}], "50": [{"angulo_tronco": 76.56123442382372, "angulo_head": 81.74335576868849}], "60": [{"angulo_tronco": 76.08136303310133, "angulo_head": 86.55810004651516}], "70": [{"angulo_tronco": 77.69170055158756, "angulo_head": 86.39555130432365}], "80": [{"angulo_tronco": 82.55480063605802, "angulo_head": 87.4758843433685}], "90": [{"angulo_tronco": 89.57775726764665, "angulo_head": 89.38554707624084}], "100": [{"angulo_tronco": 93.54206100699662, "angulo_head": 91.107682120764}], "110": [{"angulo_tronco": 106.10520739654959, "angulo_head": 92.65424831378006}], "120": [{"angulo_tronco": 104.54183533595577, "angulo_head": 92.24041848862338}], "130": [{"angulo_tronco": 110.65623861534068, "angulo_head": 93.21054571085148}], "140": [{"angulo_tronco": 109.56689605615772, "angulo_head": 97.22073709720858}], "150": [{"angulo_tronco": 111.42724660319269, "angulo_head": 98.4845975757953}], "160": [{"angulo_tronco": 105.07458000298624, "angulo_head": 143.0313043161599}], "170": [{"angulo_tronco": 114.4936067223362, "angulo_head": 143.45069424949332}], "180": []}}, "centroide": {"200": [{"respuesta": 216.63882051300686}], "250": [{"respuesta": 259.1393502540516}], "300": [{"respuesta": 306.79673329063814}], "350": [{"respuesta": 342.6856971213973}], "400": [{"respuesta": 377.5570307105715}], "450": [{"respuesta": 415.02829423157897}], "500": [{"respuesta": 441.81646015596885}], "550": [{"respuesta": 477.6613663488293}], "600": [{"respuesta": 499.8720639035462}]}, "centroide_grupal": {"200": [{"respuesta": 224.25579051259342}], "250": [{"respuesta": 268.1059349134709}], "300": [{"respuesta": 303.9905491609724}, {"respuesta": 303.95952012825217}], "350": [{"respuesta": 348.3725679971751}, {"respuesta": 348.8477630042453}], "400": [{"respuesta": 372.6065818108824}], "450": [{"respuesta": 412.35643584775966}, {"respuesta": 412.9354845411274}], "500": [{"respuesta": 437.1947567151643}], "550": [{"respuesta": 467.1053311014829}, {"respuesta": 445.28113450053354}], "600": [{"respuesta": 443.6102884809551}]}, "height_167": {"200": [{"respuesta": 179.42452325309839}], "250": [{"respuesta": 173.59897027145718}], "300": [{"respuesta": 166.98193337629218}], "350": [{"respuesta": 158.11981568595755}], "400": [{"respuesta": 152.08919558949466}], "450": [{"respuesta": 147.3272777742213}], "500": [{"respuesta": 145.10800037668872}], "550": [{"respuesta": 137.88712777539828}], "600": [{"respuesta": 133.5878088766013}]}}

# SELECTIVE con el mas ligero de yolo pero con correccion de frente
# json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "99.11893606185913"}]}, "400": {"C": [{"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.32182431221008"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.38370113045398, "angulo_head": 128.24374343935617}], "10": [{"angulo_tronco": 70.75639405657955, "angulo_head": 129.2080084706807}], "20": [{"angulo_tronco": 57.61085671603644, "angulo_head": 139.42608727384354}], "30": [{"angulo_tronco": 60.20931240147336, "angulo_head": 147.98877870557348}], "40": [{"angulo_tronco": 56.24228848744562, "angulo_head": 113.98333695938653}], "50": [{"angulo_tronco": 67.5391300862696, "angulo_head": 150.2604440782432}], "60": [{"angulo_tronco": 74.50594520383738, "angulo_head": 7.736879961488018}], "70": [{"angulo_tronco": 81.33797551851247, "angulo_head": 2.0469352576050728}], "80": [{"angulo_tronco": 85.73192904188448, "angulo_head": 17.01677674963909}], "90": [{"angulo_tronco": 87.13768028361672, "angulo_head": 164.17729490248124}], "100": [{"angulo_tronco": 98.47578071388277, "angulo_head": 146.01870834640113}], "110": [{"angulo_tronco": 98.29505604069655, "angulo_head": 20.938760260294266}], "120": [{"angulo_tronco": 111.5632178897884, "angulo_head": 32.80355587663875}], "130": [{"angulo_tronco": 110.35662260109765, "angulo_head": 41.055314971287245}], "140": [{"angulo_tronco": 118.999239595764, "angulo_head": 63.060421592573334}], "150": [{"angulo_tronco": 120.26072539770851, "angulo_head": 48.44469073717988}], "160": [{"angulo_tronco": 124.94667884895927, "angulo_head": 59.66440932706347}], "170": [{"angulo_tronco": 132.47325948382195, "angulo_head": 65.26942728478913}], "180": [{"angulo_tronco": 100.71982159438127, "angulo_head": 62.68393244362502}]}, "300": {"0": [{"angulo_tronco": 97.54912109674095, "angulo_head": 131.3926780057961}], "10": [{"angulo_tronco": 65.325758152836, "angulo_head": 133.48189777539105}], "20": [{"angulo_tronco": 72.85895806324615, "angulo_head": 133.6411739277198}], "30": [{"angulo_tronco": 65.47632371836404, "angulo_head": 123.90017090683872}], "40": [{"angulo_tronco": 64.07198011881663, "angulo_head": 110.82932535825272}], "50": [{"angulo_tronco": 62.39387053150504, "angulo_head": 123.72534133125025}], "60": [{"angulo_tronco": 68.0132617285108, "angulo_head": 141.97503083780396}], "70": [{"angulo_tronco": 73.51197531237648, "angulo_head": 152.7163872509207}], "80": [{"angulo_tronco": 83.06739396647151, "angulo_head": 21.75062141644505}], "90": [{"angulo_tronco": 88.39130472359679, "angulo_head": 70.2741407924649}], "100": [{"angulo_tronco": 97.06140072535969, "angulo_head": 169.54452703970924}], "110": [{"angulo_tronco": 94.5010395857033, "angulo_head": 25.919922892609474}], "120": [{"angulo_tronco": 101.41646203654616, "angulo_head": 19.943731714134294}], "130": [{"angulo_tronco": 104.05488460596331, "angulo_head": 27.247799213071993}], "140": [{"angulo_tronco": 106.65192686807063, "angulo_head": 42.15225676687132}], "150": [{"angulo_tronco": 115.24118558073329, "angulo_head": 53.49315273323412}], "160": [{"angulo_tronco": 126.3341520055585, "angulo_head": 160.54455437371018}], "170": [{"angulo_tronco": 115.98077671264244, "angulo_head": 50.859314963583294}], "180": [{"angulo_tronco": 105.84407501675092, "angulo_head": 55.67481487853241}]}, "400": {"0": [{"angulo_tronco": 81.95328058531332, "angulo_head": 169.84291428986637}], "10": [{"angulo_tronco": 67.5915472632689, "angulo_head": 11.359267093856193}], "20": [{"angulo_tronco": 65.07366408168184, "angulo_head": 8.864847775987162}], "30": [{"angulo_tronco": 66.40611473133669, "angulo_head": 8.795410729243404}], "40": [{"angulo_tronco": 67.00145292410953, "angulo_head": 150.01422006984447}], "50": [{"angulo_tronco": 72.94774265458229, "angulo_head": 5.337903323988617}], "60": [{"angulo_tronco": 83.23729418446189, "angulo_head": 128.07382505903524}], "70": [{"angulo_tronco": 82.53669629647669, "angulo_head": 164.91727946767384}], "80": [{"angulo_tronco": 75.21555398526945, "angulo_head": 27.435254683722516}], "90": [{"angulo_tronco": 93.22989076967856, "angulo_head": 47.51387693866334}], "100": [{"angulo_tronco": 98.60208362765579, "angulo_head": 151.75251908489324}], "110": [{"angulo_tronco": 99.17628631636924, "angulo_head": 66.46612193397804}], "120": [{"angulo_tronco": 103.97969509847897, "angulo_head": 170.40693506120985}], "130": [{"angulo_tronco": 108.88502347473855, "angulo_head": 28.70453963844503}], "140": [{"angulo_tronco": 109.61193048685801, "angulo_head": 69.24216673818839}], "150": [{"angulo_tronco": 111.89677958024183, "angulo_head": 56.173923254285306}], "160": [{"angulo_tronco": 114.63630820121215, "angulo_head": 171.3802863340509}], "170": [{"angulo_tronco": 109.62769446573103, "angulo_head": 170.03274083154452}], "180": [{"angulo_tronco": 81.86733157253593, "angulo_head": 161.5820492222696}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.8325337358122, "angulo_head": 128.96239882358185}], "10": [{"angulo_tronco": 72.09395554623494, "angulo_head": 130.50335000413486}], "20": [{"angulo_tronco": 55.92643563299919, "angulo_head": 136.90733674403845}], "30": [{"angulo_tronco": 60.28347282661566, "angulo_head": 144.48706974644077}], "40": [{"angulo_tronco": 63.46039353849564, "angulo_head": 14.010953475127943}], "50": [{"angulo_tronco": 69.93138437758046, "angulo_head": 155.9059670958426}], "60": [{"angulo_tronco": 77.89489354554813, "angulo_head": 152.69952121591487}], "70": [{"angulo_tronco": 79.00663194840062, "angulo_head": 32.74003694106268}], "80": [{"angulo_tronco": 82.5228227793453, "angulo_head": 12.286305177577553}], "90": [{"angulo_tronco": 87.83443421460018, "angulo_head": 84.26327670104386}], "100": [{"angulo_tronco": 101.09778164284201, "angulo_head": 168.60904706318033}], "110": [{"angulo_tronco": 102.45006481554148, "angulo_head": 16.96397199439838}], "120": [{"angulo_tronco": 109.56064707453872, "angulo_head": 48.306796078414926}], "130": [{"angulo_tronco": 111.91802369115084, "angulo_head": 52.70026476039046}], "140": [{"angulo_tronco": 119.09689018819712, "angulo_head": 36.248589359952916}], "150": [{"angulo_tronco": 128.23273516339503, "angulo_head": 63.2020512747073}], "160": [{"angulo_tronco": 115.65205305193007, "angulo_head": 49.21991242341242}], "170": [{"angulo_tronco": 125.80290135548826, "angulo_head": 63.674870806679635}], "180": [{"angulo_tronco": 94.98853252610425, "angulo_head": 55.25727916419304}]}, "300": {"0": [{"angulo_tronco": 84.64902777831038, "angulo_head": 127.46605383894654}], "10": [{"angulo_tronco": 67.01889300439952, "angulo_head": 133.6435192053197}], "20": [{"angulo_tronco": 62.11460633394763, "angulo_head": 140.62723266047917}], "30": [{"angulo_tronco": 67.34076422855863, "angulo_head": 153.1322426190225}], "40": [{"angulo_tronco": 72.69229923054002, "angulo_head": 154.5748645061233}], "50": [{"angulo_tronco": 71.39706232246662, "angulo_head": 157.9331749538075}], "60": [{"angulo_tronco": 69.9802525043653, "angulo_head": 9.576916116932983}], "70": [{"angulo_tronco": 82.2053179808648, "angulo_head": 19.478628771385488}], "80": [{"angulo_tronco": 82.59958359518085, "angulo_head": 0.2522860817228371}], "90": [{"angulo_tronco": 87.4916305508291, "angulo_head": 90.80239718611524}], "100": [{"angulo_tronco": 95.03230498350175, "angulo_head": 162.2626123061335}], "110": [{"angulo_tronco": 99.54195293328881, "angulo_head": 29.484493684569713}], "120": [{"angulo_tronco": 107.52746294029846, "angulo_head": 165.89285458594307}], "130": [{"angulo_tronco": 110.04582042239065, "angulo_head": 171.85320393619932}], "140": [{"angulo_tronco": 101.10403664399644, "angulo_head": 40.91688949239278}], "150": [{"angulo_tronco": 114.46339792673629, "angulo_head": 40.77610515369261}], "160": [{"angulo_tronco": 122.60726244449978, "angulo_head": 56.67801192271219}], "170": [{"angulo_tronco": 120.03670409816944, "angulo_head": 46.50251247580373}], "180": [{"angulo_tronco": 173.3454924388478, "angulo_head": 131.18297785916607}]}, "400": {"0": [{"angulo_tronco": 89.84861457727212, "angulo_head": 10.860453091554891}], "10": [], "20": [{"angulo_tronco": 57.82528406994957, "angulo_head": 137.97245920785784}], "30": [{"angulo_tronco": 65.86573260429047, "angulo_head": 107.52591741106309}], "40": [{"angulo_tronco": 73.91510417456311, "angulo_head": 7.996191561488046}], "50": [{"angulo_tronco": 76.61830087241911, "angulo_head": 7.503765647459886}], "60": [{"angulo_tronco": 76.0812742787921, "angulo_head": 5.641339447662824}], "70": [{"angulo_tronco": 77.65877213302547, "angulo_head": 21.746028754650276}], "80": [{"angulo_tronco": 82.47000620770986, "angulo_head": 3.711988384702043}], "90": [{"angulo_tronco": 89.60870297199327, "angulo_head": 58.29970506357032}], "100": [{"angulo_tronco": 93.45805661772853, "angulo_head": 154.56864942713136}], "110": [{"angulo_tronco": 106.23958732848483, "angulo_head": 171.56952703825195}], "120": [{"angulo_tronco": 104.57693722636505, "angulo_head": 147.4808603660186}], "130": [{"angulo_tronco": 110.65137222679598, "angulo_head": 155.91152911185506}], "140": [{"angulo_tronco": 109.51327899622797, "angulo_head": 20.832702035515933}], "150": [{"angulo_tronco": 111.5134056229769, "angulo_head": 36.1251040897366}], "160": [{"angulo_tronco": 105.13606454704585, "angulo_head": 171.60463964630566}], "170": [{"angulo_tronco": 114.27560875292626, "angulo_head": 170.99463636957972}], "180": []}}, "centroide": {"200": [{"respuesta": 216.63963447941615}], "250": [{"respuesta": 259.1322712793071}], "300": [{"respuesta": 306.7940141960579}], "350": [{"respuesta": 342.6862876129505}], "400": [{"respuesta": 377.55794801463963}], "450": [{"respuesta": 415.04357776561204}], "500": [{"respuesta": 441.81704736951883}], "550": [{"respuesta": 477.6575616708212}], "600": [{"respuesta": 499.89076416315095}]}, "centroide_grupal": {"200": [{"respuesta": 224.25279835552902}], "250": [{"respuesta": 268.1067542741104}], "300": [{"respuesta": 303.9913195293235}, {"respuesta": 303.9571956238318}], "350": [{"respuesta": 348.3737918724478}, {"respuesta": 348.8462384252565}], "400": [{"respuesta": 372.6077242173816}], "450": [{"respuesta": 412.36058724536275}, {"respuesta": 412.94296463232195}], "500": [{"respuesta": 437.19657672289657}], "550": [{"respuesta": 467.1059864445928}, {"respuesta": 445.2861131712625}], "600": [{"respuesta": 443.6141641815377}]}, "height_167": {"200": [{"respuesta": 179.42394674130588}], "250": [{"respuesta": 173.59130702940294}], "300": [{"respuesta": 166.98264165828985}], "350": [{"respuesta": 158.0673487312635}], "400": [{"respuesta": 152.0895573290941}], "450": [{"respuesta": 147.3116487454892}], "500": [{"respuesta": 145.01009728658505}], "550": [{"respuesta": 137.88553931690691}], "600": [{"respuesta": 133.58630347793738}]}}

# %%
# WLS con frente normal, sin correccion
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 17.56660544140292}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 11.178474540200712}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 10.8117512118006}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 35.52203335366441}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 38.57517168724967}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 28.66330531676842}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 29.938822898747446}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 1.2040964620854056}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 32.828510496279165}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 54.90903173395498}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 171.0282853033781}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 122.66738700736833}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 125.44053390266195}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 106.05531053293494}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 115.90594583554781}], "150": [{"angulo_tronco": 105.40653956449154, "angulo_head": 108.5326942011332}], "160": [{"angulo_tronco": 105.5653116282023, "angulo_head": 109.37086904175513}], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 95.56052744060207}], "180": [{"angulo_tronco": 90.22881297276098, "angulo_head": 11.21495915191994}]}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 51.342735509661516}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 51.896273741967185}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 54.630768263038924}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 40.28374912041732}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 42.37753569362289}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 16.914979098031605}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 11.645784658469212}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 19.649105336338682}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 179.7829630126809}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 80.96494799929026}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 42.05010399679801}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 23.77098370226349}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 117.09179253340518}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 38.65417283727337}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 8.442346579512801}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 116.24133933495467}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 119.36118582745205}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 113.24286524378539}], "180": [{"angulo_tronco": 92.59079680974855, "angulo_head": 22.300380834937386}]}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 43.648023982848095}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 8.449957803588003}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 4.021888843232577}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 35.92663803167994}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 28.058152761688003}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 61.789884873338956}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 65.34403737723385}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 71.67976940281024}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 38.1559062671939}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 74.64032052865774}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 30.42512856501636}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 86.63653484000979}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 152.60302224992972}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 172.74587418554958}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 100.02353085935174}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 130.33272780149557}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 135.80300114558696}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 117.21953644327778}], "180": [{"angulo_tronco": 91.16956371277506, "angulo_head": 169.81408421128216}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 27.514389820082492}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 26.215496440688494}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 72.9626201616738}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 65.14299434621495}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 29.015320788005095}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 29.10351567800873}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 32.715635438898005}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 44.09914280910142}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 40.874420353499346}], "90": [{"angulo_tronco": 90.0, "angulo_head": 44.10969846171719}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 144.1348348144727}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 140.37520457947275}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 121.44559903246528}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 118.95472538805404}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 112.521335014468}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 96.43722648852933}], "160": [{"angulo_tronco": 100.13484505212077, "angulo_head": 117.83501785411146}], "170": [{"angulo_tronco": 100.56493816441778, "angulo_head": 14.89836860059407}], "180": [{"angulo_tronco": 91.44724789522074, "angulo_head": 15.584771961576857}]}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 7.600466525133131}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 13.059028947566796}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 39.634383227931124}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 52.60979863919088}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 16.4403922740087}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 2.791610619569728}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 27.468705930768206}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 20.062372518615334}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 18.97104853635193}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 74.27607252000064}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 114.60381922413484}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 114.32936343935117}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 96.68986971353506}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 137.5443366361454}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 107.20836010424122}], "150": [{"angulo_tronco": 93.99755439085598, "angulo_head": 107.97151796841669}], "160": [{"angulo_tronco": 92.63869290613535, "angulo_head": 117.44238143398893}], "170": [{"angulo_tronco": 94.36762714443748, "angulo_head": 16.782775909207228}], "180": [{"angulo_tronco": 90.0, "angulo_head": 12.73342667622608}]}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 55.21155198892544}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 51.572035795464274}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 27.551293088375495}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 9.03208871778202}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 42.86573578546716}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 16.63197452830223}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 51.83027694907997}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 43.06517646395466}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 72.47993698263849}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 136.66188300878446}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 173.64837527404305}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 113.42198510381}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 161.5371181339294}], "140": [{"angulo_tronco": 90.0, "angulo_head": 128.28063525975193}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 138.96908913272483}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 154.47958610052805}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 124.6948546504437}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# WLS pero con correccion de frente
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 162.4333945585971}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 11.178474540200712}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 10.8117512118006}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 144.4779666463356}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 141.42482831275032}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 151.33669468323157}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 150.06117710125255}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 1.2040964620854056}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 147.17148950372084}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 54.90903173395498}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 171.0282853033781}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 57.33261299263167}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 54.55946609733804}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 73.94468946706506}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 64.09405416445219}], "150": [{"angulo_tronco": 105.40653956449154, "angulo_head": 71.4673057988668}], "160": [{"angulo_tronco": 105.5653116282023, "angulo_head": 70.62913095824487}], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 84.43947255939793}], "180": [{"angulo_tronco": 90.22881297276098, "angulo_head": 168.78504084808006}]}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 128.6572644903385}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 128.1037262580328}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 125.36923173696108}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 139.7162508795827}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 137.6224643063771}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 16.914979098031605}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 11.645784658469212}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 160.3508946636613}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 0.21703698731910162}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 80.96494799929026}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 42.05010399679801}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 23.77098370226349}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 62.90820746659482}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 38.65417283727337}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 171.55765342048718}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 63.75866066504532}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 60.63881417254795}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 66.75713475621461}], "180": [{"angulo_tronco": 92.59079680974855, "angulo_head": 22.300380834937386}]}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 43.648023982848095}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 171.550042196412}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 4.021888843232577}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 144.07336196832006}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 28.058152761688003}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 61.789884873338956}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 65.34403737723385}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 71.67976940281024}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 38.1559062671939}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 74.64032052865774}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 30.42512856501636}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 93.36346515999021}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 27.396977750070278}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 7.254125814450413}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 79.97646914064826}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 49.66727219850445}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 44.19699885441302}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 62.78046355672222}], "180": [{"angulo_tronco": 91.16956371277506, "angulo_head": 169.81408421128216}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 152.48561017991753}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 153.7845035593115}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 107.0373798383262}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 114.85700565378504}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 150.98467921199492}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 150.8964843219913}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 147.28436456110202}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 44.09914280910142}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 40.874420353499346}], "90": [{"angulo_tronco": 90.0, "angulo_head": 44.10969846171719}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 35.86516518552729}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 39.62479542052724}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 58.55440096753474}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 61.04527461194597}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 67.478664985532}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 83.56277351147067}], "160": [{"angulo_tronco": 100.13484505212077, "angulo_head": 62.16498214588852}], "170": [{"angulo_tronco": 100.56493816441778, "angulo_head": 165.10163139940593}], "180": [{"angulo_tronco": 91.44724789522074, "angulo_head": 164.41522803842315}]}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 7.600466525133131}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 13.059028947566796}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 140.36561677206888}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 127.39020136080912}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 163.5596077259913}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 2.791610619569728}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 27.468705930768206}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 20.062372518615334}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 18.97104853635193}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 105.72392747999936}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 65.39618077586516}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 65.67063656064883}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 83.31013028646494}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 42.45566336385459}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 72.79163989575878}], "150": [{"angulo_tronco": 93.99755439085598, "angulo_head": 72.02848203158331}], "160": [{"angulo_tronco": 92.63869290613535, "angulo_head": 62.557618566011065}], "170": [{"angulo_tronco": 94.36762714443748, "angulo_head": 16.782775909207228}], "180": [{"angulo_tronco": 90.0, "angulo_head": 12.73342667622608}]}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 124.78844801107456}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 128.42796420453573}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 152.4487069116245}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 9.03208871778202}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 42.86573578546716}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 16.63197452830223}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 51.83027694907997}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 136.93482353604534}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 107.52006301736151}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 136.66188300878446}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 6.351624725956957}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 66.57801489619}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 161.5371181339294}], "140": [{"angulo_tronco": 90.0, "angulo_head": 51.71936474024806}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 41.030910867275175}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 25.52041389947195}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 55.30514534955629}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# *********************************************************************************************************************************************************************************************
# SELECTIVE con frente normal, sin correccion
json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "99.11893606185913"}]}, "400": {"C": [{"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.82301592826843"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.39071081526787, "angulo_head": 51.747279847595486}], "10": [{"angulo_tronco": 70.8017636672848, "angulo_head": 50.76893215381542}], "20": [{"angulo_tronco": 57.59867346929158, "angulo_head": 40.554871172116826}], "30": [{"angulo_tronco": 60.20707450498626, "angulo_head": 32.00988316652504}], "40": [{"angulo_tronco": 56.248473995074384, "angulo_head": 66.02634101583023}], "50": [{"angulo_tronco": 67.54350794728134, "angulo_head": 29.74045964952325}], "60": [{"angulo_tronco": 74.49074218000833, "angulo_head": 7.74875402249126}], "70": [{"angulo_tronco": 81.34303619750254, "angulo_head": 2.0511020609037938}], "80": [{"angulo_tronco": 85.71493284255209, "angulo_head": 17.003767345810047}], "90": [{"angulo_tronco": 87.13513963670526, "angulo_head": 15.62377770379001}], "100": [{"angulo_tronco": 98.48930900245925, "angulo_head": 145.9532840181642}], "110": [{"angulo_tronco": 98.3088910335796, "angulo_head": 159.03059189471608}], "120": [{"angulo_tronco": 111.56583190523826, "angulo_head": 146.9170667091024}], "130": [{"angulo_tronco": 110.3697172539652, "angulo_head": 138.87933844869198}], "140": [{"angulo_tronco": 118.98812961116074, "angulo_head": 116.97291816912474}], "150": [{"angulo_tronco": 120.2771387380165, "angulo_head": 131.55151552330292}], "160": [{"angulo_tronco": 124.92708415702242, "angulo_head": 120.33106128385366}], "170": [{"angulo_tronco": 132.46171330810824, "angulo_head": 114.72841433876806}], "180": [{"angulo_tronco": 100.61529578224317, "angulo_head": 117.31117951199529}]}, "300": {"0": [{"angulo_tronco": 97.51323525997562, "angulo_head": 48.60709796826733}], "10": [{"angulo_tronco": 65.32236358473573, "angulo_head": 46.52443289152105}], "20": [{"angulo_tronco": 72.86955315979743, "angulo_head": 46.36533840520746}], "30": [{"angulo_tronco": 65.48839258019197, "angulo_head": 56.09488302980216}], "40": [{"angulo_tronco": 64.11580579893683, "angulo_head": 68.99220389292763}], "50": [{"angulo_tronco": 62.37982589688075, "angulo_head": 56.256270525003195}], "60": [{"angulo_tronco": 67.99090965099862, "angulo_head": 38.04684836357524}], "70": [{"angulo_tronco": 73.50232235140604, "angulo_head": 27.282764096485614}], "80": [{"angulo_tronco": 83.0732947231353, "angulo_head": 158.25184371796172}], "90": [{"angulo_tronco": 88.35028865827945, "angulo_head": 70.29123763557773}], "100": [{"angulo_tronco": 97.04408926922557, "angulo_head": 10.670051235167294}], "110": [{"angulo_tronco": 94.50417549171965, "angulo_head": 25.85118564125131}], "120": [{"angulo_tronco": 101.41489122341193, "angulo_head": 159.9659872794907}], "130": [{"angulo_tronco": 104.0792881950475, "angulo_head": 27.512760301305132}], "140": [{"angulo_tronco": 106.63349137794236, "angulo_head": 42.14555436864967}], "150": [{"angulo_tronco": 115.27403517781302, "angulo_head": 126.54914708957014}], "160": [{"angulo_tronco": 126.32554025079769, "angulo_head": 160.5843577791826}], "170": [{"angulo_tronco": 115.94945484494511, "angulo_head": 129.1645137300022}], "180": [{"angulo_tronco": 105.63946663184151, "angulo_head": 124.30386996766677}]}, "400": {"0": [{"angulo_tronco": 81.98148306308072, "angulo_head": 169.83968612059198}], "10": [{"angulo_tronco": 68.44779975789133, "angulo_head": 168.65736965577273}], "20": [{"angulo_tronco": 65.13594434739193, "angulo_head": 171.1314988850031}], "30": [{"angulo_tronco": 66.44360783749747, "angulo_head": 171.19965232162133}], "40": [{"angulo_tronco": 67.00358924245958, "angulo_head": 29.96723371693175}], "50": [{"angulo_tronco": 72.9802826773117, "angulo_head": 5.692319448961165}], "60": [{"angulo_tronco": 83.16084545658623, "angulo_head": 51.78392758368684}], "70": [{"angulo_tronco": 82.54902826819209, "angulo_head": 14.980616820337733}], "80": [{"angulo_tronco": 75.2481311603902, "angulo_head": 27.329633659529353}], "90": [{"angulo_tronco": 93.17472204080411, "angulo_head": 47.98921113580316}], "100": [{"angulo_tronco": 98.54289871598402, "angulo_head": 27.774197141118417}], "110": [{"angulo_tronco": 99.10364296389093, "angulo_head": 66.76728377500729}], "120": [{"angulo_tronco": 103.91801636510804, "angulo_head": 170.36636697110742}], "130": [{"angulo_tronco": 108.91459645992919, "angulo_head": 151.33083384068092}], "140": [{"angulo_tronco": 109.6256650305582, "angulo_head": 110.71913735936866}], "150": [{"angulo_tronco": 111.8525524643483, "angulo_head": 123.73065272625131}], "160": [{"angulo_tronco": 114.77877047495204, "angulo_head": 171.3812819945804}], "170": [{"angulo_tronco": 109.69083785808614, "angulo_head": 170.0281742701606}], "180": [{"angulo_tronco": 81.7239074862027, "angulo_head": 161.59827523919884}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.88836597864577, "angulo_head": 51.05170384174397}], "10": [{"angulo_tronco": 72.10300771208423, "angulo_head": 49.50917504840791}], "20": [{"angulo_tronco": 55.93537820990577, "angulo_head": 43.106768814172284}], "30": [{"angulo_tronco": 60.28303729392975, "angulo_head": 35.48933494573301}], "40": [{"angulo_tronco": 63.46172536491842, "angulo_head": 14.035966978150393}], "50": [{"angulo_tronco": 69.94486132227776, "angulo_head": 24.10297613074947}], "60": [{"angulo_tronco": 77.90771951007062, "angulo_head": 27.41326587748666}], "70": [{"angulo_tronco": 79.01414393508337, "angulo_head": 32.68425837916456}], "80": [{"angulo_tronco": 82.52304729989812, "angulo_head": 12.256291629024764}], "90": [{"angulo_tronco": 87.8375351659754, "angulo_head": 84.22177041686841}], "100": [{"angulo_tronco": 101.09824748686937, "angulo_head": 167.7494004659918}], "110": [{"angulo_tronco": 102.46075448106615, "angulo_head": 162.95802258956803}], "120": [{"angulo_tronco": 109.5678707833083, "angulo_head": 131.70681070034885}], "130": [{"angulo_tronco": 111.91315055191242, "angulo_head": 127.29740468939575}], "140": [{"angulo_tronco": 119.09237201750655, "angulo_head": 143.80317927720088}], "150": [{"angulo_tronco": 128.24854449541374, "angulo_head": 116.83106768440196}], "160": [{"angulo_tronco": 115.67309696230942, "angulo_head": 130.77682031602538}], "170": [{"angulo_tronco": 125.77986147109165, "angulo_head": 116.31374324971891}], "180": [{"angulo_tronco": 94.98854574083892, "angulo_head": 124.74501791216743}]}, "300": {"0": [{"angulo_tronco": 84.44700188552858, "angulo_head": 52.527526716520654}], "10": [{"angulo_tronco": 66.90764929269284, "angulo_head": 46.359816671092}], "20": [{"angulo_tronco": 62.08702065385864, "angulo_head": 39.362413513715175}], "30": [{"angulo_tronco": 67.33835502433809, "angulo_head": 26.935181535274303}], "40": [{"angulo_tronco": 72.67102869408245, "angulo_head": 25.429916787392685}], "50": [{"angulo_tronco": 71.42340083681779, "angulo_head": 22.066653266533713}], "60": [{"angulo_tronco": 70.00056881549395, "angulo_head": 9.519265107226683}], "70": [{"angulo_tronco": 82.22071534283474, "angulo_head": 19.39338981987827}], "80": [{"angulo_tronco": 82.5934138865495, "angulo_head": 0.22331352889299624}], "90": [{"angulo_tronco": 87.48039126581772, "angulo_head": 90.81078077633391}], "100": [{"angulo_tronco": 95.03929887122258, "angulo_head": 162.53258735403622}], "110": [{"angulo_tronco": 99.567604487606, "angulo_head": 150.59469651582202}], "120": [{"angulo_tronco": 107.47483142156923, "angulo_head": 165.8727762129648}], "130": [{"angulo_tronco": 110.06952836168044, "angulo_head": 171.82046314333238}], "140": [{"angulo_tronco": 101.14270102307003, "angulo_head": 139.10378218843556}], "150": [{"angulo_tronco": 114.41699158084705, "angulo_head": 139.2535494318695}], "160": [{"angulo_tronco": 122.5868268555384, "angulo_head": 123.24697972895387}], "170": [{"angulo_tronco": 119.97140586352013, "angulo_head": 133.48021375081277}], "180": [{"angulo_tronco": 173.29709923910355, "angulo_head": 131.19063454042555}]}, "400": {"0": [{"angulo_tronco": 89.8803163903613, "angulo_head": 169.14757068372228}], "10": [], "20": [{"angulo_tronco": 57.761243039292836, "angulo_head": 42.02148171389389}], "30": [{"angulo_tronco": 65.82200229577991, "angulo_head": 72.468718726646}], "40": [{"angulo_tronco": 73.91865376152533, "angulo_head": 8.086140563635738}], "50": [{"angulo_tronco": 76.61050074329358, "angulo_head": 7.5237181707156005}], "60": [{"angulo_tronco": 76.13532359175672, "angulo_head": 5.566366796654407}], "70": [{"angulo_tronco": 77.7328646246007, "angulo_head": 21.756277789350975}], "80": [{"angulo_tronco": 82.50653763036166, "angulo_head": 3.129281469159327}], "90": [{"angulo_tronco": 89.57609654529261, "angulo_head": 58.876174956184585}], "100": [{"angulo_tronco": 93.56530356221239, "angulo_head": 154.94850122158843}], "110": [{"angulo_tronco": 106.13240614585185, "angulo_head": 171.67528788095942}], "120": [{"angulo_tronco": 104.5618688693236, "angulo_head": 147.52648673728834}], "130": [{"angulo_tronco": 110.70128383115308, "angulo_head": 155.77634202996944}], "140": [{"angulo_tronco": 109.42645443259856, "angulo_head": 159.1405386058255}], "150": [{"angulo_tronco": 111.43284465818142, "angulo_head": 143.83971322519045}], "160": [{"angulo_tronco": 105.16670209782859, "angulo_head": 171.60152698567592}], "170": [{"angulo_tronco": 114.16001008684214, "angulo_head": 170.99714661010842}], "180": []}}, "centroide": {"200": [{"respuesta": 216.64147763047256}], "250": [{"respuesta": 259.1379294665191}], "300": [{"respuesta": 306.7978177054511}], "350": [{"respuesta": 342.688594302913}], "400": [{"respuesta": 377.56154214135756}], "450": [{"respuesta": 415.0223890550111}], "500": [{"respuesta": 441.81919524042553}], "550": [{"respuesta": 477.6600170458872}], "600": [{"respuesta": 499.89007553528415}]}, "centroide_grupal": {"200": [{"respuesta": 224.25384606195547}], "250": [{"respuesta": 268.10595539221777}], "300": [{"respuesta": 303.9938691444993}, {"respuesta": 303.95946815456125}], "350": [{"respuesta": 348.3745412740999}, {"respuesta": 348.84624058225995}], "400": [{"respuesta": 372.6031259824441}], "450": [{"respuesta": 412.36258194501966}, {"respuesta": 412.93415505893404}], "500": [{"respuesta": 437.19872215892224}], "550": [{"respuesta": 467.1121919196122}, {"respuesta": 445.28510962335093}], "600": [{"respuesta": 443.6122925323895}]}, "height_167": {"200": [{"respuesta": 179.42369041354635}], "250": [{"respuesta": 173.59139027091868}], "300": [{"respuesta": 166.98301994431182}], "350": [{"respuesta": 158.1052183087192}], "400": [{"respuesta": 152.07959870389087}], "450": [{"respuesta": 147.33465826768395}], "500": [{"respuesta": 145.02637157904275}], "550": [{"respuesta": 137.89472022044814}], "600": [{"respuesta": 133.64592808280668}]}}

# SELECTIVE pero con correccion de frente
json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "99.11893606185913"}]}, "400": {"C": [{"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.33740669883109, "angulo_head": 128.23981489169012}], "10": [{"angulo_tronco": 70.78095445919057, "angulo_head": 129.21163346031102}], "20": [{"angulo_tronco": 57.59749728010063, "angulo_head": 139.43260864009605}], "30": [{"angulo_tronco": 60.22359994954473, "angulo_head": 147.986113396903}], "40": [{"angulo_tronco": 56.24090780666604, "angulo_head": 113.98211237168863}], "50": [{"angulo_tronco": 67.53628080585563, "angulo_head": 150.26922042360496}], "60": [{"angulo_tronco": 74.51518016619154, "angulo_head": 7.796303067555881}], "70": [{"angulo_tronco": 81.34177784119974, "angulo_head": 2.037566081567303}], "80": [{"angulo_tronco": 85.71776188576867, "angulo_head": 16.979346761321462}], "90": [{"angulo_tronco": 87.14448567663669, "angulo_head": 164.23389604422462}], "100": [{"angulo_tronco": 98.48755509709308, "angulo_head": 146.14228127087728}], "110": [{"angulo_tronco": 98.30125965067221, "angulo_head": 20.810236481614478}], "120": [{"angulo_tronco": 111.5673319217542, "angulo_head": 32.86287273519246}], "130": [{"angulo_tronco": 110.38506930657934, "angulo_head": 41.0022144437128}], "140": [{"angulo_tronco": 118.99903787263379, "angulo_head": 63.11364579559671}], "150": [{"angulo_tronco": 120.23167146892497, "angulo_head": 48.49767034188222}], "160": [{"angulo_tronco": 124.92819978332349, "angulo_head": 59.692865688883316}], "170": [{"angulo_tronco": 132.4808080842517, "angulo_head": 65.27971899856156}], "180": [{"angulo_tronco": 100.60911464992378, "angulo_head": 62.68741942264983}]}, "300": {"0": [{"angulo_tronco": 97.3979700618969, "angulo_head": 131.42662037915372}], "10": [{"angulo_tronco": 65.36005310724101, "angulo_head": 133.46128145119155}], "20": [{"angulo_tronco": 72.82025887832661, "angulo_head": 133.63399215190066}], "30": [{"angulo_tronco": 65.46390965610273, "angulo_head": 123.88034847397168}], "40": [{"angulo_tronco": 64.08777730499325, "angulo_head": 110.46705921336132}], "50": [{"angulo_tronco": 62.387419441651794, "angulo_head": 123.70142704132117}], "60": [{"angulo_tronco": 68.01557011857764, "angulo_head": 142.02398278568603}], "70": [{"angulo_tronco": 73.5018581044758, "angulo_head": 152.7326708213537}], "80": [{"angulo_tronco": 83.06113879709282, "angulo_head": 21.73455063327608}], "90": [{"angulo_tronco": 88.36306114461155, "angulo_head": 70.2435621921345}], "100": [{"angulo_tronco": 97.07017881895241, "angulo_head": 169.47439899395098}], "110": [{"angulo_tronco": 94.50472394134142, "angulo_head": 25.89723858014266}], "120": [{"angulo_tronco": 101.42268118742321, "angulo_head": 20.00141908428309}], "130": [{"angulo_tronco": 104.06565098977741, "angulo_head": 27.315079416765247}], "140": [{"angulo_tronco": 106.66842302934279, "angulo_head": 42.228001350307316}], "150": [{"angulo_tronco": 115.2281474521185, "angulo_head": 53.49956802296205}], "160": [{"angulo_tronco": 126.33277961898713, "angulo_head": 160.53002167635762}], "170": [{"angulo_tronco": 115.97752455018127, "angulo_head": 50.82678035110457}], "180": [{"angulo_tronco": 105.98255199323361, "angulo_head": 55.682547814633836}]}, "400": {"0": [{"angulo_tronco": 82.00767319614975, "angulo_head": 169.84164655694647}], "10": [{"angulo_tronco": 68.04779016481277, "angulo_head": 11.34570811674851}], "20": [{"angulo_tronco": 65.07876589338878, "angulo_head": 8.862327619226457}], "30": [{"angulo_tronco": 66.44191246947697, "angulo_head": 8.79341268508494}], "40": [{"angulo_tronco": 67.03502268329454, "angulo_head": 150.02088364796077}], "50": [{"angulo_tronco": 72.96865651581744, "angulo_head": 5.523806246004706}], "60": [{"angulo_tronco": 83.20587998732772, "angulo_head": 128.03941316784412}], "70": [{"angulo_tronco": 82.53980577974716, "angulo_head": 165.09177876763897}], "80": [{"angulo_tronco": 75.2042093192285, "angulo_head": 27.333975707074096}], "90": [{"angulo_tronco": 93.13182117112171, "angulo_head": 47.49992618451479}], "100": [{"angulo_tronco": 98.46737978387671, "angulo_head": 152.38490774693122}], "110": [{"angulo_tronco": 99.12652122101947, "angulo_head": 67.07140982480813}], "120": [{"angulo_tronco": 103.92649646183919, "angulo_head": 170.25729851593644}], "130": [{"angulo_tronco": 108.9066103171292, "angulo_head": 28.596297557308205}], "140": [{"angulo_tronco": 109.61420083931469, "angulo_head": 69.40567426282252}], "150": [{"angulo_tronco": 111.88490849598575, "angulo_head": 56.145321496705556}], "160": [{"angulo_tronco": 114.8323251857983, "angulo_head": 171.3879625739445}], "170": [{"angulo_tronco": 109.50551540766524, "angulo_head": 170.03063949777015}], "180": [{"angulo_tronco": 81.82959077746635, "angulo_head": 161.5903242964138}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.89009589434454, "angulo_head": 128.9590171255046}], "10": [{"angulo_tronco": 72.10235930459372, "angulo_head": 130.48825014239998}], "20": [{"angulo_tronco": 55.93956599780741, "angulo_head": 136.88399972276483}], "30": [{"angulo_tronco": 60.267259025999714, "angulo_head": 144.49873777516268}], "40": [{"angulo_tronco": 63.452288811101596, "angulo_head": 14.040368801394592}], "50": [{"angulo_tronco": 69.95701173861252, "angulo_head": 155.88828072690507}], "60": [{"angulo_tronco": 77.86887737026474, "angulo_head": 152.69839966434122}], "70": [{"angulo_tronco": 79.01960426676938, "angulo_head": 32.774718697084914}], "80": [{"angulo_tronco": 82.52015246324729, "angulo_head": 12.252286046026693}], "90": [{"angulo_tronco": 87.83744374984147, "angulo_head": 84.2782285774972}], "100": [{"angulo_tronco": 101.10437511543928, "angulo_head": 168.14431645581922}], "110": [{"angulo_tronco": 102.44839342465058, "angulo_head": 16.94523647641567}], "120": [{"angulo_tronco": 109.561617159585, "angulo_head": 48.324318267952876}], "130": [{"angulo_tronco": 111.92549938135497, "angulo_head": 52.70638774559394}], "140": [{"angulo_tronco": 119.10027542410184, "angulo_head": 36.29253837625603}], "150": [{"angulo_tronco": 128.23968745020377, "angulo_head": 63.19029033659638}], "160": [{"angulo_tronco": 115.64748644642548, "angulo_head": 49.22301943769615}], "170": [{"angulo_tronco": 125.82974191439195, "angulo_head": 63.65780682965935}], "180": [{"angulo_tronco": 94.98638580587551, "angulo_head": 55.25526083814725}]}, "300": {"0": [{"angulo_tronco": 84.22603359479388, "angulo_head": 127.4523994651004}], "10": [{"angulo_tronco": 66.84666620985342, "angulo_head": 133.64484444765847}], "20": [{"angulo_tronco": 62.10519637666126, "angulo_head": 140.63441560761302}], "30": [{"angulo_tronco": 67.30411922761887, "angulo_head": 153.13100487922307}], "40": [{"angulo_tronco": 72.66025909582872, "angulo_head": 154.5915408814448}], "50": [{"angulo_tronco": 71.43499858629797, "angulo_head": 157.96676096684504}], "60": [{"angulo_tronco": 69.99254384156443, "angulo_head": 9.562798168361766}], "70": [{"angulo_tronco": 82.19512953129735, "angulo_head": 19.470133750890053}], "80": [{"angulo_tronco": 82.60281099740169, "angulo_head": 0.28281463810809065}], "90": [{"angulo_tronco": 87.48914979547675, "angulo_head": 90.81114448074808}], "100": [{"angulo_tronco": 95.05038291950923, "angulo_head": 162.38681121381265}], "110": [{"angulo_tronco": 99.59629555829055, "angulo_head": 29.349767295667597}], "120": [{"angulo_tronco": 107.44678868475684, "angulo_head": 165.90980002451315}], "130": [{"angulo_tronco": 110.01409706582338, "angulo_head": 171.77482271536618}], "140": [{"angulo_tronco": 101.13260710265244, "angulo_head": 40.851013711882416}], "150": [{"angulo_tronco": 114.45713411305927, "angulo_head": 40.74066195615705}], "160": [{"angulo_tronco": 122.55722009714133, "angulo_head": 56.76948751034682}], "170": [{"angulo_tronco": 119.85549278130803, "angulo_head": 46.54103545276941}], "180": [{"angulo_tronco": 173.3557103416529, "angulo_head": 131.1948177326733}]}, "400": {"0": [{"angulo_tronco": 89.85168751992542, "angulo_head": 10.855855178548879}], "10": [], "20": [{"angulo_tronco": 57.808136282117424, "angulo_head": 137.99975310447758}], "30": [{"angulo_tronco": 65.82162874294302, "angulo_head": 154.48245141131733}], "40": [{"angulo_tronco": 73.87737071315684, "angulo_head": 8.074839499350535}], "50": [{"angulo_tronco": 76.57768824113339, "angulo_head": 7.462914553633605}], "60": [{"angulo_tronco": 76.05811101669607, "angulo_head": 5.813762619899712}], "70": [{"angulo_tronco": 77.6167677392903, "angulo_head": 21.891617432524274}], "80": [{"angulo_tronco": 82.5479307971583, "angulo_head": 3.897411677228265}], "90": [{"angulo_tronco": 89.54588128625464, "angulo_head": 58.60405326983335}], "100": [{"angulo_tronco": 93.52298017140225, "angulo_head": 154.50495650963634}], "110": [{"angulo_tronco": 106.09712669364212, "angulo_head": 171.90113231595961}], "120": [{"angulo_tronco": 104.5868955971309, "angulo_head": 147.69622697386487}], "130": [{"angulo_tronco": 110.65814011489893, "angulo_head": 155.85544547229802}], "140": [{"angulo_tronco": 109.59836378887245, "angulo_head": 20.83893306982958}], "150": [{"angulo_tronco": 111.49169585050305, "angulo_head": 36.11379309446939}], "160": [{"angulo_tronco": 104.96485574545646, "angulo_head": 171.60305982401445}], "170": [{"angulo_tronco": 114.38455601298105, "angulo_head": 170.99706841842664}], "180": []}}, "centroide": {"200": [{"respuesta": 216.6385319469497}], "250": [{"respuesta": 259.1378151940221}], "300": [{"respuesta": 306.79342949492417}], "350": [{"respuesta": 342.68528184585693}], "400": [{"respuesta": 377.5540941950634}], "450": [{"respuesta": 415.04348258405776}], "500": [{"respuesta": 441.8093178501516}], "550": [{"respuesta": 477.67298656083915}], "600": [{"respuesta": 499.8916944945662}]}, "centroide_grupal": {"200": [{"respuesta": 224.2546372334914}], "250": [{"respuesta": 268.10500635598015}], "300": [{"respuesta": 303.9915210686258}, {"respuesta": 303.9565335197759}], "350": [{"respuesta": 348.3743802496378}, {"respuesta": 348.84350691397736}], "400": [{"respuesta": 372.6030335102232}], "450": [{"respuesta": 412.35876726333095}, {"respuesta": 412.93769151049537}], "500": [{"respuesta": 437.19495776803706}], "550": [{"respuesta": 467.1149139506465}, {"respuesta": 445.2846455416956}], "600": [{"respuesta": 443.6198455296255}]}, "height_167": {"200": [{"respuesta": 179.42455427744736}], "250": [{"respuesta": 173.59865585688812}], "300": [{"respuesta": 166.98462503641525}], "350": [{"respuesta": 158.1267632304426}], "400": [{"respuesta": 152.08377379191305}], "450": [{"respuesta": 147.33181121454177}], "500": [{"respuesta": 145.11352511382}], "550": [{"respuesta": 137.8892579634696}], "600": [{"respuesta": 133.5953991537451}]}}

# %%
# selective
# json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "99.11893606185913"}]}, "400": {"C": [{"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.34904617764886, "angulo_head": 77.29303453452299}], "10": [{"angulo_tronco": 70.74060043922249, "angulo_head": 78.40791501788716}], "20": [{"angulo_tronco": 57.602604128014164, "angulo_head": 77.68615982212117}], "30": [{"angulo_tronco": 60.216751810382455, "angulo_head": 79.67511506303632}], "40": [{"angulo_tronco": 56.251657288014414, "angulo_head": 80.59817713180672}], "50": [{"angulo_tronco": 67.54947018971802, "angulo_head": 82.19523841971937}], "60": [{"angulo_tronco": 74.51553955865512, "angulo_head": 84.58932107194963}], "70": [{"angulo_tronco": 81.32952007455876, "angulo_head": 83.15022853603134}], "80": [{"angulo_tronco": 85.72158842884109, "angulo_head": 85.7508132659755}], "90": [{"angulo_tronco": 87.12824806383621, "angulo_head": 88.10284173051515}], "100": [{"angulo_tronco": 98.48839373082123, "angulo_head": 92.13752722550863}], "110": [{"angulo_tronco": 98.2999579589563, "angulo_head": 91.5734181657187}], "120": [{"angulo_tronco": 111.57644966031901, "angulo_head": 93.82437668906103}], "130": [{"angulo_tronco": 110.39575729785368, "angulo_head": 95.33949467623157}], "140": [{"angulo_tronco": 118.98840944221534, "angulo_head": 96.19976764416074}], "150": [{"angulo_tronco": 120.27425338161295, "angulo_head": 96.23867090139726}], "160": [{"angulo_tronco": 124.94536967524763, "angulo_head": 95.51806204181891}], "170": [{"angulo_tronco": 132.44436093208583, "angulo_head": 95.73121603944541}], "180": [{"angulo_tronco": 100.70792609222502, "angulo_head": 98.93774484041988}]}, "300": {"0": [{"angulo_tronco": 97.51715293342998, "angulo_head": 75.929653433544}], "10": [{"angulo_tronco": 65.25860856148111, "angulo_head": 76.34352400148406}], "20": [{"angulo_tronco": 72.86238432077403, "angulo_head": 76.83421816697773}], "30": [{"angulo_tronco": 65.4680715205388, "angulo_head": 77.89751312972076}], "40": [{"angulo_tronco": 64.08101069381752, "angulo_head": 80.97568229247152}], "50": [{"angulo_tronco": 62.38525818407618, "angulo_head": 87.67469196880293}], "60": [{"angulo_tronco": 68.00662567589467, "angulo_head": 85.84569340042319}], "70": [{"angulo_tronco": 73.49766596401584, "angulo_head": 78.37493064752461}], "80": [{"angulo_tronco": 83.07801902351852, "angulo_head": 97.70903666780967}], "90": [{"angulo_tronco": 88.35238892316247, "angulo_head": 89.06241811685068}], "100": [{"angulo_tronco": 97.05891230745031, "angulo_head": 86.26678091363726}], "110": [{"angulo_tronco": 94.49944195990221, "angulo_head": 85.63849813947904}], "120": [{"angulo_tronco": 101.39012278982602, "angulo_head": 97.32878631215591}], "130": [{"angulo_tronco": 104.06262693805239, "angulo_head": 88.82440373583944}], "140": [{"angulo_tronco": 106.66043543117073, "angulo_head": 87.29597204283431}], "150": [{"angulo_tronco": 115.23578903814358, "angulo_head": 97.77994802789758}], "160": [{"angulo_tronco": 126.32434746003273, "angulo_head": 94.58164271979197}], "170": [{"angulo_tronco": 116.00326846124483, "angulo_head": 95.23356187875487}], "180": [{"angulo_tronco": 105.8236359589228, "angulo_head": 101.20843162690666}]}, "400": {"0": [{"angulo_tronco": 81.85190618535061, "angulo_head": 139.48254119990358}], "10": [{"angulo_tronco": 68.60610707932993, "angulo_head": 139.23514632549367}], "20": [{"angulo_tronco": 65.09687204982079, "angulo_head": 139.7434872122886}], "30": [{"angulo_tronco": 66.45614897647556, "angulo_head": 139.7569871345606}], "40": [{"angulo_tronco": 66.98111910695671, "angulo_head": 81.5625570755581}], "50": [{"angulo_tronco": 72.95170745407347, "angulo_head": 86.07533491435157}], "60": [{"angulo_tronco": 83.44904053845568, "angulo_head": 87.51321868638783}], "70": [{"angulo_tronco": 82.55431441553198, "angulo_head": 87.77165939501869}], "80": [{"angulo_tronco": 75.22485927354411, "angulo_head": 85.0919618287509}], "90": [{"angulo_tronco": 93.1705796180147, "angulo_head": 88.55901381606105}], "100": [{"angulo_tronco": 98.55163896643695, "angulo_head": 88.57120822449936}], "110": [{"angulo_tronco": 99.11572106435015, "angulo_head": 89.45474332183261}], "120": [{"angulo_tronco": 103.92412781706112, "angulo_head": 94.00434927329204}], "130": [{"angulo_tronco": 108.86846549041447, "angulo_head": 98.67572803871182}], "140": [{"angulo_tronco": 109.59566695371277, "angulo_head": 91.13199447553683}], "150": [{"angulo_tronco": 111.85391095088652, "angulo_head": 91.94793552857462}], "160": [{"angulo_tronco": 114.7870589204576, "angulo_head": 142.9851615986027}], "170": [{"angulo_tronco": 109.57146072230915, "angulo_head": 142.4958398249233}], "180": [{"angulo_tronco": 81.82471317435824, "angulo_head": 140.78212631952601}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.86403689519207, "angulo_head": 79.11976916423691}], "10": [{"angulo_tronco": 72.12012347785091, "angulo_head": 79.15290847911206}], "20": [{"angulo_tronco": 55.94558583365423, "angulo_head": 80.31057868110223}], "30": [{"angulo_tronco": 60.278340931836944, "angulo_head": 81.82110669154534}], "40": [{"angulo_tronco": 63.450041064806925, "angulo_head": 81.02911038038236}], "50": [{"angulo_tronco": 69.95250544242826, "angulo_head": 82.6850265546736}], "60": [{"angulo_tronco": 77.89868731412868, "angulo_head": 84.99751353898267}], "70": [{"angulo_tronco": 79.0160010838058, "angulo_head": 84.65105013641104}], "80": [{"angulo_tronco": 82.51695566054283, "angulo_head": 85.6521454525622}], "90": [{"angulo_tronco": 87.85063718963515, "angulo_head": 89.92838188703652}], "100": [{"angulo_tronco": 101.10325852301473, "angulo_head": 92.15726443892628}], "110": [{"angulo_tronco": 102.46101442784236, "angulo_head": 93.43724738603166}], "120": [{"angulo_tronco": 109.55076923951012, "angulo_head": 93.1618625719228}], "130": [{"angulo_tronco": 111.9167863746922, "angulo_head": 94.08116079394429}], "140": [{"angulo_tronco": 119.08224913274911, "angulo_head": 95.15542447445239}], "150": [{"angulo_tronco": 128.23378586882066, "angulo_head": 93.9719547189995}], "160": [{"angulo_tronco": 115.64395221510708, "angulo_head": 98.22472027227165}], "170": [{"angulo_tronco": 125.81113208191711, "angulo_head": 97.48200819177717}], "180": [{"angulo_tronco": 94.99202501145672, "angulo_head": 101.28808108981288}]}, "300": {"0": [{"angulo_tronco": 84.36578233666513, "angulo_head": 78.94616418827233}], "10": [{"angulo_tronco": 66.89305264486816, "angulo_head": 78.08445289483792}], "20": [{"angulo_tronco": 62.122793194427416, "angulo_head": 78.80001325517308}], "30": [{"angulo_tronco": 67.34733117883124, "angulo_head": 79.19519705416806}], "40": [{"angulo_tronco": 72.64925145226431, "angulo_head": 80.3529357227014}], "50": [{"angulo_tronco": 71.39032096902439, "angulo_head": 81.26443869533499}], "60": [{"angulo_tronco": 69.98587129930013, "angulo_head": 81.66928159843772}], "70": [{"angulo_tronco": 82.20245440867141, "angulo_head": 85.916032993279}], "80": [{"angulo_tronco": 82.61445295004009, "angulo_head": 87.8908990534373}], "90": [{"angulo_tronco": 87.47457506879346, "angulo_head": 90.02581997735862}], "100": [{"angulo_tronco": 95.03334646084265, "angulo_head": 91.69305549305271}], "110": [{"angulo_tronco": 99.58104350085657, "angulo_head": 91.730838095713}], "120": [{"angulo_tronco": 107.4638623883049, "angulo_head": 93.92296377874621}], "130": [{"angulo_tronco": 110.07021642954226, "angulo_head": 95.54713678945973}], "140": [{"angulo_tronco": 101.08088589582756, "angulo_head": 96.203502288628}], "150": [{"angulo_tronco": 114.43365049391103, "angulo_head": 95.4891463607332}], "160": [{"angulo_tronco": 122.5524936683824, "angulo_head": 97.81392593121029}], "170": [{"angulo_tronco": 119.82920604988338, "angulo_head": 99.60329263411437}], "180": [{"angulo_tronco": 173.2354390861765, "angulo_head": 101.41649675780124}]}, "400": {"0": [{"angulo_tronco": 89.84891589795524, "angulo_head": 140.23001615167306}], "10": [], "20": [{"angulo_tronco": 57.757825901294396, "angulo_head": 80.51370167944198}], "30": [{"angulo_tronco": 65.82153950561316, "angulo_head": 80.14922262879409}], "40": [{"angulo_tronco": 73.9115560118862, "angulo_head": 79.77055865536713}], "50": [{"angulo_tronco": 76.5995635630585, "angulo_head": 81.74304336735608}], "60": [{"angulo_tronco": 76.07668681993137, "angulo_head": 86.55794807307403}], "70": [{"angulo_tronco": 77.64125862333702, "angulo_head": 86.3962931221487}], "80": [{"angulo_tronco": 82.50026516052827, "angulo_head": 87.47658301207089}], "90": [{"angulo_tronco": 89.57352821043402, "angulo_head": 89.38546866202793}], "100": [{"angulo_tronco": 93.52418449205315, "angulo_head": 91.10841267508407}], "110": [{"angulo_tronco": 106.13082466315029, "angulo_head": 92.65401399920275}], "120": [{"angulo_tronco": 104.55016399650835, "angulo_head": 92.2400891253668}], "130": [{"angulo_tronco": 110.6630413779969, "angulo_head": 93.21071134294124}], "140": [{"angulo_tronco": 109.62982777410095, "angulo_head": 97.21993019946723}], "150": [{"angulo_tronco": 111.44991457117915, "angulo_head": 98.48506353943685}], "160": [{"angulo_tronco": 105.1036346917081, "angulo_head": 143.0316743782758}], "170": [{"angulo_tronco": 114.44521811233668, "angulo_head": 143.45066113785518}], "180": []}}, "centroide": {"200": [{"respuesta": 216.63974548481323}], "250": [{"respuesta": 259.1335789433416}], "300": [{"respuesta": 306.7983747405587}], "350": [{"respuesta": 342.6836926611685}], "400": [{"respuesta": 377.5616695384383}], "450": [{"respuesta": 415.0471642951218}], "500": [{"respuesta": 441.82784527897104}], "550": [{"respuesta": 477.7003493755452}], "600": [{"respuesta": 499.87807091095897}]}, "centroide_grupal": {"200": [{"respuesta": 224.2532696861978}], "250": [{"respuesta": 268.1055407400862}], "300": [{"respuesta": 303.9926159896883}, {"respuesta": 303.9603208762752}], "350": [{"respuesta": 348.3698951347183}, {"respuesta": 348.8457631193408}], "400": [{"respuesta": 372.60608387065906}], "450": [{"respuesta": 412.35469960463917}, {"respuesta": 412.9378374947264}], "500": [{"respuesta": 437.19526659011535}], "550": [{"respuesta": 467.1022279750118}, {"respuesta": 445.28406417266785}], "600": [{"respuesta": 443.60646029801546}]}, "height_167": {"200": [{"respuesta": 179.425519175857}], "250": [{"respuesta": 173.58649328499865}], "300": [{"respuesta": 166.9814177867548}], "350": [{"respuesta": 158.13829187752947}], "400": [{"respuesta": 152.08031170481505}], "450": [{"respuesta": 147.32540695548457}], "500": [{"respuesta": 145.1244311034335}], "550": [{"respuesta": 137.89391283234474}], "600": [{"respuesta": 133.608466047033}]}}

# wls
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.7074064485598, "angulo_head": 17.706559988209655}], "10": [{"angulo_tronco": 77.05770725494713, "angulo_head": 11.744904706068828}], "20": [{"angulo_tronco": 77.29625688219122, "angulo_head": 11.30837979027404}], "30": [{"angulo_tronco": 76.44628719983378, "angulo_head": 79.63803502347524}], "40": [{"angulo_tronco": 74.42143025945512, "angulo_head": 80.70419040553351}], "50": [{"angulo_tronco": 75.61906516799877, "angulo_head": 82.13433205134821}], "60": [{"angulo_tronco": 80.08513370170958, "angulo_head": 84.47940937563192}], "70": [{"angulo_tronco": 81.32296109046554, "angulo_head": 83.15819908873132}], "80": [{"angulo_tronco": 88.48223802406459, "angulo_head": 85.46175396064416}], "90": [{"angulo_tronco": 91.40173091287262, "angulo_head": 88.19643281915458}], "100": [{"angulo_tronco": 95.6567021713687, "angulo_head": 92.07032766738443}], "110": [{"angulo_tronco": 96.63807097910947, "angulo_head": 91.39358000486733}], "120": [{"angulo_tronco": 100.13448872571506, "angulo_head": 93.6324312857268}], "130": [{"angulo_tronco": 104.49705784550567, "angulo_head": 94.27207950893337}], "140": [{"angulo_tronco": 109.09081950676126, "angulo_head": 95.19045533489633}], "150": [{"angulo_tronco": 105.40653956449154, "angulo_head": 93.56141188611873}], "160": [{"angulo_tronco": 105.5653116282023, "angulo_head": 93.33873699277}], "170": [{"angulo_tronco": 104.86973138515397, "angulo_head": 93.00587991588964}], "180": [{"angulo_tronco": 90.22881297276098, "angulo_head": 24.62908998216105}]}, "300": {"0": [{"angulo_tronco": 89.59215084691922, "angulo_head": 76.09303061174157}], "10": [{"angulo_tronco": 74.72310863784656, "angulo_head": 75.84695760462587}], "20": [{"angulo_tronco": 81.28537587938662, "angulo_head": 77.059465496468}], "30": [{"angulo_tronco": 82.55882336012758, "angulo_head": 78.76973833221456}], "40": [{"angulo_tronco": 74.9097980628899, "angulo_head": 82.2069788932872}], "50": [{"angulo_tronco": 71.27333700136495, "angulo_head": 87.65516555405465}], "60": [{"angulo_tronco": 75.27911402074403, "angulo_head": 85.85383190669023}], "70": [{"angulo_tronco": 78.74054930016817, "angulo_head": 77.05831911008671}], "80": [{"angulo_tronco": 78.16371659750804, "angulo_head": 97.74302768220318}], "90": [{"angulo_tronco": 85.78818325364954, "angulo_head": 89.10572230625324}], "100": [{"angulo_tronco": 88.51525582824765, "angulo_head": 86.4248672776234}], "110": [{"angulo_tronco": 91.41981364445623, "angulo_head": 85.65200963926502}], "120": [{"angulo_tronco": 94.76780588471829, "angulo_head": 97.1606776396648}], "130": [{"angulo_tronco": 100.9928248179324, "angulo_head": 88.85633412756073}], "140": [{"angulo_tronco": 99.3448783592089, "angulo_head": 87.35149208100815}], "150": [{"angulo_tronco": 98.73875424274695, "angulo_head": 96.71684475636705}], "160": [{"angulo_tronco": 105.76939823936276, "angulo_head": 94.54859196436459}], "170": [{"angulo_tronco": 106.64680849986597, "angulo_head": 95.1190486821136}], "180": [{"angulo_tronco": 92.59079680974855, "angulo_head": 28.541736887816903}]}, "400": {"0": [{"angulo_tronco": 88.96273028930368, "angulo_head": 73.48133095804711}], "10": [{"angulo_tronco": 86.8843559545158, "angulo_head": 73.13244149336738}], "20": [{"angulo_tronco": 64.5039234617289, "angulo_head": 78.9228738894569}], "30": [{"angulo_tronco": 65.4952916659646, "angulo_head": 79.40743924137392}], "40": [{"angulo_tronco": 65.54149027805974, "angulo_head": 81.60439097731319}], "50": [{"angulo_tronco": 74.64843391605035, "angulo_head": 86.08904708270873}], "60": [{"angulo_tronco": 72.63688110478054, "angulo_head": 87.57568436571817}], "70": [{"angulo_tronco": 79.13698614640532, "angulo_head": 87.7353219858077}], "80": [{"angulo_tronco": 77.65166310246713, "angulo_head": 85.06899207336835}], "90": [{"angulo_tronco": 81.91857880771538, "angulo_head": 88.57999621867039}], "100": [{"angulo_tronco": 87.38281556505223, "angulo_head": 88.62804747205188}], "110": [{"angulo_tronco": 89.62480392348876, "angulo_head": 89.63302965610505}], "120": [{"angulo_tronco": 92.95832393284368, "angulo_head": 94.14209922054795}], "130": [{"angulo_tronco": 92.78969305034776, "angulo_head": 98.63159839629748}], "140": [{"angulo_tronco": 88.80533159736315, "angulo_head": 91.26833109945517}], "150": [{"angulo_tronco": 100.36974790173741, "angulo_head": 91.97508976318426}], "160": [{"angulo_tronco": 104.07496616908858, "angulo_head": 103.63490950789435}], "170": [{"angulo_tronco": 79.7390985025143, "angulo_head": 100.82420724308227}], "180": [{"angulo_tronco": 91.16956371277506, "angulo_head": 103.26789996700096}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.75984892565317, "angulo_head": 27.560004707142173}], "10": [{"angulo_tronco": 75.71390830442068, "angulo_head": 26.299547779621847}], "20": [{"angulo_tronco": 74.40752964838582, "angulo_head": 81.09826969514297}], "30": [{"angulo_tronco": 74.10790609871545, "angulo_head": 80.89460280881087}], "40": [{"angulo_tronco": 76.28897414593261, "angulo_head": 80.84208995210008}], "50": [{"angulo_tronco": 78.21405664553996, "angulo_head": 82.59612210024267}], "60": [{"angulo_tronco": 80.68814280981532, "angulo_head": 84.94005304128999}], "70": [{"angulo_tronco": 83.15490561132435, "angulo_head": 84.62855343137403}], "80": [{"angulo_tronco": 84.50933933245823, "angulo_head": 85.69905945523081}], "90": [{"angulo_tronco": 90.0, "angulo_head": 89.85567153912386}], "100": [{"angulo_tronco": 96.63596447524036, "angulo_head": 92.10274837619534}], "110": [{"angulo_tronco": 96.80922912278935, "angulo_head": 93.38934611810437}], "120": [{"angulo_tronco": 98.9229815743087, "angulo_head": 93.15732219747935}], "130": [{"angulo_tronco": 99.37838479017016, "angulo_head": 94.05112852553239}], "140": [{"angulo_tronco": 101.90776594871012, "angulo_head": 94.8263325406338}], "150": [{"angulo_tronco": 101.8210133473148, "angulo_head": 93.02872410204374}], "160": [{"angulo_tronco": 100.13484505212077, "angulo_head": 95.91846861093606}], "170": [{"angulo_tronco": 100.56493816441778, "angulo_head": 24.947938947639965}], "180": [{"angulo_tronco": 91.44724789522074, "angulo_head": 25.186134645839804}]}, "300": {"0": [{"angulo_tronco": 91.50742757043707, "angulo_head": 9.686808611005826}], "10": [{"angulo_tronco": 91.15592903440765, "angulo_head": 13.723944814994391}], "20": [{"angulo_tronco": 84.30018735788408, "angulo_head": 78.76484144437676}], "30": [{"angulo_tronco": 85.49389483561056, "angulo_head": 78.11207737027274}], "40": [{"angulo_tronco": 80.54482186386973, "angulo_head": 80.41977047819876}], "50": [{"angulo_tronco": 79.77555566987587, "angulo_head": 81.33482303715586}], "60": [{"angulo_tronco": 78.53392119994577, "angulo_head": 81.72794188102536}], "70": [{"angulo_tronco": 84.25137229032055, "angulo_head": 85.85563946998009}], "80": [{"angulo_tronco": 85.84955898001397, "angulo_head": 87.86210249279623}], "90": [{"angulo_tronco": 87.48207101707118, "angulo_head": 89.92070220648526}], "100": [{"angulo_tronco": 91.46623543162019, "angulo_head": 91.57028619326354}], "110": [{"angulo_tronco": 92.96946549978087, "angulo_head": 91.64981839414203}], "120": [{"angulo_tronco": 94.83889675312686, "angulo_head": 92.88838199294479}], "130": [{"angulo_tronco": 93.53193106499032, "angulo_head": 93.86709393880099}], "140": [{"angulo_tronco": 93.77627937784284, "angulo_head": 94.50724292320002}], "150": [{"angulo_tronco": 93.99755439085598, "angulo_head": 93.09537215195469}], "160": [{"angulo_tronco": 92.63869290613535, "angulo_head": 94.7632610683386}], "170": [{"angulo_tronco": 94.36762714443748, "angulo_head": 25.169167832885975}], "180": [{"angulo_tronco": 90.0, "angulo_head": 23.28241929337278}]}, "400": {"0": [{"angulo_tronco": 94.11079779832843, "angulo_head": 77.41550812687234}], "10": [], "20": [{"angulo_tronco": 81.0303404453366, "angulo_head": 80.43291503027044}], "30": [{"angulo_tronco": 83.42971821784167, "angulo_head": 79.68312643380864}], "40": [{"angulo_tronco": 80.48570881184936, "angulo_head": 79.86290378996738}], "50": [{"angulo_tronco": 84.37948422759774, "angulo_head": 82.04845825753348}], "60": [{"angulo_tronco": 84.91991670180006, "angulo_head": 86.55795311722075}], "70": [{"angulo_tronco": 82.78758127337208, "angulo_head": 86.47965311111095}], "80": [{"angulo_tronco": 87.67448998736376, "angulo_head": 87.32360674208097}], "90": [{"angulo_tronco": 87.84919582721047, "angulo_head": 89.21306883674754}], "100": [{"angulo_tronco": 90.09837828242058, "angulo_head": 91.15154782808244}], "110": [{"angulo_tronco": 90.1900439404048, "angulo_head": 92.68591456262334}], "120": [{"angulo_tronco": 89.97955179690216, "angulo_head": 92.04430188663798}], "130": [{"angulo_tronco": 96.55629462018081, "angulo_head": 93.21561499653383}], "140": [{"angulo_tronco": 90.0, "angulo_head": 96.99022564069588}], "150": [{"angulo_tronco": 93.9044408407329, "angulo_head": 97.11878978811163}], "160": [{"angulo_tronco": 97.80347461189751, "angulo_head": 99.71977314792782}], "170": [{"angulo_tronco": 90.9341491667609, "angulo_head": 100.80854927117588}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# %%
# wls nuevos vectores
json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.70334081346284, "angulo_head": 17.56660544140292}], "10": [{"angulo_tronco": 76.99360879157834, "angulo_head": 11.178474540200712}], "20": [{"angulo_tronco": 77.2949016529465, "angulo_head": 10.8117512118006}], "30": [{"angulo_tronco": 76.44581531699694, "angulo_head": 35.52203335366441}], "40": [{"angulo_tronco": 74.41588059948681, "angulo_head": 38.57517168724967}], "50": [{"angulo_tronco": 75.57532645951419, "angulo_head": 28.66330531676842}], "60": [{"angulo_tronco": 80.06511168797292, "angulo_head": 29.938822898747446}], "70": [{"angulo_tronco": 81.31081524571312, "angulo_head": 1.2040964620854056}], "80": [{"angulo_tronco": 88.47758972997853, "angulo_head": 32.828510496279165}], "90": [{"angulo_tronco": 91.4021865775563, "angulo_head": 54.90903173395498}], "100": [{"angulo_tronco": 95.67846619638459, "angulo_head": 171.0282853033781}], "110": [{"angulo_tronco": 96.78077168819809, "angulo_head": 122.66738700736833}], "120": [{"angulo_tronco": 100.38980258114441, "angulo_head": 125.44053390266195}], "130": [{"angulo_tronco": 104.80194763569258, "angulo_head": 106.05531053293494}], "140": [{"angulo_tronco": 109.47862418463153, "angulo_head": 115.90594583554781}], "150": [{"angulo_tronco": 105.74797890238806, "angulo_head": 108.5326942011332}], "160": [{"angulo_tronco": 105.64500555727192, "angulo_head": 109.37086904175513}], "170": [{"angulo_tronco": 105.01410559516648, "angulo_head": 95.56052744060207}], "180": [{"angulo_tronco": 90.22881707821931, "angulo_head": 11.21495915191994}]}, "300": {"0": [{"angulo_tronco": 89.59039326656475, "angulo_head": 51.342735509661516}], "10": [{"angulo_tronco": 74.49788463045553, "angulo_head": 51.896273741967185}], "20": [{"angulo_tronco": 81.2852560124775, "angulo_head": 54.630768263038924}], "30": [{"angulo_tronco": 82.55112377002777, "angulo_head": 40.28374912041732}], "40": [{"angulo_tronco": 74.90978208231347, "angulo_head": 42.37753569362289}], "50": [{"angulo_tronco": 71.24814782937486, "angulo_head": 16.914979098031605}], "60": [{"angulo_tronco": 75.23717234208841, "angulo_head": 11.645784658469212}], "70": [{"angulo_tronco": 78.72067134966929, "angulo_head": 19.649105336338682}], "80": [{"angulo_tronco": 78.11559551251045, "angulo_head": 179.7829630126809}], "90": [{"angulo_tronco": 85.78520585441157, "angulo_head": 80.96494799929026}], "100": [{"angulo_tronco": 88.515157075264, "angulo_head": 42.05010399679801}], "110": [{"angulo_tronco": 91.42809103947316, "angulo_head": 23.77098370226349}], "120": [{"angulo_tronco": 94.78023973357593, "angulo_head": 117.09179253340518}], "130": [{"angulo_tronco": 100.9941629214323, "angulo_head": 38.65417283727337}], "140": [{"angulo_tronco": 99.38410422541695, "angulo_head": 8.442346579512801}], "150": [{"angulo_tronco": 99.13135117143034, "angulo_head": 116.24133933495467}], "160": [{"angulo_tronco": 106.31579904284432, "angulo_head": 119.36118582745205}], "170": [{"angulo_tronco": 107.09760328026368, "angulo_head": 113.24286524378539}], "180": [{"angulo_tronco": 92.59760407600153, "angulo_head": 22.300380834937386}]}, "400": {"0": [{"angulo_tronco": 88.9611970720595, "angulo_head": 43.648023982848095}], "10": [{"angulo_tronco": 86.8797392437506, "angulo_head": 8.449957803588003}], "20": [{"angulo_tronco": 64.49610683409828, "angulo_head": 4.021888843232577}], "30": [{"angulo_tronco": 65.48764650630508, "angulo_head": 35.92663803167994}], "40": [{"angulo_tronco": 65.53955773514275, "angulo_head": 28.058152761688003}], "50": [{"angulo_tronco": 74.64683275873924, "angulo_head": 61.789884873338956}], "60": [{"angulo_tronco": 72.63600558098629, "angulo_head": 65.34403737723385}], "70": [{"angulo_tronco": 79.13595231933685, "angulo_head": 71.67976940281024}], "80": [{"angulo_tronco": 77.62846930430189, "angulo_head": 38.1559062671939}], "90": [{"angulo_tronco": 81.90082047618509, "angulo_head": 74.64032052865774}], "100": [{"angulo_tronco": 87.38231882443301, "angulo_head": 30.42512856501636}], "110": [{"angulo_tronco": 89.61158529262502, "angulo_head": 86.63653484000979}], "120": [{"angulo_tronco": 92.9600375515751, "angulo_head": 152.60302224992972}], "130": [{"angulo_tronco": 92.79017775764935, "angulo_head": 172.74587418554958}], "140": [{"angulo_tronco": 88.69013538367946, "angulo_head": 100.02353085935174}], "150": [{"angulo_tronco": 100.40296577879708, "angulo_head": 130.33272780149557}], "160": [{"angulo_tronco": 104.45880420312005, "angulo_head": 135.80300114558696}], "170": [{"angulo_tronco": 79.6194131564416, "angulo_head": 117.21953644327778}], "180": [{"angulo_tronco": 91.17348198383658, "angulo_head": 169.81408421128216}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.74467408715212, "angulo_head": 27.514389820082492}], "10": [{"angulo_tronco": 75.66747660800482, "angulo_head": 26.215496440688494}], "20": [{"angulo_tronco": 74.40250851834129, "angulo_head": 72.9626201616738}], "30": [{"angulo_tronco": 74.08385646817175, "angulo_head": 65.14299434621495}], "40": [{"angulo_tronco": 76.28196951670803, "angulo_head": 29.015320788005095}], "50": [{"angulo_tronco": 78.1722405942679, "angulo_head": 29.10351567800873}], "60": [{"angulo_tronco": 80.6642659880833, "angulo_head": 32.715635438898005}], "70": [{"angulo_tronco": 83.15133251364718, "angulo_head": 44.09914280910142}], "80": [{"angulo_tronco": 84.5087787789406, "angulo_head": 40.874420353499346}], "90": [{"angulo_tronco": 90.0, "angulo_head": 44.10969846171719}], "100": [{"angulo_tronco": 96.69101666258528, "angulo_head": 144.1348348144727}], "110": [{"angulo_tronco": 96.84597887414675, "angulo_head": 140.37520457947275}], "120": [{"angulo_tronco": 99.12348209187502, "angulo_head": 121.44559903246528}], "130": [{"angulo_tronco": 99.61986803335917, "angulo_head": 118.95472538805404}], "140": [{"angulo_tronco": 102.14898142643796, "angulo_head": 112.521335014468}], "150": [{"angulo_tronco": 102.03804785080396, "angulo_head": 96.43722648852933}], "160": [{"angulo_tronco": 100.26290973425002, "angulo_head": 117.83501785411146}], "170": [{"angulo_tronco": 100.6261747520111, "angulo_head": 14.89836860059407}], "180": [{"angulo_tronco": 91.44770981155105, "angulo_head": 15.584771961576857}]}, "300": {"0": [{"angulo_tronco": 91.50794955768255, "angulo_head": 7.600466525133131}], "10": [{"angulo_tronco": 91.1576055190743, "angulo_head": 13.059028947566796}], "20": [{"angulo_tronco": 84.25730376823243, "angulo_head": 39.634383227931124}], "30": [{"angulo_tronco": 85.49365280629874, "angulo_head": 52.60979863919088}], "40": [{"angulo_tronco": 80.54470485901155, "angulo_head": 16.4403922740087}], "50": [{"angulo_tronco": 79.77549598192657, "angulo_head": 2.791610619569728}], "60": [{"angulo_tronco": 78.53350791032213, "angulo_head": 27.468705930768206}], "70": [{"angulo_tronco": 84.25042063937669, "angulo_head": 20.062372518615334}], "80": [{"angulo_tronco": 85.8487006864408, "angulo_head": 18.97104853635193}], "90": [{"angulo_tronco": 87.47696998093488, "angulo_head": 74.27607252000064}], "100": [{"angulo_tronco": 91.47009598656446, "angulo_head": 114.60381922413484}], "110": [{"angulo_tronco": 93.013831713478, "angulo_head": 114.32936343935117}], "120": [{"angulo_tronco": 94.91045273462908, "angulo_head": 96.68986971353506}], "130": [{"angulo_tronco": 93.53381338045416, "angulo_head": 137.5443366361454}], "140": [{"angulo_tronco": 93.8305518850191, "angulo_head": 107.20836010424122}], "150": [{"angulo_tronco": 94.04006357867296, "angulo_head": 107.97151796841669}], "160": [{"angulo_tronco": 92.63878194871683, "angulo_head": 117.44238143398893}], "170": [{"angulo_tronco": 94.37012929738124, "angulo_head": 16.782775909207228}], "180": [{"angulo_tronco": 90.0, "angulo_head": 12.73342667622608}]}, "400": {"0": [{"angulo_tronco": 94.12141931057673, "angulo_head": 55.21155198892544}], "10": [], "20": [{"angulo_tronco": 81.02256850652581, "angulo_head": 51.572035795464274}], "30": [{"angulo_tronco": 83.42693531107538, "angulo_head": 27.551293088375495}], "40": [{"angulo_tronco": 80.48477560729069, "angulo_head": 9.03208871778202}], "50": [{"angulo_tronco": 84.37873818765885, "angulo_head": 42.86573578546716}], "60": [{"angulo_tronco": 84.91512513950613, "angulo_head": 16.63197452830223}], "70": [{"angulo_tronco": 82.78256227200553, "angulo_head": 51.83027694907997}], "80": [{"angulo_tronco": 87.6739971789383, "angulo_head": 43.06517646395466}], "90": [{"angulo_tronco": 87.84422967480224, "angulo_head": 72.47993698263849}], "100": [{"angulo_tronco": 90.0986289954239, "angulo_head": 136.66188300878446}], "110": [{"angulo_tronco": 90.19621221159704, "angulo_head": 173.64837527404305}], "120": [{"angulo_tronco": 89.97954594865651, "angulo_head": 113.42198510381}], "130": [{"angulo_tronco": 96.56029039115298, "angulo_head": 161.5371181339294}], "140": [{"angulo_tronco": 90.0, "angulo_head": 128.28063525975193}], "150": [{"angulo_tronco": 93.94866688392632, "angulo_head": 138.96908913272483}], "160": [{"angulo_tronco": 97.8087157885947, "angulo_head": 154.47958610052805}], "170": [{"angulo_tronco": 90.93526859572974, "angulo_head": 124.6948546504437}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# Selective
json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "98.96577000617981"}]}, "400": {"C": [{"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.93072748184204"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.32182431221008"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.8841941356659"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.32252749392586, "angulo_head": 51.7477649425917}], "10": [{"angulo_tronco": 70.6686567939705, "angulo_head": 50.777353353919565}], "20": [{"angulo_tronco": 57.32244373958456, "angulo_head": 40.556957877334305}], "30": [{"angulo_tronco": 59.99955799703976, "angulo_head": 31.994543308661726}], "40": [{"angulo_tronco": 55.87525849548443, "angulo_head": 66.02116361186705}], "50": [{"angulo_tronco": 67.32522022123945, "angulo_head": 29.744871265254723}], "60": [{"angulo_tronco": 74.31609674814551, "angulo_head": 7.743719969140863}], "70": [{"angulo_tronco": 81.30446934496524, "angulo_head": 2.0180741652100362}], "80": [{"angulo_tronco": 85.70446195997555, "angulo_head": 16.984970650405298}], "90": [{"angulo_tronco": 87.11521820253296, "angulo_head": 15.853968673930709}], "100": [{"angulo_tronco": 98.54295182295938, "angulo_head": 146.06791478787108}], "110": [{"angulo_tronco": 98.41480598051402, "angulo_head": 159.16234543014897}], "120": [{"angulo_tronco": 111.89803118564787, "angulo_head": 146.91913320428577}], "130": [{"angulo_tronco": 110.68059420392312, "angulo_head": 138.97307886194483}], "140": [{"angulo_tronco": 119.57901005516176, "angulo_head": 116.85444230588337}], "150": [{"angulo_tronco": 120.85544246301305, "angulo_head": 131.52958003162263}], "160": [{"angulo_tronco": 125.30785381678137, "angulo_head": 120.32940028466506}], "170": [{"angulo_tronco": 133.1132921506226, "angulo_head": 114.70229417365897}], "180": [{"angulo_tronco": 100.79816043475101, "angulo_head": 117.30652795934866}]}, "300": {"0": [{"angulo_tronco": 97.46265155395506, "angulo_head": 48.610969566223474}], "10": [{"angulo_tronco": 65.03845397011203, "angulo_head": 46.512414677074446}], "20": [{"angulo_tronco": 72.83296233546523, "angulo_head": 46.36842707530752}], "30": [{"angulo_tronco": 65.29468901037335, "angulo_head": 56.10624958879069}], "40": [{"angulo_tronco": 64.04630207718766, "angulo_head": 69.39945172092618}], "50": [{"angulo_tronco": 62.15023110202606, "angulo_head": 56.26003823341026}], "60": [{"angulo_tronco": 67.56314716270657, "angulo_head": 37.97112118929126}], "70": [{"angulo_tronco": 73.29842111804541, "angulo_head": 27.25154456750422}], "80": [{"angulo_tronco": 82.99530542903274, "angulo_head": 158.27944091912593}], "90": [{"angulo_tronco": 88.36139588270916, "angulo_head": 70.33014812860331}], "100": [{"angulo_tronco": 97.14888752649871, "angulo_head": 10.588238135863424}], "110": [{"angulo_tronco": 94.56494917092996, "angulo_head": 25.949231015271668}], "120": [{"angulo_tronco": 101.41386616125573, "angulo_head": 159.9875680871349}], "130": [{"angulo_tronco": 104.18124401811988, "angulo_head": 27.1104332515158}], "140": [{"angulo_tronco": 106.81452824679062, "angulo_head": 42.25601330772481}], "150": [{"angulo_tronco": 116.0725496175773, "angulo_head": 126.51391933722199}], "160": [{"angulo_tronco": 127.11116128293285, "angulo_head": 160.60355746569968}], "170": [{"angulo_tronco": 116.61449244305322, "angulo_head": 129.19539897921018}], "180": [{"angulo_tronco": 105.68395307542445, "angulo_head": 124.3350778167986}]}, "400": {"0": [{"angulo_tronco": 82.72145893378934, "angulo_head": 169.84588849501472}], "10": [{"angulo_tronco": 68.24228969401614, "angulo_head": 168.64893188639985}], "20": [{"angulo_tronco": 65.01586732207842, "angulo_head": 171.13313869099602}], "30": [{"angulo_tronco": 66.28792929724248, "angulo_head": 171.2040623515304}], "40": [{"angulo_tronco": 66.86073853647068, "angulo_head": 30.002907184292027}], "50": [{"angulo_tronco": 72.81423297476216, "angulo_head": 5.386096582468674}], "60": [{"angulo_tronco": 83.41772572026781, "angulo_head": 52.15545182799451}], "70": [{"angulo_tronco": 82.48973318147223, "angulo_head": 14.77604918598616}], "80": [{"angulo_tronco": 75.14525813558487, "angulo_head": 27.407828838941036}], "90": [{"angulo_tronco": 93.16736187519238, "angulo_head": 47.878246751756556}], "100": [{"angulo_tronco": 98.61541107117722, "angulo_head": 27.8091643213952}], "110": [{"angulo_tronco": 99.18292894043462, "angulo_head": 66.57523002195101}], "120": [{"angulo_tronco": 103.90883141793351, "angulo_head": 170.12428099830902}], "130": [{"angulo_tronco": 108.84315539277688, "angulo_head": 151.22727125009823}], "140": [{"angulo_tronco": 110.02681340173388, "angulo_head": 110.68352645550745}], "150": [{"angulo_tronco": 112.1377601151746, "angulo_head": 123.86253906713847}], "160": [{"angulo_tronco": 115.24600039108212, "angulo_head": 171.38428408905241}], "170": [{"angulo_tronco": 109.67701560396604, "angulo_head": 170.03221573780507}], "180": [{"angulo_tronco": 81.6480247124372, "angulo_head": 161.59568777069074}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.85831654937192, "angulo_head": 51.04273199808438}], "10": [{"angulo_tronco": 72.02398840488061, "angulo_head": 49.49788978341994}], "20": [{"angulo_tronco": 55.795519712263854, "angulo_head": 43.09328213927047}], "30": [{"angulo_tronco": 60.01008903884673, "angulo_head": 35.518808345670934}], "40": [{"angulo_tronco": 63.39107739967953, "angulo_head": 14.040679489775894}], "50": [{"angulo_tronco": 69.73957685059183, "angulo_head": 24.05717289429509}], "60": [{"angulo_tronco": 77.81943562218596, "angulo_head": 27.365284726178448}], "70": [{"angulo_tronco": 78.98742602903381, "angulo_head": 32.7494724931387}], "80": [{"angulo_tronco": 82.49731515577459, "angulo_head": 12.326701486387819}], "90": [{"angulo_tronco": 87.83813660081718, "angulo_head": 84.21434647059459}], "100": [{"angulo_tronco": 101.1954912866911, "angulo_head": 167.11686435010392}], "110": [{"angulo_tronco": 102.55804776545317, "angulo_head": 162.85226711581473}], "120": [{"angulo_tronco": 109.88066881741393, "angulo_head": 131.69079276023166}], "130": [{"angulo_tronco": 112.29179469758766, "angulo_head": 127.2883682859407}], "140": [{"angulo_tronco": 119.60272450261407, "angulo_head": 143.7487294544372}], "150": [{"angulo_tronco": 128.96190292429733, "angulo_head": 116.79679714048075}], "160": [{"angulo_tronco": 115.98142328430397, "angulo_head": 130.79948312331777}], "170": [{"angulo_tronco": 125.82719539688782, "angulo_head": 116.32327026987998}], "180": [{"angulo_tronco": 95.01134320841133, "angulo_head": 124.73737383265951}]}, "300": {"0": [{"angulo_tronco": 84.22820045799877, "angulo_head": 52.53577208194262}], "10": [{"angulo_tronco": 66.70558758546487, "angulo_head": 46.34675138760563}], "20": [{"angulo_tronco": 61.771501001834935, "angulo_head": 39.37257720539755}], "30": [{"angulo_tronco": 67.23520661218413, "angulo_head": 26.93330221661902}], "40": [{"angulo_tronco": 72.57104518339315, "angulo_head": 25.382651165706537}], "50": [{"angulo_tronco": 71.33715267925383, "angulo_head": 22.054098967077465}], "60": [{"angulo_tronco": 69.90401040911544, "angulo_head": 9.586653541951495}], "70": [{"angulo_tronco": 82.17777497390024, "angulo_head": 19.358698417194176}], "80": [{"angulo_tronco": 82.59761932216446, "angulo_head": 0.369568239131761}], "90": [{"angulo_tronco": 87.46976449840562, "angulo_head": 90.80421954629595}], "100": [{"angulo_tronco": 95.07175923600641, "angulo_head": 162.4357344766264}], "110": [{"angulo_tronco": 99.65335200671342, "angulo_head": 150.29922871457148}], "120": [{"angulo_tronco": 107.66054095037049, "angulo_head": 166.02554403037374}], "130": [{"angulo_tronco": 110.07902420542612, "angulo_head": 171.7656997511533}], "140": [{"angulo_tronco": 101.25520186515962, "angulo_head": 139.11242797026145}], "150": [{"angulo_tronco": 114.75393861400487, "angulo_head": 139.30891855716}], "160": [{"angulo_tronco": 122.77178514235234, "angulo_head": 123.80602572024742}], "170": [{"angulo_tronco": 120.11070731082954, "angulo_head": 133.4701083975872}], "180": [{"angulo_tronco": 174.48991026524922, "angulo_head": 131.1879713082326}]}, "400": {"0": [{"angulo_tronco": 89.87331285670547, "angulo_head": 169.14212546381668}], "10": [], "20": [{"angulo_tronco": 57.25578329085438, "angulo_head": 42.01689586217261}], "30": [{"angulo_tronco": 65.61259296105453, "angulo_head": 72.45376439382342}], "40": [{"angulo_tronco": 73.90647335244228, "angulo_head": 8.0180512520561}], "50": [{"angulo_tronco": 76.57559653715833, "angulo_head": 7.478598912277916}], "60": [{"angulo_tronco": 75.9234970365159, "angulo_head": 5.682966430314306}], "70": [{"angulo_tronco": 77.64131770351496, "angulo_head": 21.65109299217773}], "80": [{"angulo_tronco": 82.49772724013978, "angulo_head": 3.894729900894199}], "90": [{"angulo_tronco": 89.5645934719574, "angulo_head": 58.5056153930638}], "100": [{"angulo_tronco": 93.52347753499055, "angulo_head": 154.50197879364725}], "110": [{"angulo_tronco": 106.33595752893793, "angulo_head": 171.64548093459567}], "120": [{"angulo_tronco": 104.6354434627057, "angulo_head": 147.67285520480976}], "130": [{"angulo_tronco": 110.758099086625, "angulo_head": 155.8139725892861}], "140": [{"angulo_tronco": 109.7261872110965, "angulo_head": 159.2071771565153}], "150": [{"angulo_tronco": 111.58027095926953, "angulo_head": 143.8540288688761}], "160": [{"angulo_tronco": 105.24726352130986, "angulo_head": 171.60050080855945}], "170": [{"angulo_tronco": 114.4053601134441, "angulo_head": 171.00206327744556}], "180": []}}, "centroide": {"200": [{"respuesta": 216.6408203478348}], "250": [{"respuesta": 259.134277343814}], "300": [{"respuesta": 306.78879271172036}], "350": [{"respuesta": 342.6830639623092}], "400": [{"respuesta": 377.5580429880333}], "450": [{"respuesta": 415.0433246821317}], "500": [{"respuesta": 441.8116840622698}], "550": [{"respuesta": 477.6547892647946}], "600": [{"respuesta": 499.89016459183307}]}, "centroide_grupal": {"200": [{"respuesta": 224.25312163962107}], "250": [{"respuesta": 268.103482099335}], "300": [{"respuesta": 303.9891233896759}, {"respuesta": 303.96108493918587}], "350": [{"respuesta": 348.37583037610665}, {"respuesta": 348.8433312299388}], "400": [{"respuesta": 372.6033441385635}], "450": [{"respuesta": 412.3549128272086}, {"respuesta": 412.93808585008816}], "500": [{"respuesta": 437.20073301109437}], "550": [{"respuesta": 467.1061466180706}, {"respuesta": 445.2917849006372}], "600": [{"respuesta": 443.6149336317194}]}, "height_167": {"200": [{"respuesta": 179.42621640029165}], "250": [{"respuesta": 173.59270822284034}], "300": [{"respuesta": 166.98056018165778}], "350": [{"respuesta": 158.07612050447312}], "400": [{"respuesta": 152.08043091493977}], "450": [{"respuesta": 147.31255255687316}], "500": [{"respuesta": 145.1484051118787}], "550": [{"respuesta": 137.88715367116544}], "600": [{"respuesta": 133.67530977345118}]}}

# %%
method = "WLS-SGBM"
method = "SELECTIVE-IGEV"

# %%
method = "SELECTIVE-IGEV"
json = {"formas": {"3": {"300": {"C": [{"result": "l", "confidence": "94.66618299484253"}, {"result": "c", "confidence": "97.70745635032654"}, {"result": "c", "confidence": "92.57453083992004"}, {"result": "c", "confidence": "98.7033486366272"}, {"result": "c", "confidence": "99.95419979095459"}, {"result": "c", "confidence": "99.55000281333923"}, {"result": "l", "confidence": "89.43145871162415"}, {"result": "c", "confidence": "70.10448575019836"}], "L": [{"result": "l", "confidence": "99.42315816879272"}, {"result": "l", "confidence": "97.83556461334229"}, {"result": "l", "confidence": "99.25950169563293"}, {"result": "l", "confidence": "99.22016859054565"}, {"result": "l", "confidence": "92.49844551086426"}, {"result": "l", "confidence": "99.59307312965393"}, {"result": "l", "confidence": "97.59870767593384"}], "I": [{"result": "c", "confidence": "75.71187615394592"}, {"result": "i", "confidence": "99.63322281837463"}, {"result": "i", "confidence": "99.30071830749512"}, {"result": "i", "confidence": "99.86170530319214"}, {"result": "i", "confidence": "77.4773895740509"}, {"result": "i", "confidence": "53.69884371757507"}, {"result": "i", "confidence": "98.96577000617981"}]}, "400": {"C": [{"result": "c", "confidence": "99.25323128700256"}, {"result": "c", "confidence": "99.59290623664856"}, {"result": "l", "confidence": "96.79073095321655"}, {"result": "l", "confidence": "97.28830456733704"}], "L": [{"result": "l", "confidence": "99.23157691955566"}, {"result": "l", "confidence": "99.23850297927856"}, {"result": "l", "confidence": "98.85578155517578"}, {"result": "l", "confidence": "97.6033866405487"}, {"result": "l", "confidence": "99.13877844810486"}, {"result": "l", "confidence": "97.0491111278534"}, {"result": "l", "confidence": "99.13724660873413"}], "I": [{"result": "i", "confidence": "83.18315148353577"}, {"result": "i", "confidence": "94.77227926254272"}, {"result": "i", "confidence": "99.85589385032654"}, {"result": "i", "confidence": "99.94762539863586"}, {"result": "i", "confidence": "88.00650238990784"}, {"result": "i", "confidence": "99.9307632446289"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99717473983765"}, {"result": "c", "confidence": "99.98743534088135"}, {"result": "c", "confidence": "99.9535322189331"}, {"result": "c", "confidence": "99.99730587005615"}, {"result": "c", "confidence": "99.99983310699463"}], "L": [{"result": "l", "confidence": "94.98176574707031"}, {"result": "c", "confidence": "94.83665823936462"}, {"result": "c", "confidence": "97.92482852935791"}, {"result": "l", "confidence": "98.82170557975769"}, {"result": "c", "confidence": "97.99842238426208"}, {"result": "c", "confidence": "99.27946925163269"}, {"result": "c", "confidence": "66.54711365699768"}], "I": [{"result": "i", "confidence": "99.44199919700623"}, {"result": "i", "confidence": "99.74244832992554"}, {"result": "i", "confidence": "99.44168329238892"}, {"result": "i", "confidence": "99.92966651916504"}, {"result": "i", "confidence": "99.60760474205017"}]}, "400": {"C": [{"result": "c", "confidence": "54.35415506362915"}, {"result": "c", "confidence": "91.57931804656982"}, {"result": "c", "confidence": "99.9851942062378"}, {"result": "c", "confidence": "99.97286200523376"}, {"result": "c", "confidence": "99.98914003372192"}, {"result": "c", "confidence": "99.97867941856384"}], "L": [{"result": "l", "confidence": "97.13733196258545"}, {"result": "c", "confidence": "91.54804944992065"}, {"result": "l", "confidence": "96.16655707359314"}, {"result": "c", "confidence": "95.46051621437073"}, {"result": "l", "confidence": "99.33972358703613"}, {"result": "c", "confidence": "91.21657013893127"}, {"result": "l", "confidence": "97.19358086585999"}], "I": [{"result": "i", "confidence": "99.82301592826843"}, {"result": "i", "confidence": "97.84833192825317"}, {"result": "i", "confidence": "98.88877272605896"}, {"result": "i", "confidence": "99.77735877037048"}, {"result": "i", "confidence": "99.6075689792633"}, {"result": "i", "confidence": "99.72454309463501"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 61.3765708362278, "angulo_head": 132.2628413204136}], "10": [{"angulo_tronco": 70.69608789634921, "angulo_head": 133.254588919649}], "20": [{"angulo_tronco": 57.31582665392186, "angulo_head": 143.33128320157326}], "30": [{"angulo_tronco": 59.996862235484, "angulo_head": 27.871411359777742}], "40": [{"angulo_tronco": 55.86689327688811, "angulo_head": 79.82084298917549}], "50": [{"angulo_tronco": 67.3288573354839, "angulo_head": 140.80207057706957}], "60": [{"angulo_tronco": 74.31869130071948, "angulo_head": 32.1235376980575}], "70": [{"angulo_tronco": 81.29791262276021, "angulo_head": 26.906285644712927}], "80": [{"angulo_tronco": 85.69691478299913, "angulo_head": 15.889749183946481}], "90": [{"angulo_tronco": 87.1160763763766, "angulo_head": 122.20241841772916}], "100": [{"angulo_tronco": 98.54044643710978, "angulo_head": 149.06620211629462}], "110": [{"angulo_tronco": 98.42381039339814, "angulo_head": 49.969870637010935}], "120": [{"angulo_tronco": 111.89774737372421, "angulo_head": 127.96512666930218}], "130": [{"angulo_tronco": 110.67088494293111, "angulo_head": 37.54204200542506}], "140": [{"angulo_tronco": 119.58390570582753, "angulo_head": 76.87697533676662}], "150": [{"angulo_tronco": 120.88950763807586, "angulo_head": 39.93766648269266}], "160": [{"angulo_tronco": 125.3657702118183, "angulo_head": 51.381836070889015}], "170": [{"angulo_tronco": 133.12050930118576, "angulo_head": 58.423724008111186}], "180": [{"angulo_tronco": 100.63926045916283, "angulo_head": 58.90707913952735}]}, "300": {"0": [{"angulo_tronco": 97.53819130092667, "angulo_head": 134.2656316628938}], "10": [{"angulo_tronco": 65.00497290690434, "angulo_head": 136.50087263550137}], "20": [{"angulo_tronco": 72.87798591691822, "angulo_head": 134.03608475064857}], "30": [{"angulo_tronco": 65.25865585449837, "angulo_head": 123.74302466998515}], "40": [{"angulo_tronco": 64.04040501944063, "angulo_head": 110.03383003149054}], "50": [{"angulo_tronco": 62.14634541188954, "angulo_head": 127.13995772065701}], "60": [{"angulo_tronco": 67.53329489378382, "angulo_head": 142.54301100149868}], "70": [{"angulo_tronco": 73.29802861508777, "angulo_head": 155.70350696898112}], "80": [{"angulo_tronco": 82.97565578748667, "angulo_head": 20.501293831827265}], "90": [{"angulo_tronco": 88.35736245157823, "angulo_head": 74.67047971611825}], "100": [{"angulo_tronco": 97.10772150505444, "angulo_head": 167.8629580359629}], "110": [{"angulo_tronco": 94.53511155164071, "angulo_head": 26.00432676550051}], "120": [{"angulo_tronco": 101.44106421986443, "angulo_head": 18.103355250360266}], "130": [{"angulo_tronco": 104.20900517429892, "angulo_head": 69.82875586960984}], "140": [{"angulo_tronco": 106.82153967512723, "angulo_head": 45.941160254579806}], "150": [{"angulo_tronco": 116.14557309338676, "angulo_head": 49.61078414954466}], "160": [{"angulo_tronco": 127.08986232677576, "angulo_head": 162.07119257083647}], "170": [{"angulo_tronco": 116.56787414954339, "angulo_head": 48.59919263367489}], "180": [{"angulo_tronco": 106.24711893711121, "angulo_head": 51.96223742429765}]}, "400": {"0": [{"angulo_tronco": 82.23840660348559, "angulo_head": 55.208994146960855}], "10": [{"angulo_tronco": 67.87193880085427, "angulo_head": 122.16092254150635}], "20": [{"angulo_tronco": 65.07442331297408, "angulo_head": 118.61728779581247}], "30": [{"angulo_tronco": 66.14824971399506, "angulo_head": 118.69002128635366}], "40": [{"angulo_tronco": 66.86331488165048, "angulo_head": 142.14491107571115}], "50": [{"angulo_tronco": 72.78762769474216, "angulo_head": 20.86120529095585}], "60": [{"angulo_tronco": 83.0840104133853, "angulo_head": 128.1001079864184}], "70": [{"angulo_tronco": 82.50065454402117, "angulo_head": 145.42153932170686}], "80": [{"angulo_tronco": 75.14506150405545, "angulo_head": 26.199892987236204}], "90": [{"angulo_tronco": 93.18359182061839, "angulo_head": 47.28403242793766}], "100": [{"angulo_tronco": 98.59026730868759, "angulo_head": 142.33378767286487}], "110": [{"angulo_tronco": 99.33881797014554, "angulo_head": 85.41955301045965}], "120": [{"angulo_tronco": 104.01936606877592, "angulo_head": 172.02880806704408}], "130": [{"angulo_tronco": 108.8761294815448, "angulo_head": 26.6701316936965}], "140": [{"angulo_tronco": 110.0694528080407, "angulo_head": 62.445437594899886}], "150": [{"angulo_tronco": 112.14553657595394, "angulo_head": 50.741135307898666}], "160": [{"angulo_tronco": 115.02538165391958, "angulo_head": 58.64722147232549}], "170": [{"angulo_tronco": 109.69228680915717, "angulo_head": 65.52221778395189}], "180": [{"angulo_tronco": 81.80923252291355, "angulo_head": 108.34312803545805}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 68.83266737018874, "angulo_head": 132.22896361755903}], "10": [{"angulo_tronco": 72.00712509176653, "angulo_head": 134.36579483900582}], "20": [{"angulo_tronco": 55.79891122670953, "angulo_head": 142.17799399962848}], "30": [{"angulo_tronco": 59.996716547821144, "angulo_head": 90.0}], "40": [{"angulo_tronco": 63.39323005725839, "angulo_head": 13.051855849630355}], "50": [{"angulo_tronco": 69.76340574760573, "angulo_head": 9.006617613924623}], "60": [{"angulo_tronco": 77.80058358543413, "angulo_head": 154.51900577036093}], "70": [{"angulo_tronco": 78.98319662997218, "angulo_head": 31.641053817452132}], "80": [{"angulo_tronco": 82.50074043363203, "angulo_head": 58.37295068997231}], "90": [{"angulo_tronco": 87.84227875113847, "angulo_head": 90.76521465809353}], "100": [{"angulo_tronco": 101.16974037162885, "angulo_head": 125.69087229450535}], "110": [{"angulo_tronco": 102.55101389593392, "angulo_head": 137.2421275343678}], "120": [{"angulo_tronco": 109.88161777445902, "angulo_head": 42.42893735605729}], "130": [{"angulo_tronco": 112.3091006728344, "angulo_head": 47.908387970733045}], "140": [{"angulo_tronco": 119.61482823825295, "angulo_head": 174.20496148780524}], "150": [{"angulo_tronco": 128.97703951810385, "angulo_head": 52.55775351359493}], "160": [{"angulo_tronco": 116.00137954689492, "angulo_head": 42.808869384452855}], "170": [{"angulo_tronco": 125.8442321091772, "angulo_head": 58.12654440783849}], "180": [{"angulo_tronco": 95.00872537432994, "angulo_head": 51.665500070522974}]}, "300": {"0": [{"angulo_tronco": 84.25237633698029, "angulo_head": 130.19399024295925}], "10": [{"angulo_tronco": 66.92828772784127, "angulo_head": 136.99502882267575}], "20": [{"angulo_tronco": 61.76011359734549, "angulo_head": 144.61705564915204}], "30": [{"angulo_tronco": 67.23348845044653, "angulo_head": 90.0}], "40": [{"angulo_tronco": 72.55378707487759, "angulo_head": 138.62772042864756}], "50": [{"angulo_tronco": 71.31825278823379, "angulo_head": 7.812907722768579}], "60": [{"angulo_tronco": 69.88546172389754, "angulo_head": 9.521611175476556}], "70": [{"angulo_tronco": 82.21666855604758, "angulo_head": 19.03601611949012}], "80": [{"angulo_tronco": 82.58324000686447, "angulo_head": 73.8829505939596}], "90": [{"angulo_tronco": 87.4778874049661, "angulo_head": 91.79303337848658}], "100": [{"angulo_tronco": 95.03997284949511, "angulo_head": 128.66405936227824}], "110": [{"angulo_tronco": 99.67119763524084, "angulo_head": 49.75254936074158}], "120": [{"angulo_tronco": 107.71554725156139, "angulo_head": 169.99561914645312}], "130": [{"angulo_tronco": 110.07132609063338, "angulo_head": 141.35255671287698}], "140": [{"angulo_tronco": 101.20180567734437, "angulo_head": 37.002064376098815}], "150": [{"angulo_tronco": 114.73511291558574, "angulo_head": 31.57424389686198}], "160": [{"angulo_tronco": 122.73131271492699, "angulo_head": 54.62241130945158}], "170": [{"angulo_tronco": 120.08579783397366, "angulo_head": 40.93412021102496}], "180": [{"angulo_tronco": 174.53611285616913, "angulo_head": 134.5866029578751}]}, "400": {"0": [{"angulo_tronco": 89.85543082146901, "angulo_head": 116.69374894336921}], "10": [], "20": [{"angulo_tronco": 57.31078320827215, "angulo_head": 139.5273362625726}], "30": [{"angulo_tronco": 65.5903371094424, "angulo_head": 21.223268507793026}], "40": [{"angulo_tronco": 73.89638422083236, "angulo_head": 7.799985873189558}], "50": [{"angulo_tronco": 76.57524014092827, "angulo_head": 7.349359371219086}], "60": [{"angulo_tronco": 75.92765502750763, "angulo_head": 5.68649424768358}], "70": [{"angulo_tronco": 77.57321948519295, "angulo_head": 21.13507064039359}], "80": [{"angulo_tronco": 82.47735334270591, "angulo_head": 3.80956326865637}], "90": [{"angulo_tronco": 89.54727189945993, "angulo_head": 81.81083395482587}], "100": [{"angulo_tronco": 93.52435334999674, "angulo_head": 157.43140269036084}], "110": [{"angulo_tronco": 106.3474171208382, "angulo_head": 172.66088559557727}], "120": [{"angulo_tronco": 104.5999720632163, "angulo_head": 150.702977923271}], "130": [{"angulo_tronco": 110.69091133400936, "angulo_head": 156.69907663857376}], "140": [{"angulo_tronco": 109.77621348880605, "angulo_head": 163.99476507836854}], "150": [{"angulo_tronco": 111.64526662797158, "angulo_head": 34.75377061150052}], "160": [{"angulo_tronco": 105.14839139868356, "angulo_head": 65.65275029270607}], "170": [{"angulo_tronco": 114.16429912683202, "angulo_head": 65.04368098085558}], "180": []}}, "centroide": {"200": [{"respuesta": 216.64011662795923}], "250": [{"respuesta": 259.1384417119867}], "300": [{"respuesta": 306.7889918030704}], "350": [{"respuesta": 342.6834194765502}], "400": [{"respuesta": 377.55468153590755}], "450": [{"respuesta": 415.03371816938505}], "500": [{"respuesta": 441.8123614900671}], "550": [{"respuesta": 477.67223918300317}], "600": [{"respuesta": 499.867440299209}]}, "centroide_grupal": {"200": [{"respuesta": 224.25347687750457}], "250": [{"respuesta": 268.1023963592718}], "300": [{"respuesta": 303.99472438272846}, {"respuesta": 303.95907587239395}], "350": [{"respuesta": 348.3722483065932}, {"respuesta": 348.8436084979172}], "400": [{"respuesta": 372.60379428274166}], "450": [{"respuesta": 412.3540254835244}, {"respuesta": 412.9423755760869}], "500": [{"respuesta": 437.2004584439511}], "550": [{"respuesta": 467.10261537382837}, {"respuesta": 445.28131633715213}], "600": [{"respuesta": 443.61605989313546}]}, "height_167": {"200": [{"respuesta": 179.42084785811903}], "250": [{"respuesta": 173.5962863781486}], "300": [{"respuesta": 166.98277172641696}], "350": [{"respuesta": 158.15724761928124}], "400": [{"respuesta": 152.08336251614722}], "450": [{"respuesta": 147.2926314003453}], "500": [{"respuesta": 145.1297005739848}], "550": [{"respuesta": 137.8899733082177}], "600": [{"respuesta": 133.60884248779053}]}}

# method = "WLS-SGBM"
# json = {"formas": {"3": {"300": {"C": [{"result": "c", "confidence": "91.56423807144165"}, {"result": "c", "confidence": "99.28943514823914"}, {"result": "c", "confidence": "99.01236891746521"}, {"result": "c", "confidence": "99.58510398864746"}, {"result": "c", "confidence": "99.93078708648682"}, {"result": "c", "confidence": "99.82705116271973"}, {"result": "c", "confidence": "93.37248206138611"}, {"result": "c", "confidence": "99.68343377113342"}], "L": [{"result": "l", "confidence": "96.59467339515686"}, {"result": "l", "confidence": "98.25483560562134"}, {"result": "l", "confidence": "95.71630954742432"}, {"result": "l", "confidence": "96.92432880401611"}, {"result": "l", "confidence": "97.13249206542969"}, {"result": "l", "confidence": "99.50174689292908"}, {"result": "l", "confidence": "96.60797715187073"}], "I": [{"result": "c", "confidence": "99.99613761901855"}, {"result": "i", "confidence": "99.8025894165039"}, {"result": "i", "confidence": "99.44221377372742"}, {"result": "i", "confidence": "99.52530860900879"}, {"result": "i", "confidence": "63.55597376823425"}, {"result": "l", "confidence": "78.26581001281738"}, {"result": "i", "confidence": "80.59823513031006"}]}, "400": {"C": [{"result": "c", "confidence": "99.812251329422"}, {"result": "c", "confidence": "99.75228905677795"}, {"result": "c", "confidence": "98.78661632537842"}], "L": [{"result": "l", "confidence": "95.62825560569763"}, {"result": "l", "confidence": "83.59361290931702"}, {"result": "l", "confidence": "99.71792697906494"}, {"result": "l", "confidence": "83.45333337783813"}, {"result": "l", "confidence": "90.60088992118835"}, {"result": "l", "confidence": "94.61413025856018"}, {"result": "l", "confidence": "99.89520311355591"}], "I": [{"result": "l", "confidence": "99.74638223648071"}, {"result": "c", "confidence": "99.88873600959778"}, {"result": "i", "confidence": "95.7571268081665"}, {"result": "i", "confidence": "99.96315240859985"}, {"result": "l", "confidence": "98.2334852218628"}, {"result": "i", "confidence": "99.95866417884827"}]}}, "4": {"300": {"C": [{"result": "c", "confidence": "99.99539852142334"}, {"result": "c", "confidence": "99.996018409729"}, {"result": "c", "confidence": "98.23596477508545"}, {"result": "c", "confidence": "99.9968409538269"}, {"result": "c", "confidence": "99.99997615814209"}], "L": [{"result": "l", "confidence": "73.36476445198059"}, {"result": "c", "confidence": "99.73586201667786"}, {"result": "c", "confidence": "99.64027404785156"}, {"result": "l", "confidence": "73.69738817214966"}, {"result": "c", "confidence": "99.97013211250305"}, {"result": "c", "confidence": "99.97431635856628"}, {"result": "c", "confidence": "99.9160647392273"}], "I": [{"result": "l", "confidence": "98.09908866882324"}, {"result": "i", "confidence": "99.34121966362"}, {"result": "i", "confidence": "98.82452487945557"}, {"result": "i", "confidence": "99.79447722434998"}, {"result": "c", "confidence": "98.15349578857422"}, {"result": "i", "confidence": "99.48678016662598"}]}, "400": {"C": [{"result": "c", "confidence": "98.85854125022888"}, {"result": "c", "confidence": "85.63886880874634"}, {"result": "c", "confidence": "99.99947547912598"}, {"result": "c", "confidence": "99.99477863311768"}, {"result": "c", "confidence": "99.99736547470093"}, {"result": "c", "confidence": "99.99442100524902"}], "L": [{"result": "c", "confidence": "99.89315867424011"}, {"result": "l", "confidence": "74.76453185081482"}, {"result": "c", "confidence": "99.97103810310364"}, {"result": "l", "confidence": "98.40596914291382"}, {"result": "c", "confidence": "99.74333643913269"}, {"result": "l", "confidence": "94.17911171913147"}], "I": [{"result": "i", "confidence": "99.46362376213074"}, {"result": "i", "confidence": "97.72512912750244"}, {"result": "i", "confidence": "99.74191188812256"}, {"result": "i", "confidence": "99.4877815246582"}, {"result": "i", "confidence": "99.79396462440491"}, {"result": "i", "confidence": "99.5995283126831"}]}}}, "orientacion": {"200": {"0": [{"angulo_tronco": 76.70334081346284, "angulo_head": 125.4554235576846}], "10": [{"angulo_tronco": 76.99360879157834, "angulo_head": 133.15611998433423}], "20": [{"angulo_tronco": 77.2949016529465, "angulo_head": 135.83344360933003}], "30": [{"angulo_tronco": 76.44581531699694, "angulo_head": 149.04105231636552}], "40": [{"angulo_tronco": 74.41588059948681, "angulo_head": 143.23913911021134}], "50": [{"angulo_tronco": 75.57532645951419, "angulo_head": 128.23777242500898}], "60": [{"angulo_tronco": 80.06511168797292, "angulo_head": 123.0525521018184}], "70": [{"angulo_tronco": 81.31081524571312, "angulo_head": 47.33115029109168}], "80": [{"angulo_tronco": 88.47758972997853, "angulo_head": 105.92330859793509}], "90": [{"angulo_tronco": 91.4021865775563, "angulo_head": 80.90956812543673}], "100": [{"angulo_tronco": 95.67846619638459, "angulo_head": 117.32223506466777}], "110": [{"angulo_tronco": 96.78077168819809, "angulo_head": 50.220594932047874}], "120": [{"angulo_tronco": 100.38980258114441, "angulo_head": 50.01642039618438}], "130": [{"angulo_tronco": 104.80194763569258, "angulo_head": 69.57807613016098}], "140": [{"angulo_tronco": 109.47862418463153, "angulo_head": 55.45064421367408}], "150": [{"angulo_tronco": 105.74797890238806, "angulo_head": 71.4673057988668}], "160": [{"angulo_tronco": 105.64500555727192, "angulo_head": 70.62913095824487}], "170": [{"angulo_tronco": 105.01410559516648, "angulo_head": 80.87466548628183}], "180": [{"angulo_tronco": 90.22881707821931, "angulo_head": 168.78504084808006}]}, "300": {"0": [{"angulo_tronco": 89.59039326656475, "angulo_head": 131.5089123355802}], "10": [{"angulo_tronco": 74.49788463045553, "angulo_head": 128.99796745395034}], "20": [{"angulo_tronco": 81.2852560124775, "angulo_head": 125.38635653224131}], "30": [{"angulo_tronco": 82.55112377002777, "angulo_head": 144.02606102489838}], "40": [{"angulo_tronco": 74.90978208231347, "angulo_head": 144.0428452566465}], "50": [{"angulo_tronco": 71.24814782937486, "angulo_head": 10.431932714095062}], "60": [{"angulo_tronco": 75.23717234208841, "angulo_head": 11.411165140619698}], "70": [{"angulo_tronco": 78.72067134966929, "angulo_head": 30.726983212511985}], "80": [{"angulo_tronco": 78.11559551251045, "angulo_head": 0.20328330586691526}], "90": [{"angulo_tronco": 85.78520585441157, "angulo_head": 83.5326290937974}], "100": [{"angulo_tronco": 88.515157075264, "angulo_head": 46.48413350415706}], "110": [{"angulo_tronco": 91.42809103947316, "angulo_head": 67.25980996488123}], "120": [{"angulo_tronco": 94.78023973357593, "angulo_head": 61.36113495874926}], "130": [{"angulo_tronco": 100.9941629214323, "angulo_head": 78.71361967522184}], "140": [{"angulo_tronco": 99.38410422541695, "angulo_head": 121.82876858229885}], "150": [{"angulo_tronco": 99.13135117143034, "angulo_head": 56.577738845800184}], "160": [{"angulo_tronco": 106.31579904284432, "angulo_head": 58.37610720532792}], "170": [{"angulo_tronco": 107.09760328026368, "angulo_head": 65.05900169938906}], "180": [{"angulo_tronco": 92.59760407600153, "angulo_head": 90.0}]}, "400": {"0": [{"angulo_tronco": 88.9611970720595, "angulo_head": 41.266270810684674}], "10": [{"angulo_tronco": 86.8797392437506, "angulo_head": 172.29960905567538}], "20": [{"angulo_tronco": 64.49610683409828, "angulo_head": 3.5065741877903127}], "30": [{"angulo_tronco": 65.48764650630508, "angulo_head": 148.27738706203817}], "40": [{"angulo_tronco": 65.53955773514275, "angulo_head": 26.112368675878297}], "50": [{"angulo_tronco": 74.64683275873924, "angulo_head": 60.96680380767558}], "60": [{"angulo_tronco": 72.63600558098629, "angulo_head": 65.4581722965499}], "70": [{"angulo_tronco": 79.13595231933685, "angulo_head": 70.71612709244795}], "80": [{"angulo_tronco": 77.62846930430189, "angulo_head": 36.484169761262734}], "90": [{"angulo_tronco": 81.90082047618509, "angulo_head": 74.75352712060678}], "100": [{"angulo_tronco": 87.38231882443301, "angulo_head": 76.8758727161372}], "110": [{"angulo_tronco": 89.61158529262502, "angulo_head": 89.2966047369418}], "120": [{"angulo_tronco": 92.9600375515751, "angulo_head": 23.727700276357044}], "130": [{"angulo_tronco": 92.79017775764935, "angulo_head": 19.446763486200517}], "140": [{"angulo_tronco": 88.69013538367946, "angulo_head": 76.66663561924615}], "150": [{"angulo_tronco": 100.40296577879708, "angulo_head": 43.9029096720082}], "160": [{"angulo_tronco": 104.45880420312005, "angulo_head": 40.80818594043374}], "170": [{"angulo_tronco": 79.6194131564416, "angulo_head": 58.825140481420206}], "180": [{"angulo_tronco": 91.17348198383658, "angulo_head": 169.81408421128216}]}}, "orientacion_cabeza": {"200": {"0": [{"angulo_tronco": 80.74467408715212, "angulo_head": 109.19904836479606}], "10": [{"angulo_tronco": 75.66747660800482, "angulo_head": 110.37289919559396}], "20": [{"angulo_tronco": 74.40250851834129, "angulo_head": 112.32419294009364}], "30": [{"angulo_tronco": 74.08385646817175, "angulo_head": 119.72413782975094}], "40": [{"angulo_tronco": 76.28196951670803, "angulo_head": 122.07523202078578}], "50": [{"angulo_tronco": 78.1722405942679, "angulo_head": 152.5151720121134}], "60": [{"angulo_tronco": 80.6642659880833, "angulo_head": 149.2038991290892}], "70": [{"angulo_tronco": 83.15133251364718, "angulo_head": 43.02757857757936}], "80": [{"angulo_tronco": 84.5087787789406, "angulo_head": 39.12978677284708}], "90": [{"angulo_tronco": 90.0, "angulo_head": 90.02543349015706}], "100": [{"angulo_tronco": 96.69101666258528, "angulo_head": 31.57064078938877}], "110": [{"angulo_tronco": 96.84597887414675, "angulo_head": 36.1449947022595}], "120": [{"angulo_tronco": 99.12348209187502, "angulo_head": 53.12471070012001}], "130": [{"angulo_tronco": 99.61986803335917, "angulo_head": 56.637085361972275}], "140": [{"angulo_tronco": 102.14898142643796, "angulo_head": 64.52569686412735}], "150": [{"angulo_tronco": 102.03804785080396, "angulo_head": 80.45844350200312}], "160": [{"angulo_tronco": 100.26290973425002, "angulo_head": 62.16498214588852}], "170": [{"angulo_tronco": 100.6261747520111, "angulo_head": 165.1016313994059}], "180": [{"angulo_tronco": 91.44770981155105, "angulo_head": 164.41522803842315}]}, "300": {"0": [{"angulo_tronco": 91.50794955768255, "angulo_head": 96.76273056138747}], "10": [{"angulo_tronco": 91.1576055190743, "angulo_head": 97.6481252835077}], "20": [{"angulo_tronco": 84.25730376823243, "angulo_head": 144.36772303047366}], "30": [{"angulo_tronco": 85.49365280629874, "angulo_head": 126.5604971228905}], "40": [{"angulo_tronco": 80.54470485901155, "angulo_head": 164.1217217526685}], "50": [{"angulo_tronco": 79.77549598192657, "angulo_head": 2.6781896596318706}], "60": [{"angulo_tronco": 78.53350791032213, "angulo_head": 27.157177266997486}], "70": [{"angulo_tronco": 84.25042063937669, "angulo_head": 68.38607787467645}], "80": [{"angulo_tronco": 85.8487006864408, "angulo_head": 76.31328330803859}], "90": [{"angulo_tronco": 87.47696998093488, "angulo_head": 89.76763124661434}], "100": [{"angulo_tronco": 91.47009598656446, "angulo_head": 80.72709727839887}], "110": [{"angulo_tronco": 93.013831713478, "angulo_head": 61.98731191678172}], "120": [{"angulo_tronco": 94.91045273462908, "angulo_head": 81.77752102816314}], "130": [{"angulo_tronco": 93.53381338045416, "angulo_head": 90.0}], "140": [{"angulo_tronco": 93.8305518850191, "angulo_head": 65.74059055767388}], "150": [{"angulo_tronco": 94.04006357867296, "angulo_head": 72.02848203158331}], "160": [{"angulo_tronco": 92.63878194871683, "angulo_head": 62.557618566011065}], "170": [{"angulo_tronco": 94.37012929738124, "angulo_head": 90.0}], "180": [{"angulo_tronco": 90.0, "angulo_head": 90.0}]}, "400": {"0": [{"angulo_tronco": 94.12141931057673, "angulo_head": 128.05402708540552}], "10": [], "20": [{"angulo_tronco": 81.02256850652581, "angulo_head": 131.59935604620725}], "30": [{"angulo_tronco": 83.42693531107538, "angulo_head": 153.5961667429762}], "40": [{"angulo_tronco": 80.48477560729069, "angulo_head": 64.71867222197167}], "50": [{"angulo_tronco": 84.37873818765885, "angulo_head": 43.05721472667403}], "60": [{"angulo_tronco": 84.91512513950613, "angulo_head": 59.319538501657}], "70": [{"angulo_tronco": 82.78256227200553, "angulo_head": 51.88433253476174}], "80": [{"angulo_tronco": 87.6739971789383, "angulo_head": 71.34148365915574}], "90": [{"angulo_tronco": 87.84422967480224, "angulo_head": 91.97913962144588}], "100": [{"angulo_tronco": 90.0986289954239, "angulo_head": 107.35743485329253}], "110": [{"angulo_tronco": 90.19621221159704, "angulo_head": 105.29715150969741}], "120": [{"angulo_tronco": 89.97954594865651, "angulo_head": 63.49638484974916}], "130": [{"angulo_tronco": 96.56029039115298, "angulo_head": 115.89688702471234}], "140": [{"angulo_tronco": 90.0, "angulo_head": 43.67767510019534}], "150": [{"angulo_tronco": 93.94866688392632, "angulo_head": 34.30574671560554}], "160": [{"angulo_tronco": 97.8087157885947, "angulo_head": 22.26576485974}], "170": [{"angulo_tronco": 90.93526859572974, "angulo_head": 52.104188925430854}], "180": []}}, "centroide": {"200": [{"respuesta": 203.80744422897286}], "250": [{"respuesta": 251.36115409175892}], "300": [{"respuesta": 314.568302106125}], "350": [{"respuesta": 354.10677685395865}], "400": [{"respuesta": 402.5424957084332}], "450": [{"respuesta": 462.0791919059897}], "500": [{"respuesta": 511.16721330556237}], "550": [{"respuesta": 565.5819094896491}], "600": [{"respuesta": 611.1792043159736}]}, "centroide_grupal": {"200": [{"respuesta": 213.50142930066067}], "250": [{"respuesta": 262.82244701196606}], "300": [{"respuesta": 313.11535905975103}, {"respuesta": 313.4923936515653}], "350": [{"respuesta": 370.38756164322166}, {"respuesta": 371.2207953503374}], "400": [{"respuesta": 414.9864883457011}], "450": [{"respuesta": 464.8819997974741}, {"respuesta": 466.84516987151426}], "500": [{"respuesta": 514.2668123703811}], "550": [{"respuesta": 565.0982647347003}, {"respuesta": 517.3764168952625}], "600": [{"respuesta": 516.7212505090391}]}, "height_167": {"200": [{"respuesta": 168.1104472552508}], "250": [{"respuesta": 166.94968448217088}], "300": [{"respuesta": 167.30319377673305}], "350": [{"respuesta": 164.22656555913898}], "400": [{"respuesta": 164.09847374744285}], "450": [{"respuesta": 164.31603716594455}], "500": [{"respuesta": 167.17628590562515}], "550": [{"respuesta": 165.11649666856655}], "600": [{"respuesta": 168.3410433039}]}}

# %% [markdown]
# # Formas

# %%
val_formas = json["formas"]

# %%
data = []
for key2, value2 in val_formas["3"]["300"].items():
    for i in value2:
        data.append([key2, i["result"], i["confidence"]])
df_formas_3_300 = pd.DataFrame(data, columns=["forma", "result", "confidence"])

data = []
for key2, value2 in val_formas["3"]["400"].items():
    for i in value2:
        data.append([key2, i["result"], i["confidence"]])
df_formas_3_400 = pd.DataFrame(data, columns=["forma", "result", "confidence"])

data = []
for key2, value2 in val_formas["4"]["300"].items():
    for i in value2:
        data.append([key2, i["result"], i["confidence"]])
df_formas_4_300 = pd.DataFrame(data, columns=["forma", "result", "confidence"])

data = []
for key2, value2 in val_formas["4"]["400"].items():
    for i in value2:
        data.append([key2, i["result"], i["confidence"]])
df_formas_4_400 = pd.DataFrame(data, columns=["forma", "result", "confidence"])

# %%
val_formas["4"]["400"]
# Out:
# {'C': [{'result': 'c', 'confidence': '54.35415506362915'},
#   {'result': 'c', 'confidence': '91.57931804656982'},
#   {'result': 'c', 'confidence': '99.9851942062378'},
#   {'result': 'c', 'confidence': '99.97286200523376'},
#   {'result': 'c', 'confidence': '99.98914003372192'},
#   {'result': 'c', 'confidence': '99.97867941856384'}],
#  'L': [{'result': 'l', 'confidence': '97.13733196258545'},
#   {'result': 'c', 'confidence': '91.54804944992065'},
#   {'result': 'l', 'confidence': '96.16655707359314'},
#   {'result': 'c', 'confidence': '95.46051621437073'},
#   {'result': 'l', 'confidence': '99.33972358703613'},
#   {'result': 'c', 'confidence': '91.21657013893127'},
#   {'result': 'l', 'confidence': '97.19358086585999'}],
#  'I': [{'result': 'i', 'confidence': '99.82301592826843'},
#   {'result': 'i', 'confidence': '97.84833192825317'},
#   {'result': 'i', 'confidence': '98.88877272605896'},
#   {'result': 'i', 'confidence': '99.77735877037048'},
# ...

# %% [markdown]
# #### 3 Personas a 3 m

# %%
df_formas_3_300_L = df_formas_3_300.copy()
df_formas_3_300_L["forma"] = df_formas_3_300_L["forma"].replace("C", "L")
df_formas_3_300_L["result"] = df_formas_3_300_L["result"].replace("c", "l")
df_formas_3_300_L
# Out:
#    forma result         confidence
# 0      L      l  94.66618299484253
# 1      L      l  97.70745635032654
# 2      L      l  92.57453083992004
# 3      L      l   98.7033486366272
# 4      L      l  99.95419979095459
# 5      L      l  99.55000281333923
# 6      L      l  89.43145871162415
# 7      L      l  70.10448575019836
# 8      L      l  99.42315816879272
# 9      L      l  97.83556461334229
# 10     L      l  99.25950169563293
# 11     L      l  99.22016859054565
# 12     L      l  92.49844551086426
# 13     L      l  99.59307312965393
# 14     L      l  97.59870767593384
# 15     I      l  75.71187615394592
# 16     I      i  99.63322281837463
# 17     I      i  99.30071830749512
# 18     I      i  99.86170530319214
# 19     I      i   77.4773895740509
# 20     I      i  53.69884371757507
# 21     I      i  98.96577000617981

# %%
# matriz de confunsión con df_formas_3_300
confusion_matrix = pd.crosstab(df_formas_3_300["forma"], df_formas_3_300["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  c  i  l
# forma
# C       6  0  2
# I       1  6  0
# L       0  0  7

# %%
confusion_matrix = pd.crosstab(df_formas_3_300["forma"], df_formas_3_300["result"], rownames=["forma"], colnames=["result"])
# Normalización por filas
normalized_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
normalized_matrix.round(2)
# Out:
# result     c     i     l
# forma
# C       0.75  0.00  0.25
# I       0.14  0.86  0.00
# L       0.00  0.00  1.00

# %%
# cambiar de C a L en df_formas_3_300_L
confusion_matrix = pd.crosstab(df_formas_3_300_L["forma"], df_formas_3_300_L["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  i   l
# forma
# I       6   1
# L       0  15

# %%
confusion_matrix = pd.crosstab(df_formas_3_300_L["forma"], df_formas_3_300_L["result"], rownames=["forma"], colnames=["result"])
# Normalización por filas
normalized_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
normalized_matrix.round(2)
# Out:
# result     i     l
# forma
# I       0.86  0.14
# L       0.00  1.00

# %% [markdown]
# #### 3 Personas a 4 m

# %%
df_formas_3_400_L = df_formas_3_400.copy()
df_formas_3_400_L["forma"] = df_formas_3_400_L["forma"].replace("C", "L")
df_formas_3_400_L["result"] = df_formas_3_400_L["result"].replace("c", "l")
df_formas_3_400_L
# Out:
#    forma result         confidence
# 0      L      l  99.25323128700256
# 1      L      l  99.59290623664856
# 2      L      l  96.79073095321655
# 3      L      l  97.28830456733704
# 4      L      l  99.23157691955566
# 5      L      l  99.23850297927856
# 6      L      l  98.85578155517578
# 7      L      l   97.6033866405487
# 8      L      l  99.13877844810486
# 9      L      l   97.0491111278534
# 10     L      l  99.13724660873413
# 11     I      i  83.18315148353577
# 12     I      i  94.77227926254272
# 13     I      i  99.85589385032654
# 14     I      i  99.94762539863586
# 15     I      i  88.00650238990784
# 16     I      i   99.9307632446289

# %%
confusion_matrix = pd.crosstab(df_formas_3_400["forma"], df_formas_3_400["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  c  i  l
# forma
# C       2  0  2
# I       0  6  0
# L       0  0  7

# %%
confusion_matrix = pd.crosstab(df_formas_3_400["forma"], df_formas_3_400["result"], rownames=["forma"], colnames=["result"])
# Normalización por filas
normalized_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
normalized_matrix.round(2)
# Out:
# result    c    i    l
# forma
# C       0.5  0.0  0.5
# I       0.0  1.0  0.0
# L       0.0  0.0  1.0

# %%
confusion_matrix = pd.crosstab(df_formas_3_400_L["forma"], df_formas_3_400_L["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  i   l
# forma
# I       6   0
# L       0  11

# %%
confusion_matrix = pd.crosstab(df_formas_3_400_L["forma"], df_formas_3_400_L["result"], rownames=["forma"], colnames=["result"])
# Normalización por filas
normalized_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
normalized_matrix.round(2)
# Out:
# result    i    l
# forma
# I       1.0  0.0
# L       0.0  1.0

# %% [markdown]
# #### 4 Personas a 3 m

# %%
df_formas_4_300_C = df_formas_4_300.copy()
df_formas_4_300_C["forma"] = df_formas_4_300_C["forma"].replace("L", "C")
df_formas_4_300_C["result"] = df_formas_4_300_C["result"].replace("l", "c")
df_formas_4_300_C
# Out:
#    forma result         confidence
# 0      C      c  99.99717473983765
# 1      C      c  99.98743534088135
# 2      C      c   99.9535322189331
# 3      C      c  99.99730587005615
# 4      C      c  99.99983310699463
# 5      C      c  94.98176574707031
# 6      C      c  94.83665823936462
# 7      C      c  97.92482852935791
# 8      C      c  98.82170557975769
# 9      C      c  97.99842238426208
# 10     C      c  99.27946925163269
# 11     C      c  66.54711365699768
# 12     I      i  99.44199919700623
# 13     I      i  99.74244832992554
# 14     I      i  99.44168329238892
# 15     I      i  99.92966651916504
# 16     I      i  99.60760474205017

# %%
confusion_matrix = pd.crosstab(df_formas_4_300["forma"], df_formas_4_300["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  c  i  l
# forma
# C       5  0  0
# I       0  5  0
# L       5  0  2

# %%
confusion_matrix = pd.crosstab(df_formas_4_300["forma"], df_formas_4_300["result"], rownames=["forma"], colnames=["result"])
# Normalización por filas
normalized_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
normalized_matrix.round(2)
# Out:
# result     c    i     l
# forma
# C       1.00  0.0  0.00
# I       0.00  1.0  0.00
# L       0.71  0.0  0.29

# %%
confusion_matrix = pd.crosstab(df_formas_4_300_C["forma"], df_formas_4_300_C["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result   c  i
# forma
# C       12  0
# I        0  5

# %%
confusion_matrix = pd.crosstab(df_formas_4_300_C["forma"], df_formas_4_300_C["result"], rownames=["forma"], colnames=["result"])
# Normalización por filas
normalized_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
normalized_matrix.round(2)
# Out:
# result    c    i
# forma
# C       1.0  0.0
# I       0.0  1.0

# %% [markdown]
# #### 4 Personas a 4 m

# %%
df_formas_4_400_C = df_formas_4_400.copy()
df_formas_4_400_C["forma"] = df_formas_4_400_C["forma"].replace("L", "C")
df_formas_4_400_C["result"] = df_formas_4_400_C["result"].replace("l", "c")
df_formas_4_400_C
# Out:
#    forma result         confidence
# 0      C      c  54.35415506362915
# 1      C      c  91.57931804656982
# 2      C      c   99.9851942062378
# 3      C      c  99.97286200523376
# 4      C      c  99.98914003372192
# 5      C      c  99.97867941856384
# 6      C      c  97.13733196258545
# 7      C      c  91.54804944992065
# 8      C      c  96.16655707359314
# 9      C      c  95.46051621437073
# 10     C      c  99.33972358703613
# 11     C      c  91.21657013893127
# 12     C      c  97.19358086585999
# 13     I      i  99.82301592826843
# 14     I      i  97.84833192825317
# 15     I      i  98.88877272605896
# 16     I      i  99.77735877037048
# 17     I      i   99.6075689792633
# 18     I      i  99.72454309463501

# %%
confusion_matrix = pd.crosstab(df_formas_4_400["forma"], df_formas_4_400["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result  c  i  l
# forma
# C       6  0  0
# I       0  6  0
# L       3  0  4

# %%
confusion_matrix = pd.crosstab(df_formas_4_400["forma"], df_formas_4_400["result"], rownames=["forma"], colnames=["result"])
# Normalización por filas
normalized_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
normalized_matrix.round(2)
# Out:
# result     c    i     l
# forma
# C       1.00  0.0  0.00
# I       0.00  1.0  0.00
# L       0.43  0.0  0.57

# %%
confusion_matrix = pd.crosstab(df_formas_4_400_C["forma"], df_formas_4_400_C["result"], rownames=["forma"], colnames=["result"])
confusion_matrix
# Out:
# result   c  i
# forma
# C       13  0
# I        0  6

# %%
confusion_matrix = pd.crosstab(df_formas_4_400_C["forma"], df_formas_4_400_C["result"], rownames=["forma"], colnames=["result"])
# Normalización por filas
normalized_matrix = confusion_matrix.div(confusion_matrix.sum(axis=1), axis=0)
normalized_matrix.round(2)
# Out:
# result    c    i
# forma
# C       1.0  0.0
# I       0.0  1.0

# %% [markdown]
# # Centroide

# %%
val_centroides = json["centroide"]

# %%
data = []

for key, value in val_centroides.items():
    data.append([key, value[0]["respuesta"]])

df_centroides = pd.DataFrame(data, columns=["centroide", "respuesta"])

# %%
df_centroides
# Out:
#   centroide   respuesta
# 0       200  216.640117
# 1       250  259.138442
# 2       300  306.788992
# 3       350  342.683419
# 4       400  377.554682
# 5       450  415.033718
# 6       500  441.812361
# 7       550  477.672239
# 8       600  499.867440

# %%
# margen de error de centroide con respuesta de df_centroides
df_centroides["error"] = abs(df_centroides["centroide"].astype(int) - df_centroides["respuesta"])
df_centroides["porcentaje_error"] = (df_centroides["error"] * 100) / df_centroides["centroide"].astype(int)
df_centroides["precisión"] = 100 - df_centroides["porcentaje_error"]
df_centroides
# Out:
#   centroide   respuesta       error  porcentaje_error  precisión
# 0       200  216.640117   16.640117          8.320058  91.679942
# 1       250  259.138442    9.138442          3.655377  96.344623
# 2       300  306.788992    6.788992          2.262997  97.737003
# 3       350  342.683419    7.316581          2.090452  97.909548
# 4       400  377.554682   22.445318          5.611330  94.388670
# 5       450  415.033718   34.966282          7.770285  92.229715
# 6       500  441.812361   58.187639         11.637528  88.362472
# 7       550  477.672239   72.327761         13.150502  86.849498
# 8       600  499.867440  100.132560         16.688760  83.311240

# %%
round(df_centroides["precisión"].mean(), 2)
# Out:
# 92.09

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_centroides.index, df_centroides["centroide"].astype(int), label='Real Depth', marker='o')
ax.plot(df_centroides.index, df_centroides["respuesta"], label='Estimated Depth', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Individual centroid depth', fontsize=18)
ax.set_xlabel('Sample Index', fontsize=16)
ax.set_ylabel('Depth (cm)', fontsize=16)

# Añadir una leyenda
ax.legend(fontsize=14)

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# # Centroide grupal

# %%
val_centroides_grupal = json["centroide_grupal"]

# %%
data = []

for key, value in val_centroides_grupal.items():
    data.append([key, value[0]["respuesta"]])

df_centroides_grupal = pd.DataFrame(data, columns=["centroide_grupal", "respuesta"])

# %%
# margen de error de centroide con respuesta de df_centroides
df_centroides_grupal["error"] = abs(df_centroides_grupal["centroide_grupal"].astype(int) - df_centroides_grupal["respuesta"])
df_centroides_grupal["porcentaje_error"] = (df_centroides_grupal["error"] * 100) / df_centroides_grupal["centroide_grupal"].astype(int)
df_centroides_grupal["precisión"] = 100 - df_centroides_grupal["porcentaje_error"]
df_centroides_grupal
# Out:
#   centroide_grupal   respuesta       error  porcentaje_error  precisión
# 0              200  224.253477   24.253477         12.126738  87.873262
# 1              250  268.102396   18.102396          7.240959  92.759041
# 2              300  303.994724    3.994724          1.331575  98.668425
# 3              350  348.372248    1.627752          0.465072  99.534928
# 4              400  372.603794   27.396206          6.849051  93.150949
# 5              450  412.354025   37.645975          8.365772  91.634228
# 6              500  437.200458   62.799542         12.559908  87.440092
# 7              550  467.102615   82.897385         15.072252  84.927748
# 8              600  443.616060  156.383940         26.063990  73.936010

# %%
round(df_centroides_grupal["precisión"].mean(), 2)
# Out:
# 89.99

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_centroides_grupal.index, df_centroides_grupal["centroide_grupal"].astype(int), label='Real Depth', marker='o')
ax.plot(df_centroides_grupal.index, df_centroides_grupal["respuesta"], label='Estimated Depth', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Group Centroid Depth', fontsize=18)
ax.set_xlabel('Sample Index', fontsize=16)
ax.set_ylabel('Depth (cm)', fontsize=16)

# Añadir una leyenda
ax.legend(fontsize=14)

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# # Orientacion

# %%
val_orientacion = json["orientacion"]

# %%
data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["200"].keys():
    if val_orientacion["200"][key]:
        angulo_tronco = val_orientacion["200"][key][0]["angulo_tronco"]
    else:
        angulo_tronco = 0

    data.append({
        "angulo": key,
        "angulo_tronco": angulo_tronco,
    })

df_orientaciones_200 = pd.DataFrame(data)



data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["300"].keys():
    if val_orientacion["300"][key]:
        angulo_tronco = val_orientacion["300"][key][0]["angulo_tronco"]
    else:
        angulo_tronco = 0

    data.append({
        "angulo": key,
        "angulo_tronco": angulo_tronco,
    })


df_orientaciones_300 = pd.DataFrame(data)

data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["400"].keys():
    if val_orientacion["400"][key]:
        angulo_tronco = val_orientacion["400"][key][0]["angulo_tronco"]
    else:
        angulo_tronco = 0

    data.append({
        "angulo": key,
        "angulo_tronco": angulo_tronco,
    })

df_orientaciones_400 = pd.DataFrame(data)

# %%
df_orientaciones_200
# Out:
#    angulo  angulo_tronco
# 0       0      61.376571
# 1      10      70.696088
# 2      20      57.315827
# 3      30      59.996862
# 4      40      55.866893
# 5      50      67.328857
# 6      60      74.318691
# 7      70      81.297913
# 8      80      85.696915
# 9      90      87.116076
# 10    100      98.540446
# 11    110      98.423810
# 12    120     111.897747
# 13    130     110.670885
# 14    140     119.583906
# 15    150     120.889508
# 16    160     125.365770
# 17    170     133.120509
# 18    180     100.639260

# %%
df_orientaciones_200["error"] = df_orientaciones_200["angulo_tronco"] - df_orientaciones_200["angulo"].astype(int)
df_orientaciones_200
# Out:
#    angulo  angulo_tronco      error
# 0       0      61.376571  61.376571
# 1      10      70.696088  60.696088
# 2      20      57.315827  37.315827
# 3      30      59.996862  29.996862
# 4      40      55.866893  15.866893
# 5      50      67.328857  17.328857
# 6      60      74.318691  14.318691
# 7      70      81.297913  11.297913
# 8      80      85.696915   5.696915
# 9      90      87.116076  -2.883924
# 10    100      98.540446  -1.459554
# 11    110      98.423810 -11.576190
# 12    120     111.897747  -8.102253
# 13    130     110.670885 -19.329115
# 14    140     119.583906 -20.416094
# 15    150     120.889508 -29.110492
# 16    160     125.365770 -34.634230
# 17    170     133.120509 -36.879491
# 18    180     100.639260 -79.360740

# %%
# grafica el angulo de Y, con valores en x de los indices de df_orientaciones_200
# plt.plot(df_orientaciones_200["angulo_tronco"])
# plt.plot(df_orientaciones_200["angulo"].astype(int))

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_200.index, df_orientaciones_200["angulo"].astype(int), label='True Angle', marker='o')
ax.plot(df_orientaciones_200.index, df_orientaciones_200["angulo_tronco"], label='Estimated angle', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Angle y Estimated angle')
ax.set_xlabel('Sample Index')
ax.set_ylabel('Angle (degrees)')

# Añadir una leyenda
ax.legend()

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
df_orientaciones_300# , df_orientaciones_300.dtypes
# Out:
#    angulo  angulo_tronco
# 0       0      97.538191
# 1      10      65.004973
# 2      20      72.877986
# 3      30      65.258656
# 4      40      64.040405
# 5      50      62.146345
# 6      60      67.533295
# 7      70      73.298029
# 8      80      82.975656
# 9      90      88.357362
# 10    100      97.107722
# 11    110      94.535112
# 12    120     101.441064
# 13    130     104.209005
# 14    140     106.821540
# 15    150     116.145573
# 16    160     127.089862
# 17    170     116.567874
# 18    180     106.247119

# %%
df_orientaciones_300["error"] = df_orientaciones_300["angulo_tronco"] - df_orientaciones_300["angulo"].astype(int)
df_orientaciones_300
# Out:
#    angulo  angulo_tronco      error
# 0       0      97.538191  97.538191
# 1      10      65.004973  55.004973
# 2      20      72.877986  52.877986
# 3      30      65.258656  35.258656
# 4      40      64.040405  24.040405
# 5      50      62.146345  12.146345
# 6      60      67.533295   7.533295
# 7      70      73.298029   3.298029
# 8      80      82.975656   2.975656
# 9      90      88.357362  -1.642638
# 10    100      97.107722  -2.892278
# 11    110      94.535112 -15.464888
# 12    120     101.441064 -18.558936
# 13    130     104.209005 -25.790995
# 14    140     106.821540 -33.178460
# 15    150     116.145573 -33.854427
# 16    160     127.089862 -32.910138
# 17    170     116.567874 -53.432126
# 18    180     106.247119 -73.752881

# %%
# grafica el angulo de Y, con valores en x de los indices de df_orientaciones_300
# plt.plot(df_orientaciones_300["angulo_tronco"])
# plt.plot(df_orientaciones_300["angulo"].astype(int))

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_300.index, df_orientaciones_300["angulo"].astype(int), label='True Angle', marker='o')
ax.plot(df_orientaciones_300.index, df_orientaciones_300["angulo_tronco"], label='Estimated angle', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Angle y Estimated angle')
ax.set_xlabel('Sample Index')
ax.set_ylabel('Angle (degrees)')

# Añadir una leyenda
ax.legend()

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
df_orientaciones_400
# Out:
#    angulo  angulo_tronco
# 0       0      82.238407
# 1      10      67.871939
# 2      20      65.074423
# 3      30      66.148250
# 4      40      66.863315
# 5      50      72.787628
# 6      60      83.084010
# 7      70      82.500655
# 8      80      75.145062
# 9      90      93.183592
# 10    100      98.590267
# 11    110      99.338818
# 12    120     104.019366
# 13    130     108.876129
# 14    140     110.069453
# 15    150     112.145537
# 16    160     115.025382
# 17    170     109.692287
# 18    180      81.809233

# %%
df_orientaciones_400["error"] = df_orientaciones_400["angulo_tronco"] - df_orientaciones_400["angulo"].astype(int)
df_orientaciones_400
# Out:
#    angulo  angulo_tronco      error
# 0       0      82.238407  82.238407
# 1      10      67.871939  57.871939
# 2      20      65.074423  45.074423
# 3      30      66.148250  36.148250
# 4      40      66.863315  26.863315
# 5      50      72.787628  22.787628
# 6      60      83.084010  23.084010
# 7      70      82.500655  12.500655
# 8      80      75.145062  -4.854938
# 9      90      93.183592   3.183592
# 10    100      98.590267  -1.409733
# 11    110      99.338818 -10.661182
# 12    120     104.019366 -15.980634
# 13    130     108.876129 -21.123871
# 14    140     110.069453 -29.930547
# 15    150     112.145537 -37.854463
# 16    160     115.025382 -44.974618
# 17    170     109.692287 -60.307713
# 18    180      81.809233 -98.190767

# %%
# grafica el angulo de Y, con valores en x de los indices de df_orientaciones_300
# plt.plot(df_orientaciones_400["angulo_tronco"])
# plt.plot(df_orientaciones_400["angulo"].astype(int))

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_400.index, df_orientaciones_400["angulo"].astype(int), label='True Angle', marker='o')
ax.plot(df_orientaciones_400.index, df_orientaciones_400["angulo_tronco"], label='Estimated angle', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Angle y Estimated angle')
ax.set_xlabel('Sample Index')
ax.set_ylabel('Angle (degrees)')

# Añadir una leyenda
ax.legend()

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# # Orientacion cabeza

# %%
val_orientacion_cabeza = json["orientacion_cabeza"]

# %%
data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["200"].keys():
    if val_orientacion_cabeza["200"][key]:
        angulo_tronco = val_orientacion_cabeza["200"][key][0]["angulo_tronco"]
        angulo_head = val_orientacion_cabeza["200"][key][0]["angulo_head"]
    else:
        angulo_tronco = 0
        angulo_head = 0

    data.append({
        "angulo": key,
        "angulo_tronco": angulo_tronco,
        "angulo_head": angulo_head,
    })

df_orientaciones_cabeza_200 = pd.DataFrame(data)

data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["300"].keys():
    if val_orientacion_cabeza["300"][key]:
        angulo_tronco = val_orientacion_cabeza["300"][key][0]["angulo_tronco"]
        angulo_head = val_orientacion_cabeza["300"][key][0]["angulo_head"]
    else:
        angulo_tronco = 0
        angulo_head = 0

    data.append({
        "angulo": key,
        "angulo_tronco": angulo_tronco,
        "angulo_head": angulo_head,
    })

df_orientaciones_cabeza_300 = pd.DataFrame(data)

data = []

# crear un dataframe con las orientaciones
for key in val_orientacion["400"].keys():
    if val_orientacion_cabeza["400"][key]:
        angulo_tronco = val_orientacion_cabeza["400"][key][0]["angulo_tronco"]
        angulo_head = val_orientacion_cabeza["400"][key][0]["angulo_head"]
    else:
        angulo_tronco = 0
        angulo_head = 0

    data.append({
        "angulo": key,
        "angulo_tronco": angulo_tronco,
        "angulo_head": angulo_head,
    })

df_orientaciones_cabeza_400 = pd.DataFrame(data)

# %%
# erro_absoluto = valor_real−valor estimado
df_orientaciones_cabeza_200["error_tronco"] = abs(df_orientaciones_cabeza_200["angulo"].astype(int) - df_orientaciones_cabeza_200["angulo_tronco"])
# porcentaje_error = erro_absoluto / valor_real * 100
df_orientaciones_cabeza_200["porcentaje_error_tronco"] = (df_orientaciones_cabeza_200["error_tronco"] * 100) / df_orientaciones_cabeza_200["angulo"].astype(int)
df_orientaciones_cabeza_200["precisión_tronco"] = 100 - df_orientaciones_cabeza_200["porcentaje_error_tronco"]

df_orientaciones_cabeza_200["error_head"] = abs(df_orientaciones_cabeza_200["angulo"].astype(int) - df_orientaciones_cabeza_200["angulo_head"])
df_orientaciones_cabeza_200["porcentaje_error_head"] = (df_orientaciones_cabeza_200["error_head"] * 100) / df_orientaciones_cabeza_200["angulo"].astype(int)
df_orientaciones_cabeza_200["precisión_head"] = 100 - df_orientaciones_cabeza_200["porcentaje_error_head"]

df_orientaciones_cabeza_200
# Out:
#    angulo  angulo_tronco  angulo_head  error_tronco  porcentaje_error_tronco  \
# 0       0      68.832667   132.228964     68.832667                      inf
# 1      10      72.007125   134.365795     62.007125               620.071251
# 2      20      55.798911   142.177994     35.798911               178.994556
# 3      30      59.996717    90.000000     29.996717                99.989055
# 4      40      63.393230    13.051856     23.393230                58.483075
# 5      50      69.763406     9.006618     19.763406                39.526811
# 6      60      77.800584   154.519006     17.800584                29.667639
# 7      70      78.983197    31.641054      8.983197                12.833138
# 8      80      82.500740    58.372951      2.500740                 3.125926
# 9      90      87.842279    90.765215      2.157721                 2.397468
# 10    100     101.169740   125.690872      1.169740                 1.169740
# ...

# %%
df_orientaciones_cabeza_200[df_orientaciones_cabeza_200["precisión_tronco"] > 80]
# Out:
#    angulo  angulo_tronco  angulo_head  error_tronco  porcentaje_error_tronco  \
# 7      70      78.983197    31.641054      8.983197                12.833138
# 8      80      82.500740    58.372951      2.500740                 3.125926
# 9      90      87.842279    90.765215      2.157721                 2.397468
# 10    100     101.169740   125.690872      1.169740                 1.169740
# 11    110     102.551014   137.242128      7.448986                 6.771806
# 12    120     109.881618    42.428937     10.118382                 8.431985
# 13    130     112.309101    47.908388     17.690899                13.608384
# 14    140     119.614828   174.204961     20.385172                14.560837
# 15    150     128.977040    52.557754     21.022960                14.015307
#
#     precisión_tronco  error_head  porcentaje_error_head  precisión_head
# 7          87.166862   38.358946              54.798495       45.201505
# ...

# %%
round(df_orientaciones_cabeza_200[df_orientaciones_cabeza_200["precisión_tronco"] > 80]["precisión_tronco"].mean(), 2)
# Out:
# 91.45

# %%
df_orientaciones_cabeza_200[df_orientaciones_cabeza_200["precisión_head"] > 70]
# Out:
#    angulo  angulo_tronco  angulo_head  error_tronco  porcentaje_error_tronco  \
# 8      80      82.500740    58.372951      2.500740                 3.125926
# 9      90      87.842279    90.765215      2.157721                 2.397468
# 10    100     101.169740   125.690872      1.169740                 1.169740
# 11    110     102.551014   137.242128      7.448986                 6.771806
# 14    140     119.614828   174.204961     20.385172                14.560837
#
#     precisión_tronco  error_head  porcentaje_error_head  precisión_head
# 8          96.874074   21.627049              27.033812       72.966188
# 9          97.602532    0.765215               0.850239       99.149761
# 10         98.830260   25.690872              25.690872       74.309128
# 11         93.228194   27.242128              24.765570       75.234430
# 14         85.439163   34.204961              24.432115       75.567885

# %%
round(df_orientaciones_cabeza_200[df_orientaciones_cabeza_200["precisión_head"] > 70]["precisión_head"].mean(), 2)
# Out:
# 79.45

# %%
# grafica el angulo de Y, con valores en x de los indices de df_orientaciones_200
# plt.plot(df_orientaciones_200["angulo_tronco"])
# plt.plot(df_orientaciones_200["angulo"].astype(int))

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_cabeza_200.index, df_orientaciones_cabeza_200["angulo"].astype(int), label='True Angle', marker='o')
ax.plot(df_orientaciones_cabeza_200.index, df_orientaciones_cabeza_200["angulo_tronco"], label='Estimated Angle of Body Orientation', marker='s')
ax.plot(df_orientaciones_cabeza_200.index, df_orientaciones_cabeza_200["angulo_head"], label='Estimated Angle of Head Orientation', marker='s')


# Configurar el título y las etiquetas de los ejes
ax.set_title('Estimated angles at 2 meters - ' + method, fontsize=18)
ax.set_xlabel('Sample Index', fontsize=16)
ax.set_ylabel('Angle (degrees)', fontsize=16)

# y vaya de entre 100 y 200
plt.ylim(-50, 200)

# Añadir una leyenda
ax.legend(fontsize=14)

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
df_orientaciones_cabeza_300["error_tronco"] = abs(df_orientaciones_cabeza_300["angulo"].astype(int) - df_orientaciones_cabeza_300["angulo_tronco"])
df_orientaciones_cabeza_300["porcentaje_error_tronco"] = (df_orientaciones_cabeza_300["error_tronco"] * 100) / df_orientaciones_cabeza_300["angulo"].astype(int)
df_orientaciones_cabeza_300["precisión_tronco"] = 100 - df_orientaciones_cabeza_300["porcentaje_error_tronco"]

df_orientaciones_cabeza_300["error_head"] = abs(df_orientaciones_cabeza_300["angulo"].astype(int) - df_orientaciones_cabeza_300["angulo_head"])
df_orientaciones_cabeza_300["porcentaje_error_head"] = (df_orientaciones_cabeza_300["error_head"] * 100) / df_orientaciones_cabeza_300["angulo"].astype(int)
df_orientaciones_cabeza_300["precisión_head"] = 100 - df_orientaciones_cabeza_300["porcentaje_error_head"]

df_orientaciones_cabeza_300
# Out:
#    angulo  angulo_tronco  angulo_head  error_tronco  porcentaje_error_tronco  \
# 0       0      84.252376   130.193990     84.252376                      inf
# 1      10      66.928288   136.995029     56.928288               569.282877
# 2      20      61.760114   144.617056     41.760114               208.800568
# 3      30      67.233488    90.000000     37.233488               124.111628
# 4      40      72.553787   138.627720     32.553787                81.384468
# 5      50      71.318253     7.812908     21.318253                42.636506
# 6      60      69.885462     9.521611      9.885462                16.475770
# 7      70      82.216669    19.036016     12.216669                17.452384
# 8      80      82.583240    73.882951      2.583240                 3.229050
# 9      90      87.477887    91.793033      2.522113                 2.802347
# 10    100      95.039973   128.664059      4.960027                 4.960027
# ...

# %%
df_orientaciones_cabeza_300[df_orientaciones_cabeza_300["precisión_tronco"] > 80]
# Out:
#    angulo  angulo_tronco  angulo_head  error_tronco  porcentaje_error_tronco  \
# 6      60      69.885462     9.521611      9.885462                16.475770
# 7      70      82.216669    19.036016     12.216669                17.452384
# 8      80      82.583240    73.882951      2.583240                 3.229050
# 9      90      87.477887    91.793033      2.522113                 2.802347
# 10    100      95.039973   128.664059      4.960027                 4.960027
# 11    110      99.671198    49.752549     10.328802                 9.389820
# 12    120     107.715547   169.995619     12.284453                10.237044
# 13    130     110.071326   141.352557     19.928674                15.329749
# 18    180     174.536113   134.586603      5.463887                 3.035493
#
#     precisión_tronco  error_head  porcentaje_error_head  precisión_head
# 6          83.524230   50.478389              84.130648       15.869352
# ...

# %%
round(df_orientaciones_cabeza_300[df_orientaciones_cabeza_300["precisión_tronco"] > 80]["precisión_tronco"].mean(), 2)
# Out:
# 90.79

# %%
df_orientaciones_cabeza_300[df_orientaciones_cabeza_300["precisión_head"] > 70]
# Out:
#    angulo  angulo_tronco  angulo_head  error_tronco  porcentaje_error_tronco  \
# 8      80      82.583240    73.882951      2.583240                 3.229050
# 9      90      87.477887    91.793033      2.522113                 2.802347
# 10    100      95.039973   128.664059      4.960027                 4.960027
# 13    130     110.071326   141.352557     19.928674                15.329749
# 18    180     174.536113   134.586603      5.463887                 3.035493
#
#     precisión_tronco  error_head  porcentaje_error_head  precisión_head
# 8          96.770950    6.117049               7.646312       92.353688
# 9          97.197653    1.793033               1.992259       98.007741
# 10         95.039973   28.664059              28.664059       71.335941
# 13         84.670251   11.352557               8.732736       91.267264
# 18         96.964507   45.413397              25.229665       74.770335

# %%
round(df_orientaciones_cabeza_300[df_orientaciones_cabeza_300["precisión_head"] > 70]["precisión_head"].mean(), 2)
# Out:
# 85.55

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_cabeza_300.index, df_orientaciones_cabeza_300["angulo"].astype(int), label='True Angle', marker='o')
ax.plot(df_orientaciones_cabeza_300.index, df_orientaciones_cabeza_300["angulo_tronco"], label='Estimated Angle of Body Orientation', marker='s')
ax.plot(df_orientaciones_cabeza_300.index, df_orientaciones_cabeza_300["angulo_head"], label='Estimated Angle of Head Orientation', marker='s')


# Configurar el título y las etiquetas de los ejes
ax.set_title('Estimated angles at 3 meters - ' + method, fontsize=18)
ax.set_xlabel('Sample Index', fontsize=16)
ax.set_ylabel('Angle (degrees)', fontsize=16)

# Añadir una leyenda
ax.legend(fontsize=14)

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
df_orientaciones_cabeza_400["error_tronco"] = abs(df_orientaciones_cabeza_400["angulo"].astype(int) - df_orientaciones_cabeza_400["angulo_tronco"])
df_orientaciones_cabeza_400["porcentaje_error_tronco"] = (df_orientaciones_cabeza_400["error_tronco"] * 100) / df_orientaciones_cabeza_400["angulo"].astype(int)
df_orientaciones_cabeza_400["precisión_tronco"] = 100 - df_orientaciones_cabeza_400["porcentaje_error_tronco"]

df_orientaciones_cabeza_400["error_head"] = abs(df_orientaciones_cabeza_400["angulo"].astype(int) - df_orientaciones_cabeza_400["angulo_head"])
df_orientaciones_cabeza_400["porcentaje_error_head"] = (df_orientaciones_cabeza_400["error_head"] * 100) / df_orientaciones_cabeza_400["angulo"].astype(int)
df_orientaciones_cabeza_400["precisión_head"] = 100 - df_orientaciones_cabeza_400["porcentaje_error_head"]

df_orientaciones_cabeza_400
# Out:
#    angulo  angulo_tronco  angulo_head  error_tronco  porcentaje_error_tronco  \
# 0       0      89.855431   116.693749     89.855431                      inf
# 1      10       0.000000     0.000000     10.000000               100.000000
# 2      20      57.310783   139.527336     37.310783               186.553916
# 3      30      65.590337    21.223269     35.590337               118.634457
# 4      40      73.896384     7.799986     33.896384                84.740961
# 5      50      76.575240     7.349359     26.575240                53.150480
# 6      60      75.927655     5.686494     15.927655                26.546092
# 7      70      77.573219    21.135071      7.573219                10.818885
# 8      80      82.477353     3.809563      2.477353                 3.096692
# 9      90      89.547272    81.810834      0.452728                 0.503031
# 10    100      93.524353   157.431403      6.475647                 6.475647
# ...

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_cabeza_400.index, df_orientaciones_cabeza_400["angulo"].astype(int), label='True Angle', marker='o')
ax.plot(df_orientaciones_cabeza_400.index, df_orientaciones_cabeza_400["angulo_tronco"], label='Estimated Angle of Body Orientation', marker='s')
ax.plot(df_orientaciones_cabeza_400.index, df_orientaciones_cabeza_400["angulo_head"], label='Estimated Angle of Head Orientation', marker='s')

# Configurar el título y las etiquetas de los ejes
ax.set_title('Estimated angles at 4 meters - ' + method, fontsize=18)
ax.set_xlabel('Sample Index', fontsize=16)
ax.set_ylabel('Angle (degrees)', fontsize=16)

# Añadir una leyenda
ax.legend(fontsize=14)

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_orientaciones_cabeza_200.index, df_orientaciones_cabeza_200["angulo"].astype(int), label='True Angle', marker='o')
ax.plot(df_orientaciones_cabeza_200.index, df_orientaciones_cabeza_200["angulo_head"], label='Estimated Angle of Head Orientation 200', marker='s')
ax.plot(df_orientaciones_cabeza_300.index, df_orientaciones_cabeza_300["angulo_head"], label='Estimated Angle of Head Orientation 300', marker='s')
ax.plot(df_orientaciones_cabeza_400.index, df_orientaciones_cabeza_400["angulo_head"], label='Estimated Angle of Head Orientation 400', marker='s')



# Configurar el título y las etiquetas de los ejes
ax.set_title('Estimated angles at 2 meters - ' + method, fontsize=18)
ax.set_xlabel('Sample Index', fontsize=16)
ax.set_ylabel('Angle (degrees)', fontsize=16)

# y vaya de entre 100 y 200
plt.ylim(-50, 200)

# Añadir una leyenda
ax.legend(fontsize=14)

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# # Altura

# %%
val_height = json["height_167"]

# %%
data = []

# crear un dataframe con las orientaciones
for key in val_height.keys():
    data.append({"distancia": key, "altura_estimada": val_height[key][0]["respuesta"]})#, "angulo_head": val_orientacion["300"][key][0]["angulo_head"]})

df_val_height = pd.DataFrame(data)
df_val_height["altura_real"] = 167

# %%
df_val_height["error"] = abs(df_val_height["altura_real"] - df_val_height["altura_estimada"])
df_val_height["porcentaje_error"] = (df_val_height["error"] * 100) / df_val_height["altura_real"]
df_val_height["precisión"] = 100 - df_val_height["porcentaje_error"]
df_val_height
# Out:
#   distancia  altura_estimada  altura_real      error  porcentaje_error  \
# 0       200       179.420848          167  12.420848          7.437633
# 1       250       173.596286          167   6.596286          3.949872
# 2       300       166.982772          167   0.017228          0.010316
# 3       350       158.157248          167   8.842752          5.295061
# 4       400       152.083363          167  14.916637          8.932118
# 5       450       147.292631          167  19.707369         11.800820
# 6       500       145.129701          167  21.870299         13.095988
# 7       550       137.889973          167  29.110027         17.431154
# 8       600       133.608842          167  33.391158         19.994705
#
#    precisión
# 0  92.562367
# 1  96.050128
# 2  99.989684
# 3  94.704939
# 4  91.067882
# 5  88.199180
# 6  86.904012
# 7  82.568846
# 8  80.005295

# %%
round(df_val_height["precisión"].mean(), 2)
# Out:
# 90.23

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Graficar ambas líneas
ax.plot(df_val_height.distancia, df_val_height["altura_real"].astype(int), label='Height [True]', marker='o')
ax.plot(df_val_height.distancia, df_val_height["altura_estimada"], label='Height [Estimated]', marker='s')

# Configurar el título y las etiquetas de los ejes
# ax.set_title('Height estimation using constant height at variable depths', fontsize=18)
ax.set_title('Height estimation at variable depths', fontsize=18)
ax.set_xlabel('Distance (cm)', fontsize=16)
ax.set_ylabel('Height (cm)', fontsize=16)

# Añadir una leyenda
ax.legend(fontsize=14)

# y vaya de entre 100 y 200
plt.ylim(100, 200)

# Añadir una cuadrícula para mejor lectura
ax.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.show()
